# %%
import pandas as pd
import pickle
from tqdm import tqdm
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
header = [
    'e1_kb', 'rel_kb', 'rel_id', 'e2_kb', 'e1_oie', 'rel_oie', 'e2_oie',
    'e1_kb_id', 'e2_kb_id', 'e1_oie_id', 'e2_oie_id', 'e1_oie_root', 'e2_oie_root', 'label'
]
train = pd.read_csv('../dataset/train_align_all_balanced.tsv', sep='\t', header=None, names=header)
valid = pd.read_csv('../dataset/valid_align_all.tsv', sep='\t', header=None, names=header)
train = train.append(valid, ignore_index=True)
train = train[pd.notnull(train['e1_oie_id']) & pd.notnull(train['e2_oie_id'])]
train = train.reset_index(drop=True)

# %%
train

# %%
oie_triples = train.groupby(['rel_oie']).size()

# %%
oie_triples['written by']

# %%
align = pd.DataFrame(columns=['rel_oie', 'K', 'rel_kb', 'e1_type', 'e2_type', 'conf', 'tou'])

# %%
with open('rel_list.pickle', 'rb') as file:
    rel_list = pickle.load(file)

def get_relation_list(e1, e2):
    try:
        return rel_list[e1 + ' ' + e2]
    except KeyError:
        try:
            sparql.setQuery("""
            SELECT ?relation WHERE {
                wd:%s ?relation wd:%s .
            }
            """ % (e1, e2))
            sparql.setReturnFormat(JSON)
            results = sparql.query().convert()
            prop_list = [i['relation']['value'].replace('http://www.wikidata.org/prop/direct/', '') for i in results['results']['bindings']]
            rel_list[e1 + ' ' + e2] = prop_list
            return prop_list
        except OSError:
            sparql.setQuery("""
            SELECT ?relation WHERE {
                wd:%s ?relation wd:%s .
            }
            """ % (e1, e2))
            sparql.setReturnFormat(JSON)
            results = sparql.query().convert()
            prop_list = [i['relation']['value'].replace('http://www.wikidata.org/prop/direct/', '') for i in results['results']['bindings']]
            rel_list[e1 + ' ' + e2] = prop_list
            return prop_list

# %%
with open('entity_type.pickle', 'rb') as file:
    entity_type = pickle.load(file)

# %%
def get_entity_type(e):
    try:
        if type(entity_type[e]) == bytes:
            return entity_type[e].decode("utf-8")
        elif type(entity_type[e]) == str:
            return entity_type[e]
        else:
            return str(entity_type[e])
    except KeyError:
        ent_type = '-'
        return ent_type

# %%
idx = 0
len_train = len(train)

for i in tqdm(range(len_train)):
    rel_oie = train['rel_oie'][i]
    e1 = train['e1_oie_id'][i]
    e2 = train['e2_oie_id'][i]
    
    e1_type = get_entity_type(e1)
    e2_type = get_entity_type(e2)
    kb_rels = get_relation_list(e1, e2)
    
    for rel in kb_rels:
        align.at[idx, 'rel_oie'] = rel_oie
        align.at[idx, 'rel_kb'] = rel
        align.at[idx, 'e1_type'] = e1_type
        align.at[idx, 'e2_type'] = e2_type
        idx += 1

# %%
if len(rel_list) > 0:
    with open('rel_list.pickle', 'wb') as handle:
        pickle.dump(rel_list, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
# if len(entity_type) > 0:
#     with open('entity_type.pickle', 'wb') as handle:
#         pickle.dump(entity_type, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
align

# %%
oie_triples_align = align.groupby(['rel_oie', 'e1_type', 'e2_type']).size()
oie_triples_align_total = align.groupby(['rel_oie']).size()

# %%
for i in tqdm(range(len(align))):
    rel_oie = align['rel_oie'][i]
    e1_type = align['e1_type'][i]
    e2_type = align['e2_type'][i]
    
    # Calculate K
    K = len(oie_triples_align[rel_oie]) / oie_triples[rel_oie]
    if K > 1:
        K = 1
    align['K'][i] = K
        
    # Calculate conf
    conf = oie_triples_align[rel_oie][e1_type][e2_type] / oie_triples_align_total[rel_oie]
    align['conf'][i] = conf
    
    # Calculate tou
    tou = (1 - K) / conf
    align['tou'][i] = conf

# %%
align

# %%
align.to_csv('align.tsv', sep='\t', index=False)

# %% [markdown]
# ### Run Linear Regression

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import linear_model
from tqdm import tqdm

# %%
align = pd.read_csv('align.tsv', sep='\t')

# %%
align
# Out:
#                               rel_oie         K rel_kb  \
# 0                       was filmed in  0.012658   P462
# 1                                  is  0.011210   P462
# 2                                  is  0.011210   P462
# 3                            starring  0.002943   P161
# 4                            starring  0.002943   P161
# 5                         directed by  0.000823    P57
# 6                         directed by  0.000823   P162
# 7                                 are  0.018613   P462
# 8                                 was  0.011766    P31
# 9                            starring  0.002943   P161
# 10                      is still seen  0.200000   P462
# 11                            is seen  0.142857   P462
# 12                    is seen at_time  1.000000  P1441
# 13              is still seen at_time  1.000000  P1441
# 14                    was directed by  0.008091    P57
# 15                    was directed by  0.008091   P162
# 16                    was directed by  0.008091   P344
# 17                    was directed by  0.008091  P1040
# 18                        directed by  0.000823    P57
# 19                        directed by  0.000823   P162
# 20                        directed by  0.000823  P1040
# 21                                 is  0.011210   P136
# 22                            reps 's  0.083333  P1040
# 23                        directed by  0.000823    P57
# 24                        directed by  0.000823    P58
# 25                        directed by  0.000823   P161
# 26                        directed by  0.000823  P1040
# 27                                 is  0.011210   P364
# 28                                 is  0.011210   P364
# 29                                 is  0.011210   P364
# ...                               ...       ...    ...
# 832285              is licensed under  0.048780   P275
# 832286              is released under  0.038168   P275
# 832287              is released under  0.038168   P275
# 832288             was licensed under  0.066667   P275
# 832289                             is  0.011210   P275
# 832290                     preferring  0.066667   P275
# 832291              is released under  0.038168   P275
# 832292              is released under  0.038168   P275
# 832293              is licensed under  0.048780   P275
# 832294              is released under  0.038168   P275
# 832295              is released under  0.038168   P275
# 832296             was licensed under  0.066667   P275
# 832297                             is  0.011210   P275
# 832298                     preferring  0.066667   P275
# 832299                 Released under  0.085106   P275
# 832300              Distributed under  0.058824   P275
# 832301              is released under  0.038168   P275
# 832302              is licensed under  0.048780   P275
# 832303              is released under  0.038168   P275
# 832304  was originally released under  0.095238   P275
# 832305             was released under  0.060606   P275
# 832306           is distributed under  0.058824   P275
# 832307              is licensed under  0.048780   P275
# 832308              is released under  0.038168   P275
# 832309              is released under  0.038168   P275
# 832310             was licensed under  0.066667   P275
# 832311                             is  0.011210   P275
# 832312                     preferring  0.066667   P275
# 832313              is released under  0.038168   P275
# 832314              is released under  0.038168   P275
#
#                                   e1_type                           e2_type  \
# 0                                    film                             color
# 1                                    film                             color
# 2                                    film                             color
# 3                                    film                             human
# 4                                    film                             human
# 5                                    film                             human
# 6                                    film                             human
# 7                            color scheme                 safest web colors
# 8                               house cat                             taxon
# 9                                    film                             human
# 10                   fictional automobile                             color
# 11                   fictional automobile                             color
# 12                   fictional automobile                 television series
# 13                   fictional automobile                 television series
# 14                                   film                             human
# 15                                   film                             human
# 16                                   film                             human
# 17                                   film                             human
# 18                                   film                             human
# 19                                   film                             human
# 20                                   film                             human
# 21                                   film                        film genre
# 22                                   film                             human
# 23                                   film                             human
# 24                                   film                             human
# 25                                   film                             human
# 26                                   film                             human
# 27                                   film                 pro-drop language
# 28                                   film                          language
# 29                                   film                 pro-drop language
# ...                                   ...                               ...
# 832285                      free software  permissive free software licence
# 832286                             kernel    free software copyleft license
# 832287                             kernel    free software copyleft license
# 832288                         IRC client               open source license
# 832289                         video game                    business model
# 832290  Security-focused operating system               open source license
# 832291        wiki with script conversion                  copyleft license
# 832292                      free software                           license
# 832293                      free software  permissive free software licence
# 832294                             kernel    free software copyleft license
# 832295                             kernel    free software copyleft license
# 832296                         IRC client               open source license
# 832297                         video game                    business model
# 832298  Security-focused operating system               open source license
# 832299           instant messaging client               open source license
# 832300                   computer program               open source license
# 832301                      free software               open source license
# 832302                           software               open source license
# 832303        wiki with script conversion                  copyleft license
# 832304                      free software               open source license
# 832305                      free software               open source license
# 832306                      free software               open source license
# 832307                      free software  permissive free software licence
# 832308                             kernel    free software copyleft license
# 832309                             kernel    free software copyleft license
# 832310                         IRC client               open source license
# 832311                         video game                    business model
# 832312  Security-focused operating system               open source license
# 832313        wiki with script conversion                  copyleft license
# 832314                      free software                           license
#
#             conf       tou
# 0       0.000476  0.000476
# 1       0.000468  0.000468
# 2       0.000468  0.000468
# 3       0.767110  0.767110
# 4       0.767110  0.767110
# 5       0.916603  0.916603
# 6       0.916603  0.916603
# 7       0.001524  0.001524
# 8       0.000350  0.000350
# 9       0.767110  0.767110
# 10      1.000000  1.000000
# 11      1.000000  1.000000
# 12      1.000000  1.000000
# 13      1.000000  1.000000
# 14      0.902755  0.902755
# 15      0.902755  0.902755
# 16      0.902755  0.902755
# 17      0.902755  0.902755
# 18      0.916603  0.916603
# 19      0.916603  0.916603
# 20      0.916603  0.916603
# 21      0.002339  0.002339
# 22      1.000000  1.000000
# 23      0.916603  0.916603
# 24      0.916603  0.916603
# 25      0.916603  0.916603
# 26      0.916603  0.916603
# 27      0.052791  0.052791
# 28      0.185073  0.185073
# 29      0.052791  0.052791
# ...          ...       ...
# 832285  0.416667  0.416667
# 832286  0.227642  0.227642
# 832287  0.227642  0.227642
# 832288  1.000000  1.000000
# 832289  0.000540  0.000540
# 832290  1.000000  1.000000
# 832291  0.121951  0.121951
# 832292  0.121951  0.121951
# 832293  0.416667  0.416667
# 832294  0.227642  0.227642
# 832295  0.227642  0.227642
# 832296  1.000000  1.000000
# 832297  0.000540  0.000540
# 832298  1.000000  1.000000
# 832299  0.200000  0.200000
# 832300  0.272727  0.272727
# 832301  0.317073  0.317073
# 832302  0.583333  0.583333
# 832303  0.121951  0.121951
# 832304  0.428571  0.428571
# 832305  0.180328  0.180328
# 832306  0.272727  0.272727
# 832307  0.416667  0.416667
# 832308  0.227642  0.227642
# 832309  0.227642  0.227642
# 832310  1.000000  1.000000
# 832311  0.000540  0.000540
# 832312  1.000000  1.000000
# 832313  0.121951  0.121951
# 832314  0.121951  0.121951
#
# [832315 rows x 7 columns]

# %%
tou_list = np.array(align['tou']).reshape(-1, 1)
K_list = np.array(align['K']).reshape(-1, 1)

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(K_list, tou_list)

# Make predictions using the testing set
tou_pred = regr.predict(K_list)

# %%
tou_h = []
for i in tqdm(range(len(tou_pred))):
    tou_h.append(tou_pred[i][0])
# Out:
# 100%|██████████| 832315/832315 [00:00<00:00, 1907195.50it/s]

# %%
align['tou_h'] = tou_h

# %%
align
# Out:
#                               rel_oie         K rel_kb  \
# 0                       was filmed in  0.012658   P462
# 1                                  is  0.011210   P462
# 2                                  is  0.011210   P462
# 3                            starring  0.002943   P161
# 4                            starring  0.002943   P161
# 5                         directed by  0.000823    P57
# 6                         directed by  0.000823   P162
# 7                                 are  0.018613   P462
# 8                                 was  0.011766    P31
# 9                            starring  0.002943   P161
# 10                      is still seen  0.200000   P462
# 11                            is seen  0.142857   P462
# 12                    is seen at_time  1.000000  P1441
# 13              is still seen at_time  1.000000  P1441
# 14                    was directed by  0.008091    P57
# 15                    was directed by  0.008091   P162
# 16                    was directed by  0.008091   P344
# 17                    was directed by  0.008091  P1040
# 18                        directed by  0.000823    P57
# 19                        directed by  0.000823   P162
# 20                        directed by  0.000823  P1040
# 21                                 is  0.011210   P136
# 22                            reps 's  0.083333  P1040
# 23                        directed by  0.000823    P57
# 24                        directed by  0.000823    P58
# 25                        directed by  0.000823   P161
# 26                        directed by  0.000823  P1040
# 27                                 is  0.011210   P364
# 28                                 is  0.011210   P364
# 29                                 is  0.011210   P364
# ...                               ...       ...    ...
# 832285              is licensed under  0.048780   P275
# 832286              is released under  0.038168   P275
# 832287              is released under  0.038168   P275
# 832288             was licensed under  0.066667   P275
# 832289                             is  0.011210   P275
# 832290                     preferring  0.066667   P275
# 832291              is released under  0.038168   P275
# 832292              is released under  0.038168   P275
# 832293              is licensed under  0.048780   P275
# 832294              is released under  0.038168   P275
# 832295              is released under  0.038168   P275
# 832296             was licensed under  0.066667   P275
# 832297                             is  0.011210   P275
# 832298                     preferring  0.066667   P275
# 832299                 Released under  0.085106   P275
# 832300              Distributed under  0.058824   P275
# 832301              is released under  0.038168   P275
# 832302              is licensed under  0.048780   P275
# 832303              is released under  0.038168   P275
# 832304  was originally released under  0.095238   P275
# 832305             was released under  0.060606   P275
# 832306           is distributed under  0.058824   P275
# 832307              is licensed under  0.048780   P275
# 832308              is released under  0.038168   P275
# 832309              is released under  0.038168   P275
# 832310             was licensed under  0.066667   P275
# 832311                             is  0.011210   P275
# 832312                     preferring  0.066667   P275
# 832313              is released under  0.038168   P275
# 832314              is released under  0.038168   P275
#
#                                   e1_type                           e2_type  \
# 0                                    film                             color
# 1                                    film                             color
# 2                                    film                             color
# 3                                    film                             human
# 4                                    film                             human
# 5                                    film                             human
# 6                                    film                             human
# 7                            color scheme                 safest web colors
# 8                               house cat                             taxon
# 9                                    film                             human
# 10                   fictional automobile                             color
# 11                   fictional automobile                             color
# 12                   fictional automobile                 television series
# 13                   fictional automobile                 television series
# 14                                   film                             human
# 15                                   film                             human
# 16                                   film                             human
# 17                                   film                             human
# 18                                   film                             human
# 19                                   film                             human
# 20                                   film                             human
# 21                                   film                        film genre
# 22                                   film                             human
# 23                                   film                             human
# 24                                   film                             human
# 25                                   film                             human
# 26                                   film                             human
# 27                                   film                 pro-drop language
# 28                                   film                          language
# 29                                   film                 pro-drop language
# ...                                   ...                               ...
# 832285                      free software  permissive free software licence
# 832286                             kernel    free software copyleft license
# 832287                             kernel    free software copyleft license
# 832288                         IRC client               open source license
# 832289                         video game                    business model
# 832290  Security-focused operating system               open source license
# 832291        wiki with script conversion                  copyleft license
# 832292                      free software                           license
# 832293                      free software  permissive free software licence
# 832294                             kernel    free software copyleft license
# 832295                             kernel    free software copyleft license
# 832296                         IRC client               open source license
# 832297                         video game                    business model
# 832298  Security-focused operating system               open source license
# 832299           instant messaging client               open source license
# 832300                   computer program               open source license
# 832301                      free software               open source license
# 832302                           software               open source license
# 832303        wiki with script conversion                  copyleft license
# 832304                      free software               open source license
# 832305                      free software               open source license
# 832306                      free software               open source license
# 832307                      free software  permissive free software licence
# 832308                             kernel    free software copyleft license
# 832309                             kernel    free software copyleft license
# 832310                         IRC client               open source license
# 832311                         video game                    business model
# 832312  Security-focused operating system               open source license
# 832313        wiki with script conversion                  copyleft license
# 832314                      free software                           license
#
#             conf       tou     tou_h
# 0       0.000476  0.000476  0.515746
# 1       0.000468  0.000468  0.514561
# 2       0.000468  0.000468  0.514561
# 3       0.767110  0.767110  0.507791
# 4       0.767110  0.767110  0.507791
# 5       0.916603  0.916603  0.506054
# 6       0.916603  0.916603  0.506054
# 7       0.001524  0.001524  0.520622
# 8       0.000350  0.000350  0.515015
# 9       0.767110  0.767110  0.507791
# 10      1.000000  1.000000  0.669159
# 11      1.000000  1.000000  0.622365
# 12      1.000000  1.000000  1.324271
# 13      1.000000  1.000000  1.324271
# 14      0.902755  0.902755  0.512006
# 15      0.902755  0.902755  0.512006
# 16      0.902755  0.902755  0.512006
# 17      0.902755  0.902755  0.512006
# 18      0.916603  0.916603  0.506054
# 19      0.916603  0.916603  0.506054
# 20      0.916603  0.916603  0.506054
# 21      0.002339  0.002339  0.514561
# 22      1.000000  1.000000  0.573621
# 23      0.916603  0.916603  0.506054
# 24      0.916603  0.916603  0.506054
# 25      0.916603  0.916603  0.506054
# 26      0.916603  0.916603  0.506054
# 27      0.052791  0.052791  0.514561
# 28      0.185073  0.185073  0.514561
# 29      0.052791  0.052791  0.514561
# ...          ...       ...       ...
# 832285  0.416667  0.416667  0.545326
# 832286  0.227642  0.227642  0.536636
# 832287  0.227642  0.227642  0.536636
# 832288  1.000000  1.000000  0.559973
# 832289  0.000540  0.000540  0.514561
# 832290  1.000000  1.000000  0.559973
# 832291  0.121951  0.121951  0.536636
# 832292  0.121951  0.121951  0.536636
# 832293  0.416667  0.416667  0.545326
# 832294  0.227642  0.227642  0.536636
# 832295  0.227642  0.227642  0.536636
# 832296  1.000000  1.000000  0.559973
# 832297  0.000540  0.000540  0.514561
# 832298  1.000000  1.000000  0.559973
# 832299  0.200000  0.200000  0.575073
# 832300  0.272727  0.272727  0.553551
# 832301  0.317073  0.317073  0.536636
# 832302  0.583333  0.583333  0.545326
# 832303  0.121951  0.121951  0.536636
# 832304  0.428571  0.428571  0.583370
# 832305  0.180328  0.180328  0.555010
# 832306  0.272727  0.272727  0.553551
# 832307  0.416667  0.416667  0.545326
# 832308  0.227642  0.227642  0.536636
# 832309  0.227642  0.227642  0.536636
# 832310  1.000000  1.000000  0.559973
# 832311  0.000540  0.000540  0.514561
# 832312  1.000000  1.000000  0.559973
# 832313  0.121951  0.121951  0.536636
# 832314  0.121951  0.121951  0.536636
#
# [832315 rows x 8 columns]

# %%
is_aligned = []
for i in tqdm(range(len(tou_h))):
    thres = align['tou_h'][i]
    val = align['tou'][i]
    if val < thres:
        is_aligned.append(1)
    else:
        is_aligned.append(0)
# Out:
# 100%|██████████| 832315/832315 [00:16<00:00, 49683.02it/s]

# %%
align['is_aligned'] = is_aligned

# %%
align_pos = align[align.is_aligned == 1]

# %%
align_pos_grouped = align_pos.groupby(['rel_kb', 'rel_oie']).size()

# %%
align_pos_df = align_pos_grouped.to_frame().reset_index()
align_pos_df = align_pos_df.drop(0, axis=1)

# %%
align_pos_df
# Out:
#      rel_kb                         rel_oie
# 0     P1001                      Council of
# 1     P1001                        Court of
# 2     P1001                       branch of
# 3     P1001                           is In
# 4     P1001                           is in
# 5     P1001                   parliament 's
# 6      P101                             has
# 7      P101                           is In
# 8      P101                           is in
# 9      P101                 is professor of
# 10     P101                     merged with
# 11     P101                              of
# 12     P101                 specializing in
# 13     P101                         studied
# 14     P102                    President of
# 15     P102                   candidate for
# 16     P102                      founder of
# 17     P102                              in
# 18     P102                    is member of
# 19     P102                          joined
# 20     P102                       member of
# 21     P102                              of
# 22     P102                raised money for
# 23     P102                     represented
# 24     P102                   was member of
# 25     P103                     appeared in
# 26     P103                             had
# 27     P103                              is
# 28     P103                           is in
# 29     P103                           speak
# ...     ...                             ...
# 3845   P937  visited Korchma Taras Bulba in
# 3846   P937                was Pedagogue in
# 3847   P937                     was born at
# 3848   P937                     was born in
# 3849   P937                    was mayor of
# 3850   P937            was probably born in
# 3851    P97                      appears as
# 3852    P97                              be
# 3853    P97                          became
# 3854    P97                             had
# 3855    P97                              is
# 3856    P97              succeeded Qutuz as
# 3857    P97                             was
# 3858    P97                     was born to
# 3859    P97                  was considered
# 3860    P97                    was declared
# 3861    P97                    was sired by
# 3862    P97                was succeeded as
# 3863   P974                approximate with
# 3864   P974                       begins as
# 3865   P974                        connects
# 3866   P974                             had
# 3867   P974                is also known as
# 3868   P974            is connected through
# 3869   P974                    is joined by
# 3870   P974                     is known as
# 3871   P974                           joins
# 3872    P98                    developed by
# 3873    P98                  was founded by
# 3874    P98               was launched with
#
# [3875 rows x 2 columns]

# %%
kb_to_oie = {}
for i in range(len(align_pos_df)):
    key = align_pos_df['rel_kb'][i]
    val = align_pos_df['rel_oie'][i]
    if key not in kb_to_oie:
        kb_to_oie[key] = [val]
    else:
        kb_to_oie[key] = kb_to_oie[key] + [val]

# %%
kb_to_oie
# Out:
# {'P1001': ['Council of',
#   'Court of',
#   'branch of',
#   'is In',
#   'is in',
#   "parliament 's"],
#  'P101': ['has',
#   'is In',
#   'is in',
#   'is professor of',
#   'merged with',
#   'of',
#   'specializing in',
#   'studied'],
#  'P102': ['President of',
#   'candidate for',
#   'founder of',
#   'in',
#   'is member of',
#   'joined',
#   'member of',
#   'of',
#   'raised money for',
#   'represented',
#   'was member of'],
#  'P103': ['appeared in', 'had', 'is', 'is in', 'speak', 'was', 'wrote'],
#  'P1037': ['was founded by'],
#  'P1038': ['betraying', 'known as'],
#  'P1040': ['sequel by', 'starring'],
#  'P1049': ['is In'],
#  'P105': ['are', 'be', 'became', 'being', 'being of', 'is', 'was'],
#  'P1050': ['battling'],
#  'P1056': ['distributed', 'is edition of'],
#  'P106': ['became',
#   'called',
#   'debuted episode as',
#   'graduating as',
#   'has also remained as',
#   'has remained as',
#   'is',
#   'is active as',
#   'is considered',
#   'is daughter of',
#   'is first vintner',
#   'is married to',
#   'is most active as',
#   'is older sister of',
#   'is sister of',
#   'is vintner',
#   'lead',
#   'made contributions As',
#   'of mother is',
#   'therefore is mentioned as',
#   'was',
#   'was admitted as',
#   'was appointed',
#   'was born to',
#   'was commissioned as',
#   'was married to',
#   'was son of',
#   'worked as'],
#  'P1066': ['joined', 'went with'],
#  'P108': ['Director-General of',
#   'Emeritus at',
#   'Professor at',
#   'also worked for',
#   'attended',
#   'enrolled at',
#   'entered',
#   'founder of',
#   'graduated from',
#   'is professor at',
#   'joined',
#   'joined Department at',
#   'leaving',
#   'left',
#   'member of',
#   'obtained',
#   'professor at',
#   'received doctorate from',
#   'returned to',
#   'studied at',
#   'studied economics at',
#   'taught',
#   'taught economics at',
#   'was professor at',
#   'worked at',
#   'worked for'],
#  'P112': ["'s founder is",
#   '2011 by',
#   'Founded by',
#   'India for',
#   'being descended from',
#   'coined by',
#   'consists of',
#   'created by',
#   'edited by',
#   'established U.S. National Video Game Team with',
#   'formed',
#   'formed by',
#   'founded',
#   'founded by',
#   'from',
#   'has',
#   'incorporated by',
#   'is American technology by',
#   'is also member of',
#   'is closely tied to',
#   'is creation of',
#   'is founding member of',
#   'is member of',
#   'is named',
#   'is owned by',
#   'is run by',
#   'is technology by',
#   'is tied to',
#   'is with',
#   'originated with',
#   'owned subsidiary of',
#   'part of',
#   'played part by',
#   'profited under',
#   'starring',
#   'subsidiary of',
#   'was co-founded by',
#   'was created According to',
#   'was created by',
#   'was developed by',
#   'was established by',
#   'was first published by',
#   'was formed by',
#   'was formed in',
#   'was founded by',
#   'was headed by',
#   'was launched by',
#   'was launched with',
#   'was owned by',
#   'was published by',
#   'was started by',
#   'was venture between',
#   'wholly owned subsidiary of',
#   'will serve destinations as'],
#  'P113': ['is headquartered at', 'moved from'],
#  'P115': ['moving to'],
#  'P118': ['are',
#   'competes in',
#   'entered',
#   'is in',
#   'joined',
#   'member of',
#   'moved to',
#   'play in',
#   'played',
#   'plays in',
#   'returned to',
#   'was promoted to',
#   'were',
#   'won'],
#  'P119': ['also banned alcohol in',
#   'also banned coffee in',
#   'also banned tobacco in',
#   'banned alcohol in',
#   'banned coffee in',
#   'banned tobacco in',
#   'died',
#   'died at',
#   'died in',
#   'is buried at',
#   'is buried in',
#   'is interred there in',
#   'joined Skynyrd along in',
#   'joined Skynyrd in',
#   'lived in',
#   'moved to',
#   'returned to',
#   'was born at',
#   'was born in',
#   'was born near',
#   'was born probably in',
#   'was buried',
#   'was buried at',
#   'was buried in',
#   'was interned at',
#   'was interred in'],
#  'P1196': ['After',
#   'died',
#   'died due to',
#   'died from',
#   'died in',
#   'died of',
#   'has'],
#  'P121': ["'s Cardinal is", 'by', 'uses', 'uses daily'],
#  'P122': ['became', 'is'],
#  'P123': ['became at',
#   'being developed by',
#   'developed by',
#   'effort between',
#   'form for',
#   'is',
#   'is game from',
#   'is owned by',
#   'is part of',
#   'is published by',
#   'is video game from',
#   'produced by',
#   'published by',
#   'released by',
#   'released in',
#   'sponsored by',
#   'was announced by',
#   'was co-developed by',
#   'was created by',
#   'was developed by',
#   'was first published by',
#   'was founded by',
#   'was originally released by',
#   'was ported by',
#   'was published by',
#   'was released by',
#   'was released for',
#   'was released in',
#   'was released through'],
#  'P126': ['is in',
#   'is maintained by',
#   'is managed by',
#   'is operated by',
#   'is owned by',
#   'was acquired by',
#   'was first released by',
#   'was given to',
#   'was purchased by',
#   'was released by'],
#  'P1268': ['are athletic teams for',
#   'are athletic teams of',
#   'are intercollegiate athletic teams of',
#   'are intercollegiate teams of',
#   'are teams for',
#   'are teams of',
#   'represent',
#   'represents'],
#  'P1269': ['is', 'is In', 'is in', 'is part of', 'represent', 'writing'],
#  'P127': ["'s company is",
#   "'s parent is",
#   'A70 in',
#   'Home of',
#   'India for',
#   'President of',
#   'acquired by',
#   'are part of',
#   "arm 's",
#   'be acquired by',
#   'became',
#   'connects',
#   'division of',
#   'do business as',
#   'doing business as',
#   'donated to',
#   'folded into',
#   'form',
#   'fully owned subsidiary of',
#   'government of',
#   'had owned',
#   'has',
#   'incorporated by',
#   'is',
#   'is Baroque villa located near',
#   'is Baroque villa near',
#   'is building of',
#   'is channel of',
#   'is controlled by',
#   'is currently owned by',
#   'is federal highway in',
#   'is in',
#   'is located in',
#   'is maintained by',
#   'is member of',
#   'is now part of',
#   'is now subsidiary of',
#   'is operated by',
#   'is owned by',
#   'is owned subsidiary of',
#   'is part of',
#   'is run by',
#   'is subsidiary of',
#   'is third channel of',
#   'is villa located near',
#   'is villa near',
#   'is wholly owned by',
#   'is wholly owned subsidiary of',
#   'member of',
#   'newbuilding for',
#   'non-voting stake in',
#   'owned by',
#   'owned subsidiary of',
#   'part of',
#   'provides',
#   'provides services In addition to',
#   'second newbuilding for',
#   'stake in',
#   'starring',
#   'studio within',
#   'subsidiary of',
#   'take over routes from',
#   'team at',
#   'used by',
#   'was absorbed into',
#   'was acquired by',
#   'was co-founded by',
#   'was created by',
#   'was designed by',
#   'was established by',
#   'was founded by',
#   'was merged into',
#   'was originally acquired by',
#   'was published by',
#   'was purchased by',
#   'was venture between',
#   'were closed by',
#   'were closed down by',
#   'wholly owned subsidiary of'],
#  'P1303': ['has',
#   'is professor of',
#   'play',
#   'played',
#   'playing',
#   'plays',
#   'studied',
#   'studying',
#   'was professor of'],
#  'P131': ['Based in',
#   'Headquartered in',
#   'Located in',
#   'Republic of',
#   'Soon crossing into',
#   'Thus belongs to',
#   'University of',
#   'area in',
#   'area of',
#   'arena in',
#   'autonomous community located of',
#   'autonomous community of',
#   'based in',
#   'belongs to',
#   'between reservoir is',
#   'both in',
#   'built in',
#   "business 's",
#   'capital of',
#   'center of',
#   'centre of',
#   'church in',
#   'city in',
#   'city of',
#   'community located of',
#   'community of',
#   'connected municipalities to',
#   'connected to',
#   'connecting',
#   'connects above',
#   'contiguous area in',
#   'county in',
#   'crosses',
#   'crossing into',
#   'district of',
#   'first city in',
#   'has Acton MA in',
#   'has Tokyo in',
#   'has offices in',
#   'headquarters in',
#   'house in',
#   'in river is',
#   'in village is',
#   'inaugurated in',
#   'is German federal highway in',
#   'is German highway in',
#   'is In',
#   'is administrative centre of',
#   'is also beer-producing region of',
#   'is also city in',
#   'is also far city in',
#   'is also far largest city in',
#   'is also largest city in',
#   'is also locality in',
#   'is also main beer-producing region of',
#   'is also main region of',
#   'is also region of',
#   'is arena in',
#   'is beer-producing region of',
#   'is broadcast in',
#   'is building of',
#   'is capital of',
#   'is capital south of',
#   'is center of',
#   'is central location in',
#   'is centre in',
#   'is centre of',
#   'is city in',
#   'is commune of',
#   'is currently served by',
#   'is division of',
#   'is economic and commercial centre in',
#   'is economic centre in',
#   'is far city in',
#   'is far largest city in',
#   'is federal highway in',
#   'is formation in',
#   'is gateway to',
#   'is geological formation in',
#   'is government-funded higher institution in',
#   'is government-funded higher learning institution in',
#   'is government-funded institution in',
#   'is government-funded learning institution in',
#   'is higher institution in',
#   'is higher learning institution in',
#   'is highest point in',
#   'is highway in',
#   'is historic building of',
#   'is in',
#   'is independent private university in',
#   'is independent university in',
#   'is insular area of',
#   'is internationally recognized symbol of',
#   'is largest city in',
#   'is learning institution in',
#   'is library in',
#   'is locality in',
#   'is located in',
#   'is location in',
#   'is main beer-producing region of',
#   'is main region of',
#   'is modest tributary in',
#   'is most populated commune of',
#   'is most populous city in',
#   'is most populous province ahead of',
#   'is most populous province just ahead of',
#   'is most populous province just slightly ahead of',
#   'is most populous province of',
#   'is most populous province slightly ahead of',
#   'is mountain in',
#   'is municipality in',
#   'is oldest school in',
#   'is owned by',
#   'is palace in',
#   'is palace located in',
#   'is part of',
#   'is point in',
#   'is political center of',
#   'is populated commune of',
#   'is populous city in',
#   'is populous province ahead of',
#   'is populous province just ahead of',
#   'is populous province just slightly ahead of',
#   'is populous province of',
#   'is populous province slightly ahead of',
#   'is private university in',
#   'is province ahead of',
#   'is province just ahead of',
#   'is province just slightly ahead of',
#   'is province of',
#   'is province slightly ahead of',
#   'is recognized symbol of',
#   'is region of',
#   'is right tributary in',
#   'is river in',
#   'is school in',
#   'is seat of',
#   'is second most populous province ahead of',
#   'is second most populous province just ahead of',
#   'is second most populous province just slightly ahead of',
#   'is second most populous province of',
#   'is second most populous province slightly ahead of',
#   'is second populous province ahead of',
#   'is second populous province just ahead of',
#   'is second populous province just slightly ahead of',
#   'is second populous province of',
#   'is second populous province slightly ahead of',
#   'is second province ahead of',
#   'is second province just ahead of',
#   'is second province just slightly ahead of',
#   'is second province of',
#   'is second province slightly ahead of',
#   'is served by',
#   'is situated from',
#   'is situated in',
#   'is situated within',
#   'is southernmost part of',
#   'is state in',
#   'is town in',
#   'is tributary in',
#   'is university in',
#   'is village in',
#   'is voivodeship in',
#   'join',
#   'joined',
#   'largest area in',
#   'largest contiguous area in',
#   'lies in',
#   'lies within',
#   'linking Trois-Rivières to',
#   'located in',
#   'municipality in',
#   'of capital is',
#   'on commune is',
#   'part of',
#   'peak in',
#   'protect',
#   'préfecture of',
#   'published in',
#   'railway from',
#   'range in',
#   'region of',
#   'representing',
#   'run across',
#   'running app camps in',
#   'separating',
#   'serves',
#   'simulcasting',
#   'situated in',
#   'southernmost autonomous community located of',
#   'southernmost autonomous community of',
#   'southernmost community located of',
#   'southernmost community of',
#   'state of',
#   'took place in',
#   'villages within',
#   'was County of',
#   'was capital for',
#   'was capital of',
#   'was established at',
#   'was formed in',
#   'was separated from',
#   'was temporary capital for',
#   'zone of'],
#  'P1336': ['capital within', 'invaded', 'is with', 'part of'],
#  'P1344': ['competing in',
#   'in',
#   'lost in',
#   'represent United Kingdom in',
#   'represented India at',
#   'was member of',
#   'was part at'],
#  'P1346': ['is in', 'is with', 'was won by'],
#  'P135': ['announced',
#   'called',
#   'example of',
#   'founder of',
#   'painters of',
#   'used',
#   'was',
#   'was involved with',
#   'was member of'],
#  'P136': ['Variously described as',
#   'appears in',
#   'are',
#   'author of',
#   'be',
#   'became',
#   'has',
#   'is',
#   'is regarded as',
#   'known as',
#   'was',
#   'was adapted into',
#   'was attempt at',
#   'was early attempt at',
#   'was loosely adapted into',
#   'were'],
#  'P1365': ['is bordered by',
#   'meets',
#   'of Republic is',
#   'part of',
#   'replaced',
#   'was known as'],
#  'P1366': ['be acquired by',
#   'create',
#   'form',
#   'forming',
#   'is in',
#   'is incarnation of',
#   'is part of',
#   'is served by',
#   'joined',
#   'merged with',
#   'part of',
#   'was acquired by',
#   'was divided into',
#   'was incorporated into',
#   'was merged into',
#   'was renamed',
#   'was replaced by',
#   'was split',
#   'was succeeded by',
#   'was taken over by'],
#  'P137': ['Built by',
#   'Home of',
#   'built for',
#   'created by',
#   'developed by',
#   'is',
#   'is division of',
#   'is in',
#   'is maintained by',
#   'is operated by',
#   'is owned by',
#   'is with',
#   'left',
#   'operated by',
#   'owned by',
#   'served',
#   'sponsored by',
#   'used by',
#   'was',
#   'was British Captain-class frigate of',
#   'was British frigate of',
#   'was Captain-class frigate of',
#   'was built for',
#   'was developed by',
#   'was frigate of',
#   'was schooner in'],
#  'P1376': ['administrative center located of',
#   'administrative center of',
#   'are part of',
#   'area in',
#   'be capital of',
#   'capital of',
#   'center located of',
#   'center of',
#   'city in',
#   'city of',
#   'first city in',
#   'first industrial city in',
#   'first major city in',
#   'first major industrial city in',
#   'in river is',
#   'is administrative centre of',
#   'is also city in',
#   'is also far city in',
#   'is also far largest city in',
#   'is also largest city in',
#   'is capital of',
#   'is center of',
#   'is central location in',
#   'is centre for',
#   'is centre of',
#   'is city in',
#   'is city of',
#   'is commercial city in',
#   'is commune of',
#   'is cultural and financial center of',
#   'is cultural center of',
#   'is cultural political and center of',
#   'is cultural political and financial center of',
#   'is far city in',
#   'is far largest city in',
#   'is hub of',
#   'is in',
#   'is largest city in',
#   'is largest commercial city in',
#   'is located in',
#   'is located within',
#   'is location in',
#   'is most populated commune of',
#   'is most populous city in',
#   'is part of',
#   'is political and cultural center of',
#   'is political center of',
#   'is political economic and center of',
#   'is political economic and cultural center of',
#   'is political economic educational and center of',
#   'is political economic educational and cultural center of',
#   'is political educational and center of',
#   'is political educational and cultural center of',
#   'is populated commune of',
#   'is populous city in',
#   'is primate city of',
#   'is seat of',
#   'is situated in',
#   'is situated within',
#   'legislative and democratic capital of',
#   'lies in',
#   'near Davis is',
#   'préfecture of',
#   'region of',
#   'renamed',
#   'representing',
#   'was capital for',
#   'was capital of',
#   'was center during',
#   'was chief city of',
#   'was largest and richest center during',
#   'was largest and richest urban center during',
#   'was largest center during',
#   'was largest urban center during',
#   'was temporary capital for',
#   'was urban center during'],
#  'P138': ['built by',
#   'capital of',
#   'designed by',
#   'developed by',
#   'form',
#   'grandson of',
#   'has',
#   'headland to',
#   'is',
#   'is associated with',
#   'is based on',
#   'is connected to',
#   'is in',
#   'is named after',
#   'is part of',
#   'is situated on',
#   'is southernmost part of',
#   'long and thin headland to',
#   'long headland to',
#   'named after',
#   'published by',
#   'releases of',
#   'stable releases of',
#   'was developed by',
#   'was discovered by',
#   'was established by',
#   'was founded by',
#   'was named after',
#   'was named for'],
#  'P140': ['Tirthankara of',
#   'adopt',
#   'converted to',
#   'found',
#   'is In',
#   'is known in',
#   'practitioners of',
#   'studied',
#   'teaching',
#   'was',
#   'was member of'],
#  'P1408': ['station in'],
#  'P141': ['is', 'is listed as', 'is species of'],
#  'P1411': ['been nominated for',
#   'received',
#   'was awarded',
#   'was nominated for',
#   'won'],
#  'P1412': ['Mats Huldén Kalevala into',
#   'appeared in',
#   'becoming',
#   'comes from',
#   'debuted in',
#   'had',
#   'is',
#   'is in',
#   'is professor of',
#   'learned',
#   'published in',
#   'was',
#   'were',
#   'wrote'],
#  'P1416': ['formed by', 'is member of'],
#  'P1420': ['was described as', 'was first described as'],
#  'P1431': ['created by', 'form for'],
#  'P1433': ['based in'],
#  'P1435': ['became', 'is', 'is listed as', 'was declared', 'was designated'],
#  'P144': ['based on',
#   'be',
#   'is',
#   'is In',
#   'is based on',
#   'is closely related to',
#   'is extension to',
#   'is most closely related to',
#   'is related to',
#   'is version of',
#   'platform based on',
#   'received',
#   'releases of',
#   'stable releases of',
#   'using',
#   'version of',
#   'was based on',
#   'was derived from'],
#  'P1441': ['Thus is commonly referred in',
#   'Thus is referred in',
#   'appeared in',
#   'appears In',
#   'appears in',
#   'asks',
#   'awaken In',
#   'being axed from',
#   'character in',
#   'character of',
#   'events of',
#   'first appeared in',
#   'first appears in',
#   'fosters',
#   'got involved As',
#   'has',
#   'has appeared in',
#   'immediately got involved As',
#   'is In',
#   'is character in',
#   'is commonly referred in',
#   'is described In',
#   'is father In',
#   'is featured to',
#   'is fictionalised in',
#   'is henchman of',
#   'is in',
#   'is introduced in',
#   'is main character in',
#   'is main villain of',
#   'is playable character in',
#   'is portrayed In',
#   'is referred in',
#   'is seen at_time',
#   'is son In',
#   'is still seen at_time',
#   'is villain of',
#   'joined',
#   'joining',
#   'marry Daenerys Targaryen In',
#   'marrying',
#   'mentor of',
#   'needed In',
#   'offered at_time',
#   'previously appeared in',
#   'returned to',
#   'save',
#   'was discovered According to',
#   'was introduced in',
#   'wears outfit In',
#   'witnessed destruction According to',
#   'writes book Following'],
#  'P1454': ['are',
#   'be',
#   'became',
#   'ceased',
#   'converted to',
#   'is',
#   'is considered',
#   'is subsidiary of',
#   'was',
#   'was acquired by',
#   'was declared'],
#  'P149': ['combined',
#   'example of',
#   'included',
#   'is',
#   'is considered',
#   'is example of'],
#  'P150': ["'s capital is",
#   "'s city is",
#   "'s panhandle is",
#   'History of',
#   'Italy in',
#   'born in',
#   'developed',
#   'dye industry in',
#   'has',
#   'in',
#   'include',
#   'included',
#   'is headquartered in',
#   'is in',
#   'km from',
#   'of',
#   'of Federation is',
#   'to'],
#  'P1532': ['University of',
#   'brought',
#   'currently resides in',
#   'first played cricket for',
#   'is in',
#   'is national team of',
#   'is team of',
#   'lives in',
#   'moved to',
#   'part of',
#   'played cricket for',
#   'played for',
#   'represent',
#   'represented',
#   'represented simultaneously',
#   'representing',
#   'represents',
#   'resides in',
#   'starred for',
#   'team of',
#   'was born at',
#   'was born in'],
#  'P155': ["'s album is",
#   'acquired',
#   'be refined version of',
#   'competed in',
#   "console 's",
#   'grew out of',
#   'is after',
#   'is successor to',
#   'part of',
#   'recorded',
#   'released',
#   'replacing',
#   'studio within',
#   'was development of',
#   'was founded at',
#   'was preceded by',
#   'was superseded by'],
#  'P1557': ['is misleadingly called',
#   'is sometimes called',
#   'is sometimes misleadingly called'],
#  'P156': ["'s album is",
#   "'s successor is",
#   'Mario for',
#   'also appeared alongside',
#   'followed by',
#   'form',
#   'is',
#   'is followed by',
#   'is in',
#   'merged with',
#   'produced by',
#   'released',
#   'succeeded by',
#   'supported',
#   'was bought by',
#   'was merged into',
#   'was purchased by',
#   'was re-released along with',
#   'was renamed to',
#   'was replaced by',
#   'was shot in',
#   'was succeeded by'],
#  'P157': ['replacing'],
#  'P1589': ['is bordered by', 'is in', 'is island in', 'is largest island in'],
#  'P159': ["'s Marche is",
#   'Based in',
#   'Europe near',
#   'Founded in',
#   'Headquartered in',
#   'Located in',
#   'University of',
#   'Wadala in',
#   'Wing at',
#   'also situated in',
#   'are based in',
#   'arrived in',
#   'assigned to',
#   'based in',
#   'began in',
#   'being based in',
#   'company from',
#   'connecting',
#   'develop disc stack machines at',
#   'established in',
#   'formed in',
#   'founded in',
#   'had',
#   'had chosen',
#   'has Acton MA in',
#   'has Tokyo in',
#   'has offices in',
#   'has package in',
#   'has power generation equipment in',
#   'has staged conferences in',
#   'has trialled DVB in',
#   'have united in',
#   'headquartered in',
#   'held annually in',
#   'held in',
#   'inaugurated in',
#   'into',
#   'is',
#   'is also based in',
#   'is also operating in',
#   'is based at',
#   'is based in',
#   'is government-funded higher institution in',
#   'is government-funded higher learning institution in',
#   'is government-funded institution in',
#   'is government-funded learning institution in',
#   'is headquartered at',
#   'is headquartered in',
#   'is higher institution in',
#   'is higher learning institution in',
#   'is in',
#   'is independent private university in',
#   'is independent university in',
#   'is learning institution in',
#   'is library in',
#   'is located in',
#   'is operating in',
#   'is private university in',
#   'is situated in',
#   'is university in',
#   'lines for',
#   'located in',
#   'moved in',
#   'moved to',
#   'moving to',
#   'opened drapery shop in',
#   'opened in',
#   'opened office in',
#   'operates hospitals in',
#   'operating to',
#   'outsourced operations to',
#   'played in',
#   'produced in',
#   'provides',
#   'provides electricity in',
#   'provides gas in',
#   'provides pharmacy benefit management services in',
#   'published in',
#   'relocated to',
#   'situated in',
#   'space in',
#   'started collaboration from',
#   'started in',
#   'still headquartered in',
#   'such as Ltd is',
#   'university in',
#   'use',
#   'vacated space in',
#   'was based in',
#   'was created in',
#   'was established in',
#   'was first published in',
#   'was formed in',
#   'was founded at',
#   'was founded by',
#   'was founded in',
#   'was headquartered in',
#   'was home-based at',
#   'was housed in',
#   'was launched in',
#   'was launched publicly in',
#   'was moved to',
#   'was officially presented in',
#   'was presented in',
#   'was previously home-based at',
#   'was published in',
#   'was purchased by',
#   'will allocate year In',
#   'works in'],
#  'P16': ['became', 'is', 'was designated'],
#  'P161': ['directed by',
#   'features',
#   'featuring',
#   'follows',
#   'is play by',
#   'is with',
#   'of',
#   'offers',
#   'produced by',
#   'reunites',
#   'starred',
#   'starring',
#   'starring Anita Morris with',
#   'starring Bette Midler with',
#   'starring Danny DeVito with',
#   'starring Helen Slater with',
#   'starring Judge Reinhold with',
#   'was co-written by',
#   'was written by'],
#  'P162': ['Produced by',
#   'created by',
#   'directed by',
#   'follows',
#   'form for',
#   'giving',
#   'produced by',
#   'released by',
#   'was produced by',
#   'was written by'],
#  'P166': ['earned',
#   'followed by',
#   'received',
#   'was',
#   'was also decorated in addition to',
#   'was awarded',
#   'was decorated in addition to',
#   'was inducted into',
#   'won'],
#  'P169': ['Founded by',
#   'created by',
#   'has',
#   'is American technology by',
#   'is technology by',
#   'was developed by',
#   'was founded by',
#   'was launched by'],
#  'P17': ['A70 in',
#   'Aiguebelette in',
#   'Argen is river in',
#   'Chungju in',
#   'Founded in',
#   'Galway in',
#   'Garden of',
#   'Gerais in',
#   'Haute-Normandie in',
#   'Headquartered in',
#   'Java in',
#   'Jersey in',
#   'Located in',
#   'Missouri in',
#   'Pukhtunkhwa in',
#   'Raseborg in',
#   'Region in',
#   'Region of',
#   'Republic of',
#   'accused US officials in',
#   'allied organisations in',
#   'ancient route from',
#   'ancient route to',
#   'ancient tea-caravan route from',
#   'ancient tea-caravan route to',
#   'are part in',
#   'are part located in',
#   'are rugged subrange of',
#   'are small rugged subrange of',
#   'are small subrange of',
#   'are subrange of',
#   'area in',
#   'army of',
#   'autonomous community located of',
#   'autonomous community of',
#   'bank in',
#   'based in',
#   'be capital of',
#   'began in',
#   'begins in',
#   "branch 's",
#   'built in',
#   "business 's",
#   'came in',
#   'camp in',
#   'capital of',
#   'capital within',
#   'centers in',
#   'centre of',
#   'cinema in',
#   'city in',
#   'city of',
#   'college in',
#   'commercial electricity in',
#   'community located of',
#   'community of',
#   'competition in',
#   'considered as',
#   'county in',
#   'electricity in',
#   'emerges in',
#   'employer in',
#   'established in',
#   'ever landed in',
#   'first city in',
#   'first industrial city in',
#   'first major city in',
#   'first major industrial city in',
#   'flight of',
#   'flows through',
#   'follows Aran Valley into',
#   'follows Aran Valley northwards into',
#   'founded in',
#   'has Acton MA in',
#   'has Tokyo in',
#   'has offices in',
#   'has stores In',
#   'headquartered in',
#   'held annually in',
#   'held in',
#   'in Main is',
#   'in Province is',
#   'in Sendai is',
#   'in county is',
#   'in river is',
#   'in temple is',
#   'in town is',
#   'in village is',
#   'inaugurated in',
#   'introduced by',
#   'is 23rd borough of',
#   'is 26th city in',
#   'is 26th largest city in',
#   'is Baroque villa located near',
#   'is Baroque villa near',
#   'is In',
#   'is Japanese garden in',
#   'is airport in',
#   'is airport on',
#   'is also beer-producing region of',
#   'is also main beer-producing region of',
#   'is also main region of',
#   'is also region of',
#   'is area in',
#   'is beer-producing region of',
#   'is best known in',
#   'is body in',
#   'is borough of',
#   'is building in',
#   'is building of',
#   'is business in',
#   'is capital of',
#   'is center of',
#   'is centre of',
#   'is city in',
#   'is city of',
#   'is commercial city in',
#   'is commune in',
#   'is crater in',
#   'is cultural and financial center of',
#   'is cultural center of',
#   'is cultural political and center of',
#   'is cultural political and financial center of',
#   'is currency of',
#   'is currency prior of',
#   'is district in',
#   'is division of',
#   'is dormant volcano in',
#   'is economic center of',
#   'is far city in',
#   'is far largest city in',
#   'is federal highway in',
#   'is found in',
#   'is fourth-largest city in',
#   'is garden in',
#   'is gateway to',
#   'is generally known throughout',
#   'is glacier in',
#   'is governing body in',
#   'is headquartered in',
#   'is highest mountain in',
#   'is highest mountain of',
#   'is historic building of',
#   'is historic house in',
#   'is historic inn in',
#   'is historic residence near',
#   'is historical structure in',
#   'is historically informal area in',
#   'is historically informal urban area in',
#   'is home to',
#   'is house in',
#   'is however name in',
#   'is however well-known name in',
#   'is in',
#   'is informal area in',
#   'is informal urban area in',
#   'is inn in',
#   'is insular area of',
#   'is international airport in',
#   'is international airport of',
#   'is island in',
#   'is known in',
#   'is largest city in',
#   'is largest commercial city in',
#   'is largest glacier in',
#   'is largest island in',
#   'is library in',
#   'is lighthouse in',
#   'is lighthouse offshore in',
#   'is located at',
#   'is located in',
#   'is long however in',
#   'is long in',
#   'is low-income area in',
#   'is low-income historically informal area in',
#   'is low-income historically informal urban area in',
#   'is low-income informal area in',
#   'is low-income informal urban area in',
#   'is low-income urban area in',
#   'is main airport of',
#   'is main beer-producing region of',
#   'is main international airport of',
#   'is main region of',
#   'is major airport in',
#   'is major international airport in',
#   'is modest tributary in',
#   'is most populous city in',
#   'is most populous province ahead of',
#   'is most populous province just ahead of',
#   'is most populous province just slightly ahead of',
#   'is most populous province of',
#   'is most populous province slightly ahead of',
#   'is mountain in',
#   'is mountain of',
#   'is municipality in',
#   'is national team of',
#   'is newspaper in',
#   'is oldest Japanese garden in',
#   'is oldest garden in',
#   'is oldest public Japanese garden in',
#   'is oldest public garden in',
#   'is only airport on',
#   'is owned business in',
#   'is palace in',
#   'is palace located in',
#   'is palazzo in',
#   'is part of',
#   'is peak in',
#   'is political center of',
#   'is populous city in',
#   'is populous province ahead of',
#   'is populous province just ahead of',
#   'is populous province just slightly ahead of',
#   'is populous province of',
#   'is populous province slightly ahead of',
#   'is primate city of',
#   'is privately owned business in',
#   'is province ahead of',
#   'is province just ahead of',
#   'is province just slightly ahead of',
#   'is province of',
#   'is province slightly ahead of',
#   'is public Japanese garden in',
#   'is public garden in',
#   'is region of',
#   'is residence near',
#   'is right tributary in',
#   'is river in',
#   'is river of',
#   'is second most populous province ahead of',
#   'is second most populous province just ahead of',
#   'is second most populous province just slightly ahead of',
#   'is second most populous province of',
#   'is second most populous province slightly ahead of',
#   'is second populous province ahead of',
#   'is second populous province just ahead of',
#   'is second populous province just slightly ahead of',
#   'is second populous province of',
#   'is second populous province slightly ahead of',
#   'is second province ahead of',
#   'is second province just ahead of',
#   'is second province just slightly ahead of',
#   'is second province of',
#   'is second province slightly ahead of',
#   'is situated in',
#   'is situated on',
#   'is situated within',
#   'is southernmost part of',
#   'is state in',
#   'is statutory division of',
#   'is still generally known throughout',
#   'is still known throughout',
#   'is structure in',
#   'is team of',
#   'is territory of',
#   'is third city in',
#   'is third highest mountain in',
#   'is third largest city in',
#   'is third mountain in',
#   'is third-largest city in',
#   'is town in',
#   'is tributary in',
#   'is unincorporated and unorganized territory of',
#   'is unincorporated territory of',
#   'is urban area in',
#   'is villa located near',
#   'is villa near',
#   'is village in',
#   'is voivodeship in',
#   'is volcanic crater in',
#   'is volcano in',
#   'is waterfall in',
#   'is well-known name in',
#   'joined',
#   'kingdoms in',
#   'known in',
#   'lake in',
#   'largest employer in',
#   'largest private employer in',
#   'largest retailer in',
#   'lies in',
#   'located in',
#   'long river in',
#   'most populous city of',
#   'most selective college in',
#   'near Baden-Württemberg is',
#   'neighbourhood in',
#   'of Parliament is',
#   'of Province is',
#   'of Republic is',
#   'of capital is',
#   'of district is',
#   'of mouth is',
#   'of union is',
#   'on County is',
#   'on airport is',
#   'operator in',
#   'organisation for',
#   "parliament 's",
#   'part of',
#   'party to',
#   'peak of',
#   'played in',
#   'populous city of',
#   'portal in',
#   'premiered in',
#   'private employer in',
#   'published in',
#   'region of',
#   'released soundtrack in',
#   'remain in',
#   'represent',
#   'representing',
#   'represents',
#   'river of',
#   'route from',
#   'route to',
#   'run across',
#   'running app camps in',
#   'school in',
#   'selective college in',
#   'set in',
#   'shipyards in',
#   'southernmost autonomous community located of',
#   'southernmost autonomous community of',
#   'southernmost community located of',
#   'southernmost community of',
#   'started in',
#   'state of',
#   'tea-caravan route from',
#   'tea-caravan route to',
#   'territory of',
#   'third college in',
#   'third employer in',
#   'third largest employer in',
#   'third largest private employer in',
#   'third most selective college in',
#   'third private employer in',
#   'third selective college in',
#   'took place in',
#   'town in',
#   'was County of',
#   'was biggest stadium in',
#   'was built in',
#   'was capital of',
#   'was center during',
#   'was city in',
#   'was dam in',
#   'was earthen dam in',
#   'was established in',
#   'was experimental pay-per-view telecast in',
#   'was experimental telecast in',
#   'was formed in',
#   'was founded by',
#   'was founded in',
#   'was held in',
#   'was largest and richest center during',
#   'was largest and richest urban center during',
#   'was largest center during',
#   'was largest urban center during',
#   'was officially presented in',
#   'was pay-per-view telecast in',
#   'was presented in',
#   'was ranked in',
#   'was stadium in',
#   'was telecast in',
#   'was third largest retailer in',
#   'was third retailer in',
#   'was urban center during',
#   'went in',
#   'westernmost point of',
#   'wettest city in'],
#  'P170': ['created by',
#   'developed by',
#   'devised by',
#   'directed by',
#   'improved by',
#   'is hosted by',
#   'made by',
#   'originated with',
#   'published by',
#   'was conceived by',
#   'was created by',
#   'was designed by',
#   'was developed by',
#   'was first portrayed by',
#   'was founded by',
#   'was launched by',
#   'was marketed by',
#   'was portrayed by',
#   'was written by'],
#  'P171': ['belongs to',
#   'is member of',
#   'was assigned to',
#   'was most widespread subspecies of',
#   'was subspecies of',
#   'was widespread subspecies of'],
#  'P1716': ['built by', 'launched by', 'produced by'],
#  'P172': ['King of',
#   'fell with',
#   'is derived from',
#   'joined',
#   'leader of',
#   'was',
#   'was born to',
#   'weroansqua of'],
#  'P175': ["'s album is",
#   'established',
#   'features',
#   'giving',
#   'has',
#   'is album by',
#   'is played by',
#   'is portrayed by',
#   'is song by',
#   'is third album by',
#   'is voiced by',
#   'offshoot of',
#   'performed by',
#   'released',
#   'voiced by',
#   'was briefly played by',
#   'was first portrayed by',
#   'was played by',
#   'was portrayed Jessica Alba by',
#   'was portrayed Kate Mara by',
#   'was portrayed by',
#   'was produced by',
#   'was produced however by',
#   'was written by',
#   'won',
#   'written by'],
#  'P176': ['Built by',
#   'being developed by',
#   'built at',
#   'built by',
#   'designed by',
#   'developed by',
#   'introduced by',
#   'is',
#   'is built by',
#   'is owned by',
#   'launched by',
#   'made by',
#   'manufactured by',
#   'produced by',
#   'released by',
#   'was announced by',
#   'was built as',
#   'was built at',
#   'was built by',
#   'was constructed by',
#   'was developed by',
#   'was jointly developed by',
#   'was laid down by',
#   'was ordered from',
#   'was sold to'],
#  'P177': ['bridge over', 'crosses', 'spans of'],
#  'P178': ['Developed by',
#   "OS 's",
#   'be created with',
#   'became at',
#   'being developed by',
#   'created by',
#   'designed by',
#   'developed by',
#   'division of',
#   'effort between',
#   'game by',
#   'introduced by',
#   'is',
#   'is currently developed by',
#   'is developed by',
#   'is maintained by',
#   'is named after',
#   'is owned by',
#   'is part of',
#   'is supported by',
#   'is trademark of',
#   'manufactured by',
#   'official standard of',
#   'produced by',
#   'published by',
#   'released by',
#   'serves',
#   'was acquired by',
#   'was announced by',
#   'was built by',
#   'was commercial success According to',
#   'was created by',
#   'was designed by',
#   'was developed at',
#   'was developed by',
#   'was developed for',
#   'was first implemented by',
#   'was founded by',
#   'was implemented by',
#   'was important milestone for',
#   'was initially developed for',
#   'was introduced by',
#   'was maintained by',
#   'was marketed by',
#   'was milestone for',
#   'was originally developed by',
#   'was originally released by',
#   'was originally written by',
#   'was owned by',
#   'was ported by',
#   'was primarily used within',
#   'was published by',
#   'was released by',
#   'was success According to',
#   'was used within',
#   'was written by',
#   'written by'],
#  'P179': ['is',
#   'is episode of',
#   'part of',
#   'return to',
#   'was',
#   'was released on',
#   'was written by',
#   'won'],
#  'P180': ['is divided In', 'is with', 'of', 'was created as'],
#  'P1830': ['by', 'moved from', 'non-voting stake in', 'stake in'],
#  'P186': ['consist of', 'is in'],
#  'P1876': ['fourth mission for', 'mission for'],
#  'P1877': ['created by'],
#  'P1889': ["' competition is", "'s company is", 'is', 'is named', 'refers to'],
#  'P19': ['1435 in',
#   'Born had name in',
#   'Born in',
#   'Born on',
#   'December in',
#   'July in',
#   'Lord of',
#   'May in',
#   'President of',
#   'Returning to',
#   'also banned alcohol in',
#   'also banned coffee in',
#   'also banned tobacco in',
#   'am in',
#   'appeared in',
#   'banned alcohol in',
#   'banned coffee in',
#   'banned tobacco in',
#   'been born in',
#   'began in',
#   'black mayor of',
#   'born in',
#   'brought family to',
#   'came from',
#   'debuted in',
#   'did from',
#   'died at',
#   'died in',
#   'died later in',
#   'educated in',
#   'elected mayor of',
#   'first black mayor of',
#   'first mayor of',
#   'geologist Shantabai Metre at',
#   'geologist Wamanrao Bapuji Metre at',
#   'graduated in',
#   'grew up in',
#   'grew up on',
#   'guitarist for',
#   'had name in',
#   'is Japanese actress from',
#   'is actress from',
#   'is buried in',
#   'is celebrated in',
#   'is from',
#   'is in',
#   'is interred at',
#   'just elected mayor of',
#   'later riksjarl of',
#   'lawyer from',
#   'lead',
#   'left',
#   'lived in',
#   'lives in',
#   'mayor of',
#   'moved in',
#   'moved to',
#   'nurseryman in',
#   'opened Challinor Sports at',
#   'opened office in',
#   'performed in',
#   'played club football in',
#   'produces in',
#   'raised in',
#   'received B.A. in',
#   'regularly produces in',
#   'represent',
#   'resides in',
#   'return safely to',
#   'return to',
#   'returned to',
#   'returning to',
#   'riksjarl of',
#   'settled back in',
#   'settled in',
#   'studied music in',
#   'studied painting in',
#   'took in',
#   'travelled around',
#   'was because suspected in',
#   'was born Republic in',
#   'was born Zhu Chang in',
#   'was born at',
#   'was born daughter in',
#   'was born grandson in',
#   'was born in',
#   'was born near',
#   'was born on',
#   'was born probably in',
#   'was born son in',
#   'was born south in',
#   'was buried in',
#   'was collaborator in',
#   'was interred in',
#   'was main collaborator in',
#   'was pastor from',
#   'was probably born in',
#   'was suspected in',
#   'would remain in',
#   'writer from'],
#  'P197': ['is part of', 'opened near'],
#  'P20': ['Born had name in',
#   'Born in',
#   'Brought up in',
#   'Brought up largely in',
#   'July in',
#   'King of',
#   'University of',
#   'abbot in',
#   'also banned alcohol in',
#   'also banned coffee in',
#   'also banned tobacco in',
#   'am in',
#   'appeared in',
#   'banned alcohol in',
#   'banned coffee in',
#   'banned tobacco in',
#   'black mayor of',
#   'born in',
#   'brought family to',
#   'came from',
#   'continue In',
#   'did from',
#   'died',
#   'died Sacha Distel in',
#   'died at',
#   'died in',
#   'died later in',
#   'disappeared from',
#   'first black mayor of',
#   'first mayor of',
#   'graduated in',
#   'grew up in',
#   'had name in',
#   'held position in',
#   'is buried at',
#   'is buried in',
#   'is celebrated in',
#   'is in',
#   'is interred at',
#   'left Sandwich Islands for',
#   'lived in',
#   "mayor 's",
#   'mayor of',
#   'moved in',
#   'moved to',
#   'opened Challinor Sports at',
#   'part of',
#   'probably died in',
#   'pursued writing in',
#   'represented',
#   'resided in',
#   'return safely to',
#   'return to',
#   'returned to',
#   'returning to',
#   'served in',
#   'set in',
#   'set up Fronius International GmbH in',
#   'set up government in',
#   'settled back in',
#   'settled in',
#   'shifted capital to',
#   'south-southeast of',
#   'started workshop in',
#   'studied at',
#   'took in',
#   'traveled to',
#   'visited',
#   'was because suspected in',
#   'was born at',
#   'was born in',
#   'was buried in',
#   'was collaborator in',
#   'was educated at',
#   'was interred in',
#   'was killed in',
#   'was made secretary general in',
#   'was main collaborator in',
#   'was mayor of',
#   'was probably born in',
#   'was resident of',
#   'was sent to',
#   'was suspected in',
#   'was transferred to',
#   'went at',
#   'went down at',
#   'went to'],
#  'P200': ['is man-made reservoir between',
#   'is partially man-made reservoir between',
#   'is reservoir between'],
#  'P201': ['drains via', 'is point of'],
#  'P205': ['Aiguebelette in', 'is in', 'lake in'],
#  'P206': ['Canada on',
#   'Located in',
#   'Located on',
#   'Standing on',
#   'archipelago in',
#   'are archipelago in',
#   'are group in',
#   'are scattered archipelago in',
#   'are widely scattered archipelago in',
#   'borders',
#   'has',
#   'is biggest town at',
#   'is bordered by',
#   'is bounded by',
#   'is group in',
#   'is in',
#   'is island in',
#   'is largest island in',
#   'is located between',
#   'is located in',
#   'is located on',
#   'is on',
#   'is prefecture of',
#   'is situated on',
#   'island in',
#   'lie capital in',
#   'lie in',
#   'lies in',
#   'lies on',
#   'on',
#   'part of',
#   'separates',
#   'to',
#   'tributary of',
#   'west of'],
#  'P2079': ['is'],
#  'P21': ['is'],
#  'P22': ["' father is",
#   "'s father is",
#   'be son of',
#   'be successor to',
#   'child of',
#   'commanded cavalry of',
#   'daughter of',
#   'daughters of',
#   'follows',
#   'grandson of',
#   'had also received letter from',
#   'had become With',
#   'had received letter from',
#   'inherited power from',
#   'instructed by',
#   'is child of',
#   'is daughter of',
#   'is first son of',
#   'is in',
#   'is progeny of',
#   'is second child of',
#   'is son of',
#   'is younger daughter of',
#   'is youngest progeny of',
#   'only child of',
#   'possibly son of',
#   'prayed to',
#   'son of',
#   'thus was again child of',
#   'thus was again youngest child of',
#   'thus was child of',
#   'thus was once again child of',
#   'thus was once again youngest child of',
#   'thus was youngest child of',
#   'was again child of',
#   'was again youngest child of',
#   'was born',
#   'was born to',
#   'was brother of',
#   'was child of',
#   'was daughter of',
#   'was eldest son of',
#   'was known Unlike',
#   'was loved by',
#   'was once again child of',
#   'was once again youngest child of',
#   'was sired by',
#   'was son of',
#   'youngest son of'],
#  'P2341': ['is area in',
#   'is historically informal area in',
#   'is historically informal urban area in',
#   'is informal area in',
#   'is informal urban area in',
#   'is low-income area in',
#   'is low-income historically informal area in',
#   'is low-income historically informal urban area in',
#   'is low-income informal area in',
#   'is low-income informal urban area in',
#   'is low-income urban area in',
#   'is urban area in'],
#  'P2348': ['are', 'emperor of', 'is In'],
#  'P241': ['Division of',
#   'enlisted in',
#   'entered',
#   'formed from',
#   'is American writer of',
#   'is formation of',
#   'is in',
#   'is inactive unit of',
#   'is regiment of',
#   'is unit of',
#   'is writer of',
#   'joined',
#   'joining',
#   'part of',
#   'regiment of',
#   'served in',
#   'was',
#   'was cavalry regiment of',
#   'was formation of',
#   'was infantry regiment of',
#   'was member of',
#   'was recruited by',
#   'was regiment of',
#   'worked with'],
#  'P2416': ['revolutionized'],
#  'P25': ["' mother is",
#   "'s mother is",
#   'is daughter of',
#   'is son of',
#   'son of',
#   'was born to',
#   'was brother of',
#   'was created by',
#   'was daughter of',
#   'was sired out of',
#   'was son by',
#   'was son of',
#   'was youngest son of',
#   'were sons of'],
#  'P2505': ['is covered tunnel on',
#   'is short covered tunnel on',
#   'is short tunnel on',
#   'is tunnel on'],
#  'P2546': ['is in'],
#  'P2563': ['has'],
#  'P26': ["'s tomb is",
#   "'s wife is",
#   'Roberts as',
#   'appeared on',
#   'appeared to',
#   'asked',
#   'asks',
#   'effectively divorced',
#   'fathered Lahamu masc upon',
#   'fathered deities Lahmu upon',
#   'fathered elder deities Lahmu upon',
#   'fell with',
#   'home of',
#   'is consort of',
#   'is with',
#   'join',
#   'later married',
#   'leaving',
#   'left',
#   'loved',
#   'married',
#   'marry',
#   'marrying',
#   'meets',
#   'mother-in-law of',
#   'pick',
#   'recorded',
#   'starring',
#   'surrender',
#   'was briefly married to',
#   'was engaged to',
#   'was married to',
#   'wed',
#   'went with',
#   'wife of',
#   'worked again with'],
#  'P264': ["'s label is",
#   'Reissued by',
#   'Shortly launching',
#   'formed',
#   'formed by',
#   'founded',
#   'founder of',
#   'joined',
#   'left',
#   'officially left',
#   'on',
#   'recording for',
#   'release recordings with',
#   'released by',
#   'released on',
#   'released through',
#   'signed deal with',
#   'signed for',
#   'signed record deal with',
#   'signed to',
#   'signed with',
#   'signing to',
#   'since founded',
#   'to',
#   'was moved to',
#   'was released by',
#   'was released on',
#   'was released through',
#   'was signed to',
#   'were signed by'],
#  'P2650': ['has'],
#  'P2670': ['of'],
#  'P27': ['Born in',
#   'Emperor of',
#   'Fathers of',
#   'Gouki in',
#   'Helen of',
#   'King of',
#   'President of',
#   'Prior served for',
#   'Returning to',
#   'Shah of',
#   'University of',
#   'be First Lady of',
#   'be Lady of',
#   'be inaugural First Lady of',
#   'be inaugural Lady of',
#   'began in',
#   'brought',
#   'came from',
#   'debuted in',
#   'died in',
#   'established',
#   'finally immigrating to',
#   'founder of',
#   'generally supervised',
#   'grew up in',
#   'grew up on',
#   'immigrated to',
#   'is cultural icon in',
#   'is dual citizen of',
#   'is fairly well known in',
#   'is icon in',
#   'is in',
#   'is interred in',
#   'is interred there in',
#   'is known in',
#   'is member of',
#   'is well known in',
#   'joined',
#   'later ordered reinstatement to',
#   'lead',
#   'lived in',
#   'lives in',
#   'main town in',
#   'minister of',
#   'moved to',
#   'moving to',
#   'novelist from',
#   'of',
#   'ordered reinstatement to',
#   'part of',
#   'played for',
#   'president of',
#   'rabbi of',
#   'raised in',
#   'represent',
#   'represented',
#   'represented simultaneously',
#   'returned to',
#   'starred for',
#   'studied Mining Administration at',
#   'toured',
#   'toured together',
#   'town in',
#   'veering',
#   'was born',
#   'was born Seo Ju-hyun in',
#   'was born as',
#   'was born at',
#   'was born child in',
#   'was born in',
#   'was first King of',
#   'was killed in',
#   'was king of',
#   'was only King of',
#   'was pastor from',
#   'was professor at',
#   'was raised in',
#   'was third king of',
#   'went in'],
#  'P272': ['Distributed by',
#   'aired on',
#   'created by',
#   'directed at',
#   'directed for',
#   'is published by',
#   'made by',
#   'premiered on',
#   'produced by',
#   'released by',
#   'was acquired by',
#   'was developed under',
#   'was produced by',
#   'was released by',
#   'was released theatrically by',
#   'was theatrically released by'],
#  'P275': ['Distributed under',
#   'However will change from',
#   'Released under',
#   'distributed under',
#   'is',
#   'is distributed under',
#   'is licensed under',
#   'is published under',
#   'is released under',
#   'released under',
#   'was originally released under',
#   'was released to',
#   'was released under',
#   'will change from'],
#  'P276': ['Seminary in',
#   'capital of',
#   'flows through',
#   'headquartered at',
#   'held annually in',
#   'held at',
#   'held in',
#   'is In',
#   'is based in',
#   'is centre in',
#   'is important centre in',
#   'is in',
#   'is internationally recognized symbol of',
#   'is located in',
#   'is located on',
#   'is part of',
#   'is recognized symbol of',
#   'is situated in',
#   'is situated on',
#   'lies in',
#   'lies partially in',
#   'lighthouse of',
#   'monument in',
#   'moved to',
#   'raid on',
#   'took place in',
#   'train in',
#   'university in',
#   'was created in',
#   'was held at',
#   'was held in'],
#  'P277': ['is written in',
#   'mostly written in',
#   'was written entirely in',
#   'written in'],
#  'P2770': ['announced Public Policy Initiative following'],
#  'P2789': ['connects', 'meets', 'was passed to'],
#  'P279': ['are',
#   'being',
#   'is',
#   'is approach',
#   'is brand of',
#   'is newest class of',
#   'is subject like',
#   'was',
#   'was direct forerunner of',
#   'was forerunner of'],
#  'P2868': ['appears as',
#   'is',
#   'is in',
#   'is used as',
#   'was',
#   'was announced as'],
#  'P287': ['designed by',
#   'developed by',
#   'is developed by',
#   'was developed by',
#   'was developed jointly by',
#   'was jointly developed by'],
#  'P289': ['was'],
#  'P291': ['Based in',
#   'based in',
#   'is based in',
#   'is in',
#   'lost',
#   'moved to',
#   'opened in',
#   'published in',
#   'serves',
# ...
#   'broke box-office records In',
#   'broke weekend grosses In',
#   'capital of',
#   'chart in',
#   'city in',
#   'co-production of',
#   'debuted in',
#   'developed by',
#   'formed from',
#   'formed in',
#   'founded in',
#   'had seen La Tosca in',
#   'had seen in',
#   'hitting stores across',
#   'is',
#   'is International Judge for',
#   'is Judge for',
#   'is also known in',
#   'is band from',
#   'is broadcast in',
#   'is city in',
#   'is co-production among',
#   'is commune of',
#   'is in',
#   'is known in',
#   'is largest city in',
#   'is least polluted commune of',
#   'is least polluted urban commune of',
#   'is located in',
#   'is newspaper in',
#   'is now International Judge for',
#   'is now Judge for',
#   'is polluted commune of',
#   'is polluted urban commune of',
#   'is set in',
#   'is southernmost territory of',
#   'is state in',
#   'is territory of',
#   'is urban commune of',
#   'known in',
#   'largest city in',
#   'now part of',
#   'opened in',
#   'originated in',
#   'performed in',
#   'performed well in',
#   'played',
#   'played in',
#   'premiered in',
#   'produced in',
#   'program on',
#   'published in',
#   'represent',
#   'represented',
#   'returned to',
#   'settled back in',
#   'settled in',
#   'takes place in',
#   'territory of',
#   'toured',
#   'toured together',
#   'was 17th film in',
#   'was 17th highest-grossing film in',
#   'was aired In',
#   'was band from',
#   'was banned in',
#   'was born in',
#   'was created in',
#   'was developed by',
#   'was distributed across',
#   'was entry from',
#   'was filmed at',
#   'was filmed in',
#   'was first published in',
#   'was first released in',
#   'was first screened in',
#   'was formed in',
#   'was founded at',
#   'was founded in',
#   'was official entry from',
#   'was originally aired In',
#   'was originally formed in',
#   'was originally released in',
#   'was premiered in',
#   'was published in',
#   'was released In',
#   'was released in',
#   'was released theatrically In',
#   'was released theatrically in',
#   'was shot entirely in',
#   'was shot in',
#   'was shot primarily in',
#   'were formed in'],
#  'P50': ["arm 's",
#   'edited by',
#   'is coming-of-age novel by',
#   'is novel by',
#   'is twelfth novel by',
#   'novels by',
#   'was created by',
#   'was founded by',
#   'was initially created by',
#   'was written by'],
#  'P500': ['state of'],
#  'P501': ['is fully surrounded by', 'is in', 'placing'],
#  'P5059': ['is based on'],
#  'P509': ['battling',
#   'being diagnosed with',
#   'committed suicide',
#   'developed',
#   'died',
#   'died from',
#   'died in',
#   'died of',
#   'giving',
#   'has',
#   'shortly being diagnosed with',
#   'was found',
#   'was killed in'],
#  'P512': ['earned', 'worked as'],
#  'P5138': ['represented'],
#  'P527': ["' drummer is",
#   'Located on',
#   'became',
#   'contains',
#   'has',
#   'is',
#   'is coalition of',
#   'of',
#   'of Republic is',
#   'on',
#   'platform based on',
#   'refer to',
#   'refer together to',
#   'such as',
#   'was formed by',
#   'was founded by',
#   'were originally formed by'],
#  'P53': ['came from',
#   'emperor of',
#   'established',
#   'founder of',
#   'is',
#   'was figure in',
#   'was king of',
#   'was member of',
#   'was prominent member of',
#   'was third king of'],
#  'P530': ['However occupied',
#   'Ukraine with',
#   'bordering',
#   'captured Ramallah from',
#   'exported mainly to',
#   'exported to',
#   'form',
#   'has',
#   'has Human Development Index after',
#   'invaded',
#   'is African country between',
#   'is In',
#   'is Northern African country between',
#   'is Northern country between',
#   'is also founding member along with',
#   'is also member along with',
#   'is bordered by',
#   'is bordered to',
#   'is considered Together with',
#   'is country between',
#   'is founding member along with',
#   'is in',
#   'is member along with',
#   'join',
#   'joined',
#   'send troops into',
#   'sharing land borders with',
#   'signed treaty with'],
#  'P54': ['Signed by',
#   'debuted for',
#   'has played for',
#   'has previously played for',
#   'is member of',
#   'joined',
#   'midfielder from',
#   'moved to',
#   'play for',
#   'played at',
#   'returning with',
#   'signed deal with',
#   'supported',
#   'transferred to',
#   'was active for',
#   'was part of',
#   'was promoted to',
#   'was signed by',
#   'was signed to',
#   'was traded to',
#   'winning Malaysia Cup for',
#   'won Stanley Cup with'],
#  'P551': ['Born in',
#   'Presently is staying in',
#   'Set in',
#   'began in',
#   'cede part to',
#   'cede part up to',
#   'currently lives in',
#   'died in',
#   'educated in',
#   'farmer from',
#   'founded',
#   'grew up in',
#   'had left',
#   'has',
#   'is Japanese actress from',
#   'is actress from',
#   'is based in',
#   'is in',
#   'is staying in',
#   'joined',
#   'later relocated to',
#   'leaving',
#   'left',
#   'live in',
#   'lived in',
#   'lived primarily in',
#   'lives in',
#   'moved from',
#   'moved in',
#   'moved to',
#   'performed in',
#   'posting in',
#   'preaches around',
#   'raised in',
#   'received Marudhar Gaurav Award from',
#   'relocated to',
#   'represent',
#   'resides in',
#   'returned to',
#   'settled back in',
#   'settled in',
#   'traveled from',
#   'visited Korchma Taras Bulba in',
#   'was born at',
#   'was born in',
#   'was sent to',
#   'worked at',
#   'would remain in'],
#  'P559': ['connects',
#   'extending Drammen Line to',
#   'is internationally recognized symbol of',
#   'is recognized symbol of',
#   'runs from'],
#  'P566': ['was described as', 'was first described as'],
#  'P57': ['created by',
#   'directed by',
#   'follows',
#   'produced by',
#   'sequel by',
#   'starring',
#   'was adapted by',
#   'was also part of',
#   'was directed by',
#   'was part of',
#   'was produced by',
#   'was remade by',
#   'was subsequently remade by',
#   'was written by',
#   'written by'],
#  'P58': ['created by',
#   'directed by',
#   'is play by',
#   'produced along with',
#   'produced by',
#   'starring',
#   'was adapted by',
#   'was co-written by',
#   'was directed by',
#   'was produced by',
#   'was written by',
#   'written by'],
#  'P5800': ['appears as', 'is', 'replacing Darth Vader as'],
#  'P59': ['is in', 'star in', 'was assigned to'],
#  'P607': ['Earl during',
#   'Regiment during',
#   'built during',
#   'is in',
#   'served during',
#   'survived until',
#   'took part in',
#   'was armoured regiment during',
#   'was built during',
#   'was formed during',
#   'was man During',
#   'was only man During',
#   'was rear admiral during',
#   'was regiment during',
#   'was widely used In'],
#  'P609': ['is in', 'linking'],
#  'P61': ['developed by',
#   'led by',
#   'published by',
#   'was conceived by',
#   'was developed by',
#   'was discovered by'],
#  'P610': ["'s peak is"],
#  'P629': ['be incremental upgrade to', 'be upgrade to', 'is edition of'],
#  'P641': ['Israel in',
#   'Uzbekistan in',
#   'are',
#   'body for',
#   'championships in',
#   'gave up',
#   'has',
#   'is',
#   'is In',
#   'is body for',
#   'is body of',
#   'is governing body of',
#   'is in',
#   'is national body of',
#   'is national governing body of',
#   'play',
#   'playing',
#   'playing professionally',
#   'represents Armenia in',
#   'represents Cameroon in',
#   'represents Faroe Islands in',
#   'started',
#   'was fifth season of',
#   'was season in',
#   'was season of',
#   'was third season of',
#   'won gold In'],
#  'P65': ['using'],
#  'P664': ['was season of'],
#  'P669': ['is located at', 'is located in', 'is located on'],
#  'P674': ['is with',
#   'led by',
#   'saves',
#   'saves Princess Toadstool from',
#   'sung by'],
#  'P676': ['giving',
#   'produced by',
#   'was produced by',
#   'was written by',
#   'written by'],
#  'P688': ['also known as', 'known as'],
#  'P69': ['Educated in',
#   'Emeritus at',
#   'attended',
#   'attending',
#   'briefly attended',
#   'earned Bachelor from',
#   'enrolled at',
#   'entered',
#   'first attended',
#   'graduated at',
#   'graduated from',
#   'graduating from',
#   'is graduate of',
#   'is professor at',
#   'joined Department at',
#   'left',
#   'obtained',
#   'obtained MBA from',
#   'piano at',
#   'professor at',
#   'received dissertation appointment at',
#   'student at',
#   'studied at',
#   'studied economics at',
#   'taught',
#   'taught economics at',
#   'was educated at',
#   'was graduate of',
#   'was habilitated At',
#   'went to'],
#  'P702': ['also known as'],
#  'P706': ['Located in',
#   'are group in',
#   'is administrative center of',
#   'is center of',
#   'is country in',
#   'is dam on',
#   'is found in',
#   'is in',
#   'is landlocked country in',
#   'is located in',
#   'is multi-purpose dam on',
#   'is nation in',
#   'is part of',
#   'is poorest country in',
#   'is second country in',
#   'is second poorest country in',
#   'is situated in',
#   'is smallest nation in',
#   'lies in',
#   'marsh of',
#   'serving',
#   'was built on'],
#  'P708': ['is cathedral of'],
#  'P710': ['gave',
#   'is with',
#   'launched by',
#   'performed by',
#   'was conflict between',
#   'was military conflict between',
#   'was seven-month conflict between',
#   'was seven-month military conflict between',
#   'was seven-month undeclared conflict between',
#   'was seven-month undeclared military conflict between',
#   'was undeclared conflict between',
#   'was undeclared military conflict between'],
#  'P725': ['is with', 'was written by'],
#  'P734': ['began According to'],
#  'P740': ['Based in',
#   'Dot Festival in',
#   'Formed in',
#   'Founded in',
#   'Hailing from',
#   'Headquartered in',
#   'also situated in',
#   'are based in',
#   'arrived in',
#   'based in',
#   'began in',
#   'came from',
#   'came in',
#   'came together in',
#   'carried out presentations through',
#   'established in',
#   'formed in',
#   'founded in',
#   'grew up in',
#   'has lived in',
#   'has offices in',
#   'has package in',
#   'has power generation equipment in',
#   'has trialled DVB in',
#   'headquartered in',
#   'held monopoly from',
#   'is',
#   'is Christian punk from',
#   'is also based in',
#   'is band from',
#   'is based in',
#   'is headquartered in',
#   'is in',
#   'is punk from',
#   'is situated in',
#   'living in',
#   'moved from',
#   'moved to',
#   'moving to',
#   'opened in',
#   'originated in',
#   'perform in',
#   'played',
#   'played Valencia Tool In',
#   'played gig outside',
#   'produced in',
#   'provides pharmacy benefit management services in',
#   'raised in',
#   'released',
#   'relocated in',
#   'relocated to',
#   'represent',
#   'represented',
#   'return to',
#   'returned to',
#   'running app camps in',
#   'settled back in',
#   'settled in',
#   'situated in',
#   'started in',
#   'such as Ltd is',
#   'toured',
#   'toured together',
#   'was American mod active from',
#   'was American mod from',
#   'was band from',
#   'was born in',
#   'was created in',
#   'was established in',
#   'was formed backstage in',
#   'was formed in',
#   'was founded at',
#   'was founded by',
#   'was founded in',
#   'was headquartered in',
#   'was housed in',
#   'was launched in',
#   'was mod active from',
#   'was mod from',
#   'was officially presented in',
#   'was presented in',
#   'was purchased by',
#   'was started in',
#   'went to',
#   'were formed in'],
#  'P747': ['overtook',
#   'replace',
#   'replace However',
#   'replacing',
#   'was succeeded by'],
#  'P749': ["' company is",
#   "'s company is",
#   "'s successor is",
#   'President of',
#   'acquired by',
#   'are part of',
#   "arm 's",
#   'be acquired by',
#   'became',
#   'been acquired by',
#   'codesharing with',
#   'division of',
#   'do business as',
#   'doing business as',
#   'established by',
#   'form',
#   'had owned',
#   'is',
#   'is body of',
#   'is branch of',
#   'is component of',
#   'is division of',
#   'is headquarters of',
#   'is in',
#   'is member of',
#   'is now part of',
#   'is now subsidiary of',
#   'is owned by',
#   'is owned subsidiary of',
#   'is part of',
#   'is subsidiary of',
#   'is wholly owned subsidiary of',
#   'is wing of',
#   'is with',
#   'member of',
#   'merged with',
#   'non-voting stake in',
#   'operated by',
#   'owned by',
#   'owned subsidiary of',
#   'part of',
#   'stake in',
#   'studio within',
#   'subsidiary of',
#   'take over routes from',
#   'was absorbed into',
#   'was acquired by',
#   'was bought by',
#   'was established by',
#   'was founded by',
#   'was initially joint venture by',
#   'was initially venture by',
#   'was joint venture by',
#   'was legally merged with',
#   'was merged into',
#   'was merged with',
#   'was owned by',
#   'was purchased by',
#   'was renamed to',
#   'was reorganized into',
#   'was sold to',
#   'was venture by',
#   'was wholly owned subsidiary of',
#   'were closed by',
#   'were closed down by',
#   'wholly owned subsidiary of'],
#  'P750': ["' company is",
#   'Distributed by',
#   'aired on',
#   'had release by',
#   'is distributed by',
#   'made by',
#   'moved from',
#   'produced by',
#   'produced for',
#   'published by',
#   'released by',
#   'was acquired by',
#   'was announced by',
#   'was cancelled by',
#   'was co-production of',
#   'was distributed by',
#   'was picked up by',
#   'was produced by',
#   'was published by',
#   'was released by',
#   'was released on',
#   'was released through',
#   'was sold to',
#   'was theatrically released by'],
#  'P767': ['began According to', 'was also part of', 'was part of'],
#  'P793': ['be', 'for', 'gave', 'has', 'is', 'started', 'to'],
#  'P800': ["'s album is",
#   "'s epic is",
#   "'s poem is",
#   'author of',
#   'begins',
#   'built',
#   'by',
#   'concludes',
#   'continuation of',
#   'designed',
#   'designing',
#   'developing',
#   'founded',
#   'founder of',
#   'has',
#   'in',
#   'intentionally withholding information from',
#   'is in',
#   'of',
#   'on',
#   'promote',
#   'refers in',
#   'released',
#   'started',
#   'to',
#   'was born in',
#   'was writing',
#   'withholding information from',
#   'write',
#   'writes in',
#   'writing',
#   'wrote'],
#  'P802': ['known as'],
#  'P803': ['is appointed professor at'],
#  'P805': ['were'],
#  'P807': ['is bordered by', 'represented', 'were break-off group of'],
#  'P81': ['SI41 on',
#   'is located on',
#   'is on',
#   'is served by',
#   'is situated on',
#   'was opened by',
#   'was served by'],
#  'P84': ['Built by',
#   'belonged to',
#   'built by',
#   'designed by',
#   'is',
#   'was built by',
#   'was constructed by',
#   'was designed by',
#   'was designed with',
#   'was founded by'],
#  'P840': ['Lights of',
#   'Located in',
#   'Set in',
#   'University of',
#   'based in',
#   'be released for',
#   'came in',
#   'came together in',
#   'features',
#   'is',
#   'is city in',
#   'is far city in',
#   'is far largest city in',
#   'is in',
#   'is largest city in',
#   'is located in',
#   'is set in',
#   'opened in',
#   'premiered in',
#   'return to',
#   'school in',
#   'sees episode In',
#   'set in',
#   'takes place in',
#   'was banned in',
#   'was filmed in',
#   'was first released in',
#   'was formed in',
#   'was published by',
#   'was published in',
#   'was released in',
#   'was shot in'],
#  'P859': ['introducing', 'is supported by', 'took place at'],
#  'P86': ['composed by',
#   'earned',
#   'produced by',
#   'was developed by',
#   'was produced by',
#   'was recorded by',
#   'was scored by',
#   'was written by',
#   'written by'],
#  'P885': ['connects'],
#  'P915': ['Located in',
#   'Set in',
#   'filmed in',
#   'filming in',
#   'is',
#   'is gateway to',
#   'is in',
#   'is located in',
#   'is main gateway to',
#   'is set in',
#   'opened in',
#   'premiered in',
#   'sees episode In',
#   'set in',
#   'shot in',
#   'takes place in',
#   'was banned in',
#   'was filmed in',
#   'was released in',
#   'was shot in'],
#  'P921': ['base after', 'is in', 'main base after', 'uses', 'written by'],
#  'P931': ['is in'],
#  'P937': ['Born in',
#   'Brought up in',
#   'Brought up largely in',
#   'Set in',
#   'been born in',
#   'began in',
#   'came from',
#   'died in',
#   'grew up in',
#   'is appointed professor at',
#   'is based in',
#   'is buried at',
#   'is in',
#   'live in',
#   'lived in',
#   'lives in',
#   'married fellow Auschwitz survivor Elfriede Geiringer in',
#   'moved to',
#   'moving to',
#   'posting in',
#   'preaches around',
#   'resided in',
#   'resides in',
#   'return to',
#   'returned to',
#   'set up government in',
#   'settled in',
#   'studied at',
#   'traveled from',
#   'visited Korchma Taras Bulba in',
#   'was Pedagogue in',
#   'was born at',
#   'was born in',
#   'was mayor of',
#   'was probably born in'],
#  'P97': ['appears as',
#   'be',
#   'became',
#   'had',
#   'is',
#   'succeeded Qutuz as',
#   'was',
#   'was born to',
#   'was considered',
#   'was declared',
#   'was sired by',
#   'was succeeded as'],
#  'P974': ['approximate with',
#   'begins as',
#   'connects',
#   'had',
#   'is also known as',
#   'is connected through',
#   'is joined by',
#   'is known as',
#   'joins'],
#  'P98': ['developed by', 'was founded by', 'was launched with']}

# %%
with open('align.p', 'wb') as fp:
    pickle.dump(kb_to_oie, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
"'s son is" in kb_to_oie['P40']
# Out:
# True
