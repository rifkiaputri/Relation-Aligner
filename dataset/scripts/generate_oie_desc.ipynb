# %%
from nltk.wsd import lesk
from nltk.corpus import wordnet as wn
from tqdm import tqdm
import pandas as pd
import spacy

nlp = spacy.load('en_core_web_md')

# %%
data_header = ['e1_kb', 'rel_kb', 'rel_id', 'e2_kb', 'e1_oie', 'rel_oie', 'e2_oie',
                       'e1_kb_id', 'e2_kb_id', 'e1_oie_id', 'e2_oie_id',
                       'e1_oie_root', 'e2_oie_root', 'label']
# dt_type = 'v10/test'
dt_type = 'test'
align_data = pd.read_csv('../' + dt_type + '_align_gold_v2.tsv', sep='\t', header=None, names=data_header)

# %%
align_data
# Out:
#                                    e1_kb  \
# 0                                 Cronus
# 1                      A Royal Christmas
# 2                             Mystic Ark
# 3                        Nisqually River
# 4                               Big Fish
# 5                          Jane Menelaus
# 6                             Diddy Kong
# 7                               Deadpool
# 8                  Stony Brook Seawolves
# 9                                 Garuda
# 10                              Katyusha
# 11                      Ramapo Mountains
# 12                         Dayton Flyers
# 13                     Jackson Mountains
# 14                        Pacific Ranges
# 15              Central Methodist Eagles
# 16                                  Hops
# 17                                  Zeus
# 18                        Peaky Blinders
# 19                              Lady Gan
# 20                           Wicklow Way
# 21                            Bluefields
# 22                                Trebur
# 23                              Margaret
# 24                                 Maemo
# 25                       Thomas Hawksley
# 26                              Deerhoof
# 27                              Jeconiah
# 28                            Shrewsbury
# 29                         Reinhard Mohn
# ..                                   ...
# 370                     SteamWorld Heist
# 371                            Your Name
# 372                               Tekken
# 373               Kandagawa Pervert Wars
# 374                           Gwangju FC
# 375                         Soviet ruble
# 376                      1987 NFL season
# 377         2017 F4 Spanish Championship
# 378                          Hard Target
# 379                          Rock School
# 380                            Nano Ripe
# 381                     Walter fitz Alan
# 382  1st Assault Brigade Royal Engineers
# 383                            Jind Kaur
# 384                           Betty Boop
# 385                               Ceefax
# 386                     Anthropology 101
# 387                       The Internship
# 388                               Bigelf
# 389                        YÅ«gen gaisha
# 390                     Dropkick Murphys
# 391                       Marks Barfield
# 392                            TeÄovice
# 393                                 Yoda
# 394                          Marthe Vogt
# 395                           Lucy Burns
# 396                            Wu Jingui
# 397                    The Amazing Grace
# 398          My Awkward Sexual Adventure
# 399                     The Overnighters
#
#                                                rel_kb rel_id  \
# 0                                               child    P40
# 1                                         distributor   P750
# 2                                           developer   P178
# 3                            mouth of the watercourse   P403
# 4                                    filming location   P915
# 5                                              spouse    P26
# 6                                     present in work  P1441
# 7                                           member of   P463
# 8                                          represents  P1268
# 9                                            facet of  P1269
# 10                                        named after   P138
# 11                                     mountain range  P4552
# 12                                         represents  P1268
# 13   located in the administrative territorial entity   P131
# 14                                     mountain range  P4552
# 15                                         represents  P1268
# 16                                                use   P366
# 17                                            sibling  P3373
# 18                                 narrative location   P840
# 19                                             spouse    P26
# 20                                            country    P17
# 21                                         capital of  P1376
# 22         contains administrative territorial entity   P150
# 23                          original language of work   P364
# 24                                          developer   P178
# 25                                              child    P40
# 26                              location of formation   P740
# 27                                     place of death    P20
# 28                located in or next to body of water   P206
# 29                                           conflict   P607
# ..                                                ...    ...
# 370                                          platform   P400
# 371                                 country of origin   P495
# 372                                          platform   P400
# 373                                       distributor   P750
# 374                                            league   P118
# 375                                       replaced by  P1366
# 376            sports season of league or competition  P3450
# 377            sports season of league or competition  P3450
# 378                                narrative location   P840
# 379                                  original network   P449
# 380                                      record label   P264
# 381                                            father    P22
# 382                                   military branch   P241
# 383                                            spouse    P26
# 384                                   present in work  P1441
# 385                                  original network   P449
# 386                                      screenwriter    P58
# 387                                          producer   P162
# 388                             location of formation   P740
# 389                           applies to jurisdiction  P1001
# 390                             location of formation   P740
# 391                                      notable work   P800
# 392                                shares border with    P47
# 393                                   present in work  P1441
# 394                                     work location   P937
# 395                                 country for sport  P1532
# 396                                    place of birth    P19
# 397                                          producer   P162
# 398                                      screenwriter    P58
# 399                                          director    P57
#
#                             e2_kb                               e1_oie  \
# 0                            Zeus                               Cronus
# 1                Hallmark Channel                      Royal Christmas
# 2                         Produce                           Mystic Ark
# 3                     Puget Sound                      Nisqually River
# 4                         Alabama                             Big Fish
# 5                   Geoffrey Rush                        Jane Menelaus
# 6             Donkey Kong Country                           Diddy Kong
# 7                         X-Force                             Deadpool
# 8          Stony Brook University                Stony Brook Seawolves
# 9                        Buddhism                               Garuda
# 10                      Ekaterina                             Katyusha
# 11          Appalachian Mountains                     Ramapo Mountains
# 12           University of Dayton                        Dayton Flyers
# 13                Humboldt County                    Jackson Mountains
# 14                Coast Mountains                       Pacific Ranges
# 15   Central Methodist University             Central Methodist Eagles
# 16                        brewing                                 Hops
# 17                         Hestia                                 Zeus
# 18                     Birmingham                       Peaky Blinders
# 19                        Liu Bei                             Lady Gan
# 20                        Ireland                          Wicklow Way
# 21                 Mosquito Coast                           Bluefields
# 22                        Astheim                               Trebur
# 23                        English                             Margaret
# 24                          Nokia                                Maemo
# 25               Charles Hawksley                      Thomas Hawksley
# 26                  San Francisco                             Deerhoof
# 27                        Babylon                             Jeconiah
# 28                         Severn                           Shrewsbury
# 29                   World War II                        Reinhard Mohn
# ..                            ...                                  ...
# 370                  Nintendo 3DS                     SteamWorld Heist
# 371                         Japan                            Your Name
# 372                   PlayStation                               Tekken
# 373                  Million Film               Kandagawa Pervert Wars
# 374            K League Challenge                           Gwangju FC
# 375                 Russian ruble                         Soviet ruble
# 376      National Football League                      1987 NFL season
# 377       Spanish F4 Championship         2017 F4 Spanish Championship
# 378                   New Orleans                          Hard Target
# 379                     Channel 4                          Rock School
# 380                        Lantis                            Nano Ripe
# 381               Alan fitz Flaad                     Walter fitz Alan
# 382                  British Army  1st Assault Brigade Royal Engineers
# 383                  Ranjit Singh                            Jind Kaur
# 384                   Talkartoons                           Betty Boop
# 385                           BBC                               Ceefax
# 386                 Chris McKenna                     Anthropology 101
# 387                  Vince Vaughn                           Internship
# 388                   Los Angeles                               Bigelf
# 389                         Japan                        YÅ«gen gaisha
# 390                        Quincy                     Dropkick Murphys
# 391                    London Eye                       Marks Barfield
# 392                         ZlÃ­n                            TeÄovice
# 393                     Star Wars                                 Yoda
# 394                     Cambridge                          Marthe Vogt
# 395                United Kingdom                           Lucy Burns
# 396                      Shanghai                            Wu Jingui
# 397                    Jeta Amata                        Amazing Grace
# 398                Jonas Chernick          My Awkward Sexual Adventure
# 399                    Jesse Moss                         Overnighters
#
#                                     rel_oie                        e2_oie  \
# 0                                  ' son is                          Zeus
# 1                                  aired on              Hallmark Channel
# 2                         also developed by                       Produce
# 3                     also lived throughout                   Puget Sound
# 4                Apart was entirely shot in                       Alabama
# 5                             appeared with                 Geoffrey Rush
# 6                              appearing in           Donkey Kong Country
# 7                              appearing in                       X-Force
# 8                     are athletic teams of        Stony Brook University
# 9                              are birds In                      Buddhism
# 10                      are common forms of                     Ekaterina
# 11                    are forested chain of         Appalachian Mountains
# 12             are intercollegiate teams of          University of Dayton
# 13                           are located in               Humboldt County
# 14          are southernmost subdivision of               Coast Mountains
# 15                             are teams of  Central Methodist University
# 16                              are used in                       brewing
# 17                                  assigns                        Hestia
# 18                                 based in                    Birmingham
# 19                         be honoured with                       Liu Bei
# 20                             be opened in                       Ireland
# 21                              became over                Mosquito Coast
# 22                     became Together with                       Astheim
# 23                                     been                       English
# 24                    been developed within                         Nokia
# 25                         been followed by              Charles Hawksley
# 26                                 began in                 San Francisco
# 27                            began trip to                       Babylon
# 28              being entirely encircled by                  River Severn
# 29                    being involved during                  World War II
# ..                                      ...                           ...
# 370                        was released for                  Nintendo 3DS
# 371                         was released in                         Japan
# 372           was released respectively for                   PlayStation
# 373            was released theatrically by                  Million Film
# 374                        was relegated to            K League Challenge
# 375                       was replaced with                 Russian ruble
# 376                           was season of      National Football League
# 377                    was second season of       Spanish F4 Championship
# 378                             was shot in                   New Orleans
# 379                            was shown on                     Channel 4
# 380                           was signed to                        Lantis
# 381                              was son of               Alan fitz Flaad
# 382  was specialisied armoured formation of                  British Army
# 383                           was spouse of                  Ranjit Singh
# 384                             was star of                   Talkartoons
# 385                          was started by                           BBC
# 386                          was written by                 Chris McKenna
# 387                             weighs down                  Vince Vaughn
# 388                          were formed in                   Los Angeles
# 389                     were implemented in                         Japan
# 390               were originally formed in                        Quincy
# 391                          were owners of                    London Eye
# 392                                 west of                         ZlÃ­n
# 393                          will appear in                     Star Wars
# 394                                 work in                     Cambridge
# 395                              working in                United Kingdom
# 396                             would steer                      Shanghai
# 397                              written by                    Jeta Amata
# 398                              written by                Jonas Chernick
# 399                              written by                    Jesse Moss
#
#       e1_kb_id   e2_kb_id  e1_oie_id  e2_oie_id  e1_oie_root  e2_oie_root  \
# 0       Q44204     Q34201     Q44204     Q34201          NaN          NaN
# 1    Q18611433  Q15501374  Q18611433  Q15501374          NaN          NaN
# 2     Q6948921   Q7247680   Q6948921   Q7247680          NaN          NaN
# 3      Q829444    Q604141    Q829444    Q604141          NaN          NaN
# 4      Q278997       Q173    Q278997       Q173          NaN          NaN
# 5     Q2063601    Q166272   Q2063601    Q166272          NaN          NaN
# 6    Q10904385    Q518987  Q10904385    Q518987          NaN          NaN
# 7     Q1631090    Q938034   Q1631090    Q938034          NaN          NaN
# 8     Q7619507    Q969850   Q7619507    Q969850          NaN          NaN
# 9      Q188676       Q748    Q188676       Q748          NaN          NaN
# 10      Q18288  Q17317988     Q18288  Q17317988          NaN          NaN
# 11     Q591130     Q93332    Q591130     Q93332          NaN          NaN
# 12    Q3074591   Q2092392   Q3074591   Q2092392          NaN          NaN
# 13    Q6117265    Q495376   Q6117265    Q495376          NaN          NaN
# 14    Q1285418    Q920070   Q1285418    Q920070          NaN          NaN
# 15    Q5061421   Q5061424   Q5061421   Q5061424          NaN          NaN
# 16    Q3214940    Q869095   Q3214940    Q869095          NaN          NaN
# 17      Q34201     Q41419     Q34201     Q41419          NaN          NaN
# 18   Q14944179      Q2256  Q14944179      Q2256          NaN          NaN
# 19    Q1064069    Q245315   Q1064069    Q245315          NaN          NaN
# 20     Q389539        Q27    Q389539        Q27          NaN          NaN
# 21     Q885996   Q1165546    Q885996   Q1165546          NaN          NaN
# 22     Q634084    Q749125    Q634084    Q749125          NaN          NaN
# 23     Q866694      Q1860    Q866694      Q1860          NaN          NaN
# 24     Q239749      Q1418    Q239749      Q1418          NaN          NaN
# 25    Q2424595   Q5078845   Q2424595   Q5078845          NaN          NaN
# 26    Q1109380        Q62   Q1109380        Q62          NaN          NaN
# 27     Q319049      Q5684    Q319049      Q5684          NaN          NaN
# 28     Q201970     Q19682    Q201970     Q19682          NaN          NaN
# 29      Q62631       Q362     Q62631       Q362          NaN          NaN
# ..         ...        ...        ...        ...          ...          ...
# 370  Q22019745    Q203597  Q22019745    Q203597          NaN          NaN
# 371  Q27037028        Q17  Q27037028        Q17          NaN          NaN
# 372   Q1142893     Q10677   Q1142893     Q10677          NaN          NaN
# 373   Q6361192   Q6859778   Q6361192   Q6859778          NaN          NaN
# 374    Q168364   Q5100359    Q168364   Q5100359          NaN          NaN
# 375    Q615640     Q41044    Q615640     Q41044          NaN          NaN
# 376   Q2406048   Q1215884   Q2406048   Q1215884          NaN          NaN
# 377  Q28128562  Q18712537  Q28128562  Q18712537          NaN          NaN
# 378    Q574993     Q34404    Q574993     Q34404          NaN          NaN
# 379   Q7354681    Q501070   Q7354681    Q501070          NaN          NaN
# 380    Q307388   Q1062659    Q307388   Q1062659          NaN          NaN
# 381    Q593455   Q3607788    Q593455   Q3607788          NaN          NaN
# 382   Q4596153    Q222595   Q4596153    Q222595          NaN          NaN
# 383   Q2753670    Q332620   Q2753670    Q332620          NaN          NaN
# 384    Q583810   Q3980443    Q583810   Q3980443          NaN          NaN
# 385   Q1038123      Q9531   Q1038123      Q9531          NaN          NaN
# 386   Q4773906   Q5107425   Q4773906   Q5107425          NaN          NaN
# 387   Q4207359    Q107730   Q4207359    Q107730          NaN          NaN
# 388    Q509540        Q65    Q509540        Q65          NaN          NaN
# 389   Q1185713        Q17   Q1185713        Q17          NaN          NaN
# 390    Q938630     Q49143    Q938630     Q49143          NaN          NaN
# 391  Q16947378    Q160659  Q16947378    Q160659          NaN          NaN
# 392   Q1789569    Q171018   Q1789569    Q171018          NaN          NaN
# 393     Q51730       Q462     Q51730       Q462          NaN          NaN
# 394    Q101167       Q350    Q101167       Q350          NaN          NaN
# 395  Q27567893       Q145  Q27567893       Q145          NaN          NaN
# 396   Q4468233      Q8686   Q4468233      Q8686          NaN          NaN
# 397   Q7713315  Q16004508   Q7713315  Q16004508          NaN          NaN
# 398  Q15281738  Q16202764  Q15281738  Q16202764          NaN          NaN
# 399  Q17073603  Q20649765  Q17073603  Q20649765          NaN          NaN
#
#      label
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
# 5        1
# 6        0
# 7        0
# 8        1
# 9        0
# 10       0
# 11       1
# 12       0
# 13       0
# 14       0
# 15       0
# 16       0
# 17       1
# 18       0
# 19       1
# 20       1
# 21       1
# 22       1
# 23       1
# 24       0
# 25       1
# 26       0
# 27       1
# 28       0
# 29       0
# ..     ...
# 370      0
# 371      0
# 372      0
# 373      0
# 374      0
# 375      0
# 376      0
# 377      0
# 378      0
# 379      0
# 380      0
# 381      1
# 382      0
# 383      0
# 384      0
# 385      0
# 386      0
# 387      1
# 388      0
# 389      0
# 390      0
# 391      1
# 392      0
# 393      0
# 394      0
# 395      1
# 396      1
# 397      0
# 398      0
# 399      1
#
# [400 rows x 14 columns]

# %%
def spacy_to_wn_tags(pos_tag):
    if pos_tag == 'ADJ':
        return wn.ADJ
    elif pos_tag in ['ADV', 'ADP']:
        return wn.ADV
    elif pos_tag.startswith('V'):
        return wn.VERB
    elif pos_tag.startswith('N'):
        return wn.NOUN
    else:
        return None

rels_oie_def = []
for i in tqdm(range(len(align_data))):
    e1 = align_data['e1_oie'][i]
    rel = align_data['rel_oie'][i]
    e2 = align_data['e2_oie'][i]
    doc = nlp(rel)

    defs = []
    for token in doc:
        word = token.text
        if word == "'s":
            defs.append(word)
        elif token.pos_ not in ['PUNCT']:
            pos_word = spacy_to_wn_tags(token.pos_)
            dep_word = token.dep_

            if pos_word == 'r':
                syns = wn.synsets(word, pos=pos_word)
                if len(syns) > 0:
                    defs.append(syns[0].definition().split('; ')[0])
            else:
                syn = lesk([word, e1, e2], word)
                if syn is not None:
                    defs.append(syn.definition().split('; ')[0])

    if len(defs) > 0:
        rels_oie_def.append(' '.join(defs))
    else:
        rels_oie_def.append(rel)
# Out:
# 100%|██████████| 400/400 [00:04<00:00, 90.25it/s]

# %%
len(rels_oie_def)
# Out:
# 400

# %%
align_data['def'] = rels_oie_def

# %%
align_data.to_csv('../' + dt_type + '_align_gold_def_v2.tsv', sep='\t', header=False, index=False)

# %%
data_header = ['e1_kb', 'rel_kb', 'rel_id', 'e2_kb', 'e1_oie', 'rel_oie', 'e2_oie',
                       'e1_kb_id', 'e2_kb_id', 'e1_oie_id', 'e2_oie_id',
                       'e1_oie_root', 'e2_oie_root', 'label', 'oie_def']
align_data = pd.read_csv('../' + dt_type + '_align_gold_def_v2.tsv', sep='\t', header=None, names=data_header)

# %%
align_data
# Out:
#                                    e1_kb  \
# 0                                 Cronus
# 1                      A Royal Christmas
# 2                             Mystic Ark
# 3                        Nisqually River
# 4                               Big Fish
# 5                          Jane Menelaus
# 6                             Diddy Kong
# 7                               Deadpool
# 8                  Stony Brook Seawolves
# 9                                 Garuda
# 10                              Katyusha
# 11                      Ramapo Mountains
# 12                         Dayton Flyers
# 13                     Jackson Mountains
# 14                        Pacific Ranges
# 15              Central Methodist Eagles
# 16                                  Hops
# 17                                  Zeus
# 18                        Peaky Blinders
# 19                              Lady Gan
# 20                           Wicklow Way
# 21                            Bluefields
# 22                                Trebur
# 23                              Margaret
# 24                                 Maemo
# 25                       Thomas Hawksley
# 26                              Deerhoof
# 27                              Jeconiah
# 28                            Shrewsbury
# 29                         Reinhard Mohn
# ..                                   ...
# 370                     SteamWorld Heist
# 371                            Your Name
# 372                               Tekken
# 373               Kandagawa Pervert Wars
# 374                           Gwangju FC
# 375                         Soviet ruble
# 376                      1987 NFL season
# 377         2017 F4 Spanish Championship
# 378                          Hard Target
# 379                          Rock School
# 380                            Nano Ripe
# 381                     Walter fitz Alan
# 382  1st Assault Brigade Royal Engineers
# 383                            Jind Kaur
# 384                           Betty Boop
# 385                               Ceefax
# 386                     Anthropology 101
# 387                       The Internship
# 388                               Bigelf
# 389                        YÅ«gen gaisha
# 390                     Dropkick Murphys
# 391                       Marks Barfield
# 392                            TeÄovice
# 393                                 Yoda
# 394                          Marthe Vogt
# 395                           Lucy Burns
# 396                            Wu Jingui
# 397                    The Amazing Grace
# 398          My Awkward Sexual Adventure
# 399                     The Overnighters
#
#                                                rel_kb rel_id  \
# 0                                               child    P40
# 1                                         distributor   P750
# 2                                           developer   P178
# 3                            mouth of the watercourse   P403
# 4                                    filming location   P915
# 5                                              spouse    P26
# 6                                     present in work  P1441
# 7                                           member of   P463
# 8                                          represents  P1268
# 9                                            facet of  P1269
# 10                                        named after   P138
# 11                                     mountain range  P4552
# 12                                         represents  P1268
# 13   located in the administrative territorial entity   P131
# 14                                     mountain range  P4552
# 15                                         represents  P1268
# 16                                                use   P366
# 17                                            sibling  P3373
# 18                                 narrative location   P840
# 19                                             spouse    P26
# 20                                            country    P17
# 21                                         capital of  P1376
# 22         contains administrative territorial entity   P150
# 23                          original language of work   P364
# 24                                          developer   P178
# 25                                              child    P40
# 26                              location of formation   P740
# 27                                     place of death    P20
# 28                located in or next to body of water   P206
# 29                                           conflict   P607
# ..                                                ...    ...
# 370                                          platform   P400
# 371                                 country of origin   P495
# 372                                          platform   P400
# 373                                       distributor   P750
# 374                                            league   P118
# 375                                       replaced by  P1366
# 376            sports season of league or competition  P3450
# 377            sports season of league or competition  P3450
# 378                                narrative location   P840
# 379                                  original network   P449
# 380                                      record label   P264
# 381                                            father    P22
# 382                                   military branch   P241
# 383                                            spouse    P26
# 384                                   present in work  P1441
# 385                                  original network   P449
# 386                                      screenwriter    P58
# 387                                          producer   P162
# 388                             location of formation   P740
# 389                           applies to jurisdiction  P1001
# 390                             location of formation   P740
# 391                                      notable work   P800
# 392                                shares border with    P47
# 393                                   present in work  P1441
# 394                                     work location   P937
# 395                                 country for sport  P1532
# 396                                    place of birth    P19
# 397                                          producer   P162
# 398                                      screenwriter    P58
# 399                                          director    P57
#
#                             e2_kb                               e1_oie  \
# 0                            Zeus                               Cronus
# 1                Hallmark Channel                      Royal Christmas
# 2                         Produce                           Mystic Ark
# 3                     Puget Sound                      Nisqually River
# 4                         Alabama                             Big Fish
# 5                   Geoffrey Rush                        Jane Menelaus
# 6             Donkey Kong Country                           Diddy Kong
# 7                         X-Force                             Deadpool
# 8          Stony Brook University                Stony Brook Seawolves
# 9                        Buddhism                               Garuda
# 10                      Ekaterina                             Katyusha
# 11          Appalachian Mountains                     Ramapo Mountains
# 12           University of Dayton                        Dayton Flyers
# 13                Humboldt County                    Jackson Mountains
# 14                Coast Mountains                       Pacific Ranges
# 15   Central Methodist University             Central Methodist Eagles
# 16                        brewing                                 Hops
# 17                         Hestia                                 Zeus
# 18                     Birmingham                       Peaky Blinders
# 19                        Liu Bei                             Lady Gan
# 20                        Ireland                          Wicklow Way
# 21                 Mosquito Coast                           Bluefields
# 22                        Astheim                               Trebur
# 23                        English                             Margaret
# 24                          Nokia                                Maemo
# 25               Charles Hawksley                      Thomas Hawksley
# 26                  San Francisco                             Deerhoof
# 27                        Babylon                             Jeconiah
# 28                         Severn                           Shrewsbury
# 29                   World War II                        Reinhard Mohn
# ..                            ...                                  ...
# 370                  Nintendo 3DS                     SteamWorld Heist
# 371                         Japan                            Your Name
# 372                   PlayStation                               Tekken
# 373                  Million Film               Kandagawa Pervert Wars
# 374            K League Challenge                           Gwangju FC
# 375                 Russian ruble                         Soviet ruble
# 376      National Football League                      1987 NFL season
# 377       Spanish F4 Championship         2017 F4 Spanish Championship
# 378                   New Orleans                          Hard Target
# 379                     Channel 4                          Rock School
# 380                        Lantis                            Nano Ripe
# 381               Alan fitz Flaad                     Walter fitz Alan
# 382                  British Army  1st Assault Brigade Royal Engineers
# 383                  Ranjit Singh                            Jind Kaur
# 384                   Talkartoons                           Betty Boop
# 385                           BBC                               Ceefax
# 386                 Chris McKenna                     Anthropology 101
# 387                  Vince Vaughn                           Internship
# 388                   Los Angeles                               Bigelf
# 389                         Japan                        YÅ«gen gaisha
# 390                        Quincy                     Dropkick Murphys
# 391                    London Eye                       Marks Barfield
# 392                         ZlÃ­n                            TeÄovice
# 393                     Star Wars                                 Yoda
# 394                     Cambridge                          Marthe Vogt
# 395                United Kingdom                           Lucy Burns
# 396                      Shanghai                            Wu Jingui
# 397                    Jeta Amata                        Amazing Grace
# 398                Jonas Chernick          My Awkward Sexual Adventure
# 399                    Jesse Moss                         Overnighters
#
#                                     rel_oie                        e2_oie  \
# 0                                  ' son is                          Zeus
# 1                                  aired on              Hallmark Channel
# 2                         also developed by                       Produce
# 3                     also lived throughout                   Puget Sound
# 4                Apart was entirely shot in                       Alabama
# 5                             appeared with                 Geoffrey Rush
# 6                              appearing in           Donkey Kong Country
# 7                              appearing in                       X-Force
# 8                     are athletic teams of        Stony Brook University
# 9                              are birds In                      Buddhism
# 10                      are common forms of                     Ekaterina
# 11                    are forested chain of         Appalachian Mountains
# 12             are intercollegiate teams of          University of Dayton
# 13                           are located in               Humboldt County
# 14          are southernmost subdivision of               Coast Mountains
# 15                             are teams of  Central Methodist University
# 16                              are used in                       brewing
# 17                                  assigns                        Hestia
# 18                                 based in                    Birmingham
# 19                         be honoured with                       Liu Bei
# 20                             be opened in                       Ireland
# 21                              became over                Mosquito Coast
# 22                     became Together with                       Astheim
# 23                                     been                       English
# 24                    been developed within                         Nokia
# 25                         been followed by              Charles Hawksley
# 26                                 began in                 San Francisco
# 27                            began trip to                       Babylon
# 28              being entirely encircled by                  River Severn
# 29                    being involved during                  World War II
# ..                                      ...                           ...
# 370                        was released for                  Nintendo 3DS
# 371                         was released in                         Japan
# 372           was released respectively for                   PlayStation
# 373            was released theatrically by                  Million Film
# 374                        was relegated to            K League Challenge
# 375                       was replaced with                 Russian ruble
# 376                           was season of      National Football League
# 377                    was second season of       Spanish F4 Championship
# 378                             was shot in                   New Orleans
# 379                            was shown on                     Channel 4
# 380                           was signed to                        Lantis
# 381                              was son of               Alan fitz Flaad
# 382  was specialisied armoured formation of                  British Army
# 383                           was spouse of                  Ranjit Singh
# 384                             was star of                   Talkartoons
# 385                          was started by                           BBC
# 386                          was written by                 Chris McKenna
# 387                             weighs down                  Vince Vaughn
# 388                          were formed in                   Los Angeles
# 389                     were implemented in                         Japan
# 390               were originally formed in                        Quincy
# 391                          were owners of                    London Eye
# 392                                 west of                         ZlÃ­n
# 393                          will appear in                     Star Wars
# 394                                 work in                     Cambridge
# 395                              working in                United Kingdom
# 396                             would steer                      Shanghai
# 397                              written by                    Jeta Amata
# 398                              written by                Jonas Chernick
# 399                              written by                    Jesse Moss
#
#       e1_kb_id   e2_kb_id  e1_oie_id  e2_oie_id  e1_oie_root  e2_oie_root  \
# 0       Q44204     Q34201     Q44204     Q34201          NaN          NaN
# 1    Q18611433  Q15501374  Q18611433  Q15501374          NaN          NaN
# 2     Q6948921   Q7247680   Q6948921   Q7247680          NaN          NaN
# 3      Q829444    Q604141    Q829444    Q604141          NaN          NaN
# 4      Q278997       Q173    Q278997       Q173          NaN          NaN
# 5     Q2063601    Q166272   Q2063601    Q166272          NaN          NaN
# 6    Q10904385    Q518987  Q10904385    Q518987          NaN          NaN
# 7     Q1631090    Q938034   Q1631090    Q938034          NaN          NaN
# 8     Q7619507    Q969850   Q7619507    Q969850          NaN          NaN
# 9      Q188676       Q748    Q188676       Q748          NaN          NaN
# 10      Q18288  Q17317988     Q18288  Q17317988          NaN          NaN
# 11     Q591130     Q93332    Q591130     Q93332          NaN          NaN
# 12    Q3074591   Q2092392   Q3074591   Q2092392          NaN          NaN
# 13    Q6117265    Q495376   Q6117265    Q495376          NaN          NaN
# 14    Q1285418    Q920070   Q1285418    Q920070          NaN          NaN
# 15    Q5061421   Q5061424   Q5061421   Q5061424          NaN          NaN
# 16    Q3214940    Q869095   Q3214940    Q869095          NaN          NaN
# 17      Q34201     Q41419     Q34201     Q41419          NaN          NaN
# 18   Q14944179      Q2256  Q14944179      Q2256          NaN          NaN
# 19    Q1064069    Q245315   Q1064069    Q245315          NaN          NaN
# 20     Q389539        Q27    Q389539        Q27          NaN          NaN
# 21     Q885996   Q1165546    Q885996   Q1165546          NaN          NaN
# 22     Q634084    Q749125    Q634084    Q749125          NaN          NaN
# 23     Q866694      Q1860    Q866694      Q1860          NaN          NaN
# 24     Q239749      Q1418    Q239749      Q1418          NaN          NaN
# 25    Q2424595   Q5078845   Q2424595   Q5078845          NaN          NaN
# 26    Q1109380        Q62   Q1109380        Q62          NaN          NaN
# 27     Q319049      Q5684    Q319049      Q5684          NaN          NaN
# 28     Q201970     Q19682    Q201970     Q19682          NaN          NaN
# 29      Q62631       Q362     Q62631       Q362          NaN          NaN
# ..         ...        ...        ...        ...          ...          ...
# 370  Q22019745    Q203597  Q22019745    Q203597          NaN          NaN
# 371  Q27037028        Q17  Q27037028        Q17          NaN          NaN
# 372   Q1142893     Q10677   Q1142893     Q10677          NaN          NaN
# 373   Q6361192   Q6859778   Q6361192   Q6859778          NaN          NaN
# 374    Q168364   Q5100359    Q168364   Q5100359          NaN          NaN
# 375    Q615640     Q41044    Q615640     Q41044          NaN          NaN
# 376   Q2406048   Q1215884   Q2406048   Q1215884          NaN          NaN
# 377  Q28128562  Q18712537  Q28128562  Q18712537          NaN          NaN
# 378    Q574993     Q34404    Q574993     Q34404          NaN          NaN
# 379   Q7354681    Q501070   Q7354681    Q501070          NaN          NaN
# 380    Q307388   Q1062659    Q307388   Q1062659          NaN          NaN
# 381    Q593455   Q3607788    Q593455   Q3607788          NaN          NaN
# 382   Q4596153    Q222595   Q4596153    Q222595          NaN          NaN
# 383   Q2753670    Q332620   Q2753670    Q332620          NaN          NaN
# 384    Q583810   Q3980443    Q583810   Q3980443          NaN          NaN
# 385   Q1038123      Q9531   Q1038123      Q9531          NaN          NaN
# 386   Q4773906   Q5107425   Q4773906   Q5107425          NaN          NaN
# 387   Q4207359    Q107730   Q4207359    Q107730          NaN          NaN
# 388    Q509540        Q65    Q509540        Q65          NaN          NaN
# 389   Q1185713        Q17   Q1185713        Q17          NaN          NaN
# 390    Q938630     Q49143    Q938630     Q49143          NaN          NaN
# 391  Q16947378    Q160659  Q16947378    Q160659          NaN          NaN
# 392   Q1789569    Q171018   Q1789569    Q171018          NaN          NaN
# 393     Q51730       Q462     Q51730       Q462          NaN          NaN
# 394    Q101167       Q350    Q101167       Q350          NaN          NaN
# 395  Q27567893       Q145  Q27567893       Q145          NaN          NaN
# 396   Q4468233      Q8686   Q4468233      Q8686          NaN          NaN
# 397   Q7713315  Q16004508   Q7713315  Q16004508          NaN          NaN
# 398  Q15281738  Q16202764  Q15281738  Q16202764          NaN          NaN
# 399  Q17073603  Q20649765  Q17073603  Q20649765          NaN          NaN
#
#      label                                            oie_def
# 0        0  the divine word of God have an existence, be e...
# 1        0  expose to cool or cold air so as to cool or fr...
# 2        0  in addition create by training and teaching so...
# 3        1  in addition continue to live through hardship ...
# 4        0  separated or at a distance in place or positio...
# 5        1  give a certain impression or have a certain ou...
# 6        0  give a certain impression or have a certain ou...
# 7        0  give a certain impression or have a certain ou...
# 8        1  have an existence, be extant having a sturdy a...
# 9        0  have an existence, be extant watch and study b...
# 10       0  have an existence, be extant common to or shar...
# 11       1  have an existence, be extant covered with fore...
# 12       0  have an existence, be extant used of competiti...
# 13       0  have an existence, be extant determine or indi...
# 14       0  have an existence, be extant situated farthest...
# 15       0           have an existence, be extant form a team
# 16       0  have an existence, be extant previously used o...
# 17       1                                  attribute or give
# 18       0  use (purified cocaine) by burning it and inhal...
# 19       1  have an existence, be extant show respect towards
# 20       1  have an existence, be extant spread out or ope...
# 21       1  enhance the appearance of at or to a point acr...
# 22       1  enhance the appearance of in contact with each...
# 23       1                       have an existence, be extant
# 24       0  have an existence, be extant create by trainin...
# 25       1  have an existence, be extant follow with the e...
# 26       0  take the first step or steps in carrying out a...
# 27       1  take the first step or steps in carrying out a...
# 28       0  a living thing that has (or can develop) the a...
# 29       0  a living thing that has (or can develop) the a...
# ..     ...                                                ...
# 370      0  happen, occur, take place make (assets) available
# 371      0  happen, occur, take place make (assets) availa...
# 372      0  happen, occur, take place make (assets) availa...
# 373      0  happen, occur, take place make (assets) availa...
# 374      0  happen, occur, take place assign to a class or...
# 375      0  happen, occur, take place take the place or mo...
# 376      0  happen, occur, take place make more temperate,...
# 377      0  happen, occur, take place the gear that has th...
# 378      0  happen, occur, take place sports equipment con...
# 379      0  happen, occur, take place take (someone) to th...
# 380      0  happen, occur, take place having a handwritten...
# 381      1   happen, occur, take place the divine word of God
# 382      0  happen, occur, take place used of animals (geo...
# 383      0  happen, occur, take place a person's partner i...
# 384      0  happen, occur, take place be the star in a per...
# 385      0  happen, occur, take place move or jump suddenl...
# 386      0  happen, occur, take place systematically colle...
# 387      1  to be oppressive or burdensome drink down enti...
# 388      0  have an existence, be extant give shape or for...
# 389      0  have an existence, be extant apply in a manner...
# 390      0  have an existence, be extant in an original ma...
# 391      1  have an existence, be extant a person who owns...
# 392      0                         to, toward, or in the west
# 393      0  leave or give by will after one's death appear...
# 394      0  a place where work is done to or toward the in...
# 395      1  serving to permit or facilitate further work o...
# 396      1             an indication of potential opportunity
# 397      0  systematically collected and written down so a...
# 398      0  systematically collected and written down so a...
# 399      1  systematically collected and written down so a...
#
# [400 rows x 15 columns]

# %%
align_data_arranged = align_data[[
                        'e1_kb', 'rel_kb', 'rel_id', 'e2_kb', 'e1_oie', 'rel_oie', 'e2_oie',
                        'e1_kb_id', 'e2_kb_id', 'e1_oie_id', 'e2_oie_id', 'oie_def', 'label'
                    ]]

# %%
align_data_arranged.to_csv('../' + dt_type + '_align_gold_def_v2.tsv', sep='\t', header=False, index=False)
