# %%
import json

# %%
with open('../../predict/cesi/cluster_rel.json') as f:
    rel_data = json.load(f)

# %%
cluster = rel_data['cluster']

# %%
rel_to_id = {}
for i in range(len(cluster)):
    for rel in cluster[i]:
        rel_to_id[rel] = i

# %%
rel_to_id
# Out:
# {'headquarters location': 0,
#  'location': 0,
#  'import goods than': 1,
#  'producer': 2,
#  'named for': 3,
#  'best known for': 3,
#  'known for': 3,
#  'responsible for': 3,
#  'outpacing': 4,
#  'is island of': 5,
#  'is gated community on': 5,
#  'is bordered to': 5,
#  'is coastal parish on': 5,
#  'is island in': 5,
#  'more closely resembled': 6,
#  'child': 7,
#  'continent': 8,
#  'on': 9,
#  'is based on': 9,
#  'is city located in': 10,
#  'is city in': 10,
#  'is prefecture-level city in': 10,
#  'is small city in': 10,
#  'is township in': 10,
#  'town in': 10,
#  'is former borough in': 10,
#  'is incorporated city in': 10,
#  'is borough in': 10,
#  'is town in': 10,
#  'is county in': 10,
#  'is census-designated place in': 10,
#  'is city on': 10,
#  'is place in': 11,
#  'is result like': 11,
#  'is also home of': 11,
#  'is variety of': 11,
#  'is largest technological research for': 11,
#  'is further downstream than': 11,
#  'is remake of': 11,
#  'is neighborhood of': 11,
#  'additionally is heartland of': 11,
#  'is peak in': 11,
#  'is popular because of': 11,
#  'is in': 11,
#  'is': 11,
#  'is also ornament in': 11,
#  'is derived from': 11,
#  'in houston is': 11,
#  'is site of': 11,
#  'is one': 11,
#  'is region in': 11,
#  'is source of': 11,
#  'is center of': 11,
#  'is composed of': 11,
#  'father': 12,
#  'mother': 12,
#  'to': 13,
#  'be home to': 13,
#  'key to': 13,
#  'closer to': 13,
#  'moved to': 13,
#  'is home to': 13,
#  'borders louisiana to': 13,
#  'is undercurrent throughout': 14,
#  'still includes canadian arctic archipelago together with': 15,
#  'including republic is': 15,
#  'part along with': 15,
#  'performer': 16,
#  'state of': 17,
#  'is state in': 17,
#  'is third-largest state in': 17,
#  'is state of': 17,
#  'named': 18,
#  'named after': 18,
#  'occupies': 19,
#  'administered by': 20,
#  'is owned by': 20,
#  'directed by': 20,
#  'written by': 20,
#  'published by': 20,
#  'surrounded by': 20,
#  'founded by': 20,
#  'owned by': 20,
#  'shares border with': 21,
#  'however lost territory along': 21,
#  'be understood as': 22,
#  'is book by': 22,
#  'is novel by': 22,
#  'is song by': 22,
#  'known by': 22,
#  'is served by': 22,
#  'runs': 23,
#  'defines': 24,
#  'sport': 25,
#  'placed under': 26,
#  'does support': 27,
#  'support': 27,
#  'is debut single': 28,
#  'are in': 29,
#  'are': 29,
#  'are collection in': 29,
#  'produced': 30,
#  'military branch': 31,
#  'married': 32,
#  'accompanies': 33,
#  'contains administrative territorial entity': 34,
#  'located in the administrative territorial entity': 34,
#  'signing': 35,
#  'place of death': 36,
#  'place of birth': 36,
#  'one of': 36,
#  'owner of': 36,
#  'was daughter of': 36,
#  'was eldest son of': 36,
#  'president of': 36,
#  'was son of': 36,
#  'wife of': 36,
#  'instance of': 36,
#  'part of': 36,
#  'also seat of': 36,
#  "'s father is": 37,
#  "set 's": 37,
#  "'s parents is": 37,
#  "'s son is": 37,
#  'spouse': 38,
#  'taught': 39,
#  'advocated': 40,
#  'thoroughly rolled into': 41,
#  'generates': 42,
#  'buy tickets to': 43,
#  'rises in': 44,
#  'plays': 45,
#  'is located near': 46,
#  'is municipality in': 46,
#  'is commune in': 46,
#  'located in': 46,
#  'is situated in': 46,
#  'is southernmost district of': 46,
#  'is village in': 46,
#  'is situated on': 46,
#  'are located in': 46,
#  'is located in': 46,
#  'situated in': 46,
#  'is 127-mile river in': 46,
#  'include': 47,
#  'notable work': 47,
#  'cast member': 48,
#  'won': 49,
#  'dominated': 50,
#  'capital': 51,
#  'capital of': 51,
#  'developer': 52,
#  'occupation': 53,
#  'original language of work': 54,
#  'languages spoken': 54,
#  'written or signed': 54,
#  'official language': 54,
#  'native language': 54,
#  'shows': 55,
#  'follows': 56,
#  'country of citizenship': 57,
#  'country': 57,
#  'starring': 58,
#  'genre': 59,
#  'park in': 60,
#  'built in': 60,
#  'formed in': 60,
#  'died in': 60,
#  'author': 61,
#  'subclass of': 62,
#  'publisher': 63,
#  'allows': 64,
#  'became': 65,
#  'becoming': 65,
#  'was born in': 66,
#  'was marque of': 66,
#  'was succeeded by': 66,
#  'was king of': 66,
#  'was under': 66,
#  'was able': 66,
#  'was released as': 66,
#  'was known as': 66,
#  'was considered as': 66,
#  'was': 66,
#  'was taken over by': 66,
#  'was king during': 66,
#  'was born on': 66,
#  'was named as': 66,
#  'was miller from': 66,
#  'is 700-metre road in': 67,
#  'fields': 68,
#  'has': 69,
#  'has hosted soccer teams due to': 69,
#  'has after': 69,
#  'has part': 69,
#  'was director of': 70,
#  'director': 70,
#  'material used': 71,
#  'hub of': 72,
#  'instrument': 73,
#  'contains': 74,
#  'pays homage to': 75,
#  'manufacturer': 76}

# %%
with open('../../predict/cesi/rel_to_cluster_id.json', 'w') as outfile:
    json.dump(rel_to_id, outfile)
