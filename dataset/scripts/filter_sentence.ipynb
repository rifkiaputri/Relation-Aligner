# %%
import csv
import pandas as pd
import nltk
import re
from mosestokenizer import MosesTokenizer
tokenizer = MosesTokenizer('en')

# %%
sent_data = pd.read_csv('../valid_sentences.tsv', sep='\t', header=None, names=['e1_id', 'e2_id', 'rel_id', 'e1_label', 'e2_label', 'rel_label', 'sent'], quoting=csv.QUOTE_NONE)

# %%
sent_data
# Out:
#          e1_id     e2_id rel_id                          e1_label  \
# 0      Q496290      Q884   P495                             Pasta
# 1      Q275740      Q869   P131                      Kanchanaburi
# 2     Q1083043   Q215380    P31                          Christie
# 3       Q35666    Q23392   P186                           glacier
# 4     Q1238748    Q41298    P31                             Domus
# 5     Q1238748    Q41298    P31                             Domus
# 6         Q265      Q232    P47                        Uzbekistan
# 7      Q159729     Q5372   P641                 San Antonio Spurs
# 8      Q382389    Q28389   P106                   Jacques Audiard
# 9     Q2333456  Q3372216   P161                        Spider-Man
# 10     Q465282     Q7850  P1412                         Liu Xiang
# 11     Q235955      Q155    P27                 Clarice Lispector
# 12    Q1197400     Q2095   P279                           crouton
# 13    Q3187334  Q1823259   P131                             Hints
# 14      Q25235     Q7727   P527                              hour
# 15    Q2448686     Q1899   P159                  Interfax-Ukraine
# 16       Q1028       Q29    P47                           Morocco
# 17    Q1652574      Q172   P159                Manulife Financial
# 18      Q49137      Q100   P131                      Faneuil Hall
# 19     Q888344      Q794    P17                             Qeshm
# 20       Q1445     Q1159    P47                        Tamil Nadu
# 21    Q1156323      Q847   P641  United States Tennis Association
# 22     Q723513   Q334800   P127                             Lay's
# 23     Q485712       Q17    P27                      Hideki Irabu
# 24    Q3051656   Q134556    P31                        Temptation
# 25    Q1913755     Q1321  P1412                             Pollo
# 26    Q1023983      Q774    P17                       Mazatenango
# 27    Q1113804     Q1345   P159                           Comcast
# 28    Q2497882      Q889    P17                          Shindand
# 29        Q962       Q15    P30                             Benin
# ...        ...       ...    ...                               ...
# 1596   Q781877   Q482994    P31                          Stardust
# 1597   Q717956    Q18424   P131                         Unisphere
# 1598  Q2750108    Q44613   P279                            priory
# 1599   Q612373    Q11424    P31                          Fortress
# 1600      Q724   Q390141   P150                             Maine
# 1601    Q10566       Q16    P17                         Saskatoon
# 1602    Q10566       Q16    P17                         Saskatoon
# 1603  Q2622347      Q668   P495                            Wanted
# 1604    Q44122     Q8341   P136                  Django Reinhardt
# 1605  Q4734374   Q150186   P175                             Alone
# 1606  Q2956259    Q11424    P31                           Chantal
# 1607  Q3598102   Q482994    P31                                21
# 1608  Q3598102   Q482994    P31                                21
# 1609  Q3598102   Q482994    P31                                21
# 1610    Q34771      Q585   P131                      Holmenkollen
# 1611   Q775812     Q1344    P31                       Treemonisha
# 1612      Q833     Q1865   P150                          Malaysia
# 1613  Q4655519   Q235356   P279                             coach
# 1614  Q4655519   Q235356   P279                             coach
# 1615  Q2511540      Q150   P364                              Plot
# 1616  Q1469370    Q41466   P641                Pittsburgh Pirates
# 1617  Q1783243      Q847   P641                      Mary Carillo
# 1618  Q2615521    Q11424    P31                              Race
# 1619  Q2615521    Q11424    P31                              Race
# 1620  Q1510292   Q482994    P31                          Intimacy
# 1621   Q935535      Q142    P17                              Isle
# 1622    Q77558    Q33231   P106                       Thomas Ruff
# 1623   Q908848   Q215380    P31                              Devo
# 1624  Q1630424       Q27    P17                          Hospital
# 1625  Q1767236    Q22151   P175                        Unintended
#
#             e2_label                                         rel_label  \
# 0        South Korea                                 country of origin
# 1           Thailand  located in the administrative territorial entity
# 2               band                                       instance of
# 3                ice                                     material used
# 4           magazine                                       instance of
# 5           magazine                                       instance of
# 6         Kazakhstan                                shares border with
# 7         basketball                                             sport
# 8       screenwriter                                        occupation
# 9         Paul Soles                                       cast member
# 10           Chinese               languages spoken, written or signed
# 11            Brazil                            country of citizenship
# 12              food                                       subclass of
# 13         Lichfield  located in the administrative territorial entity
# 14            minute                                          has part
# 15              Kiev                             headquarters location
# 16             Spain                                shares border with
# 17           Toronto                             headquarters location
# 18            Boston  located in the administrative territorial entity
# 19              Iran                                           country
# 20    Andhra Pradesh                                shares border with
# 21            tennis                                             sport
# 22           PepsiCo                                          owned by
# 23             Japan                            country of citizenship
# 24            single                                       instance of
# 25           Spanish               languages spoken, written or signed
# 26         Guatemala                                           country
# 27      Philadelphia                             headquarters location
# 28       Afghanistan                                           country
# 29            Africa                                         continent
# ...              ...                                               ...
# 1596           album                                       instance of
# 1597          Queens  located in the administrative territorial entity
# 1598       monastery                                       subclass of
# 1599            film                                       instance of
# 1600     York County        contains administrative territorial entity
# 1601          Canada                                           country
# 1602          Canada                                           country
# 1603           India                                 country of origin
# 1604            jazz                                             genre
# 1605             B'z                                         performer
# 1606            film                                       instance of
# 1607           album                                       instance of
# 1608           album                                       instance of
# 1609           album                                       instance of
# 1610            Oslo  located in the administrative territorial entity
# 1611           opera                                       instance of
# 1612    Kuala Lumpur        contains administrative territorial entity
# 1613        carriage                                       subclass of
# 1614        carriage                                       subclass of
# 1615          French                         original language of work
# 1616      ice hockey                                             sport
# 1617          tennis                                             sport
# 1618            film                                       instance of
# 1619            film                                       instance of
# 1620           album                                       instance of
# 1621          France                                           country
# 1622    photographer                                        occupation
# 1623            band                                       instance of
# 1624         Ireland                                           country
# 1625            Muse                                         performer
#
#                                                    sent
# 0     Pasta (Hangul: 파스타) is a 2010 South Korean tel...
# 1     Kanchanaburi is the largest of the western pro...
# 2     Christie is an English rock band that formed a...
# 3     A glacier is a persistent body of dense ice th...
# 4     Domus is an architecture and design magazine f...
# 5     Published by Editoriale Domus, the magazine is...
# 6     Uzbekistan is bordered by five landlocked coun...
# 7     The San Antonio Spurs are an American professi...
# 8     Jacques Audiard is a French film director and ...
# 9     The show starred the voice of Paul Soles as Pe...
# 10    Liu Xiang, born Liu Gengsheng and bearing the ...
# 11    Clarice Lispector was a Brazilian writer accla...
# 12    A crouton is a piece of sautéed or rebaked bre...
# 13    Hints is a small village and civil parish betw...
# 14    As a unit of time, the minute is most of times...
# 15    The Interfax-Ukraine News Agency is a Kiev-bas...
# 16    The African enclaves of Ceuta and Melilla make...
# 17    Manulife Financial Corporation is a Canadian m...
# 18    Faneuil Hall, located near the waterfront and ...
# 19    Qeshm is a coastal city and capital of Qeshm C...
# 20    Tamil Nadu lies in the southernmost part of th...
# 21    The United States Tennis Association (USTA) is...
# 22    Lay's has been owned by PepsiCo through Frito-...
# 23    Hideki Irabu  was a Japanese professional base...
# 24    "Temptation" is a stand-alone single released ...
# 25    Adrián José Hernández Acosta, known as Pollo, ...
# 26    Mazatenango is a municipality in the Suchitepé...
# 27    Comcast Corporation is an American global tele...
# 28    Shīnḍanḍ is a town and the center of the Shind...
# 29    Benin, officially the Republic of Benin and fo...
# ...                                                 ...
# 1596  Stardust is the twenty-second studio album by ...
# 1597  The Unisphere is a spherical stainless steel r...
# 1598  A priory is a monastery of men or women under ...
# 1599  Fortress is a 1992 Australian-American science...
# 1600  York County is the southwesternmost county in ...
# 1601  With a 2016 census population of 246,376, Sask...
# 1602  The City of Saskatoon has estimated its popula...
# 1603  Wanted is 2009 Indian Hindi-language action fi...
# 1604  Jean Reinhardt stage name Django Reinhardt, wa...
# 1605  Alone is the ninth single by B'z, released on ...
# 1606  Chantal is a 2007 direct-to-video film written...
# 1607  21 is the second studio album by American R&B ...
# 1608  The album's title was inspired from when Omari...
# 1609  Vinyl LPs are still issued, though album sales...
# 1610  Holmenkollen is a neighborhood in the Vestre A...
# 1611  Treemonisha (1911) is an opera composed by the...
# 1612  Kuala Lumpur, officially the Federal Territory...
# 1613  A coach is originally a large, usually closed,...
# 1614  A public passenger vehicle would not usually b...
# 1615  Plot is a 1972 French-Italian thriller film di...
# 1616  The Pittsburgh Pirates were an American profes...
# 1617  Mary Carillo is a U.S. sportscaster and former...
# 1618  Race is a 2008 Indian action thriller film dir...
# 1619  The first installment of Race film series, the...
# 1620  Intimacy is the third studio album by English ...
# 1621  The Isle is a 255-kilometre (158 mi) long rive...
# 1622  Thomas Ruff is a German photographer who lives...
# 1623  Devo is an American rock band from Akron, Ohio...
# 1624  Hospital is a town in east County Limerick, Ir...
# 1625  "Unintended" is a song by English rock band Mu...
#
# [1626 rows x 7 columns]

# %%
def normalize_text(text):
    text = text.replace('"', ' ')
    text = text.replace('[note]', ' ')
    text = text.replace('(disambuguation)', ' ')
    text = text.replace('[citation needed]', ' ')
    text = text.replace('[update]', ' ')
    text = text.replace('[contradictory]', ' ')
    text = text.replace('[page needed]', ' ')
    text = re.sub(r'\[relevant\?\s*\–\s*discuss\]', ' ', text)
    text = text.replace('[clarification needed]', ' ')
    text = re.sub(r'\[[a-z]*\?\]', ' ', text)
    text = re.sub(r'\[nb\s[0-9]*\]', ' ', text)
    text = re.sub(r'\[nb\]', ' ', text)
    text = re.sub(r'\[[a-z]\]', ' ', text)
    text = re.sub(r'\[[A-Z]\]', ' ', text)
    text = re.sub(r'\[[0-9]+\]', ' ', text)
    text = re.sub(r'[a-z]\.\^', ' ', text)
    text = text.replace('[.', ' ')
    text = text.replace('[', ' ')
    sent_text = nltk.sent_tokenize(text)
    sent = sent_text[0]
    sent = ' '.join(sent.split()) # remove multiple spaces
    if not sent.endswith('.'):
        sent = sent + '.'
    return sent
    

def is_consecutive_token_in_sent_list(tokens, sent_list):
    idxs = []
    for token in tokens:
        try:
            idx = sent_list.index(token)
            idxs.append(idx)
        except ValueError:
            return False
    
    len_idx = idxs[-1] - idxs[0]
    len_token = len(tokens) - 1
    
    if len_idx != len_token:
        return False
    
    return True


def is_sent_contain_entities(e1, e2, sent):
    e1_tokens = tokenizer(e1)
    e2_tokens = tokenizer(e2)
    sent_tokens = tokenizer(sent)
    
    contain_e1 = is_consecutive_token_in_sent_list(e1_tokens, sent_tokens)
    contain_e2 = is_consecutive_token_in_sent_list(e2_tokens, sent_tokens)
    
    return contain_e1 and contain_e2

# %%
remove_idxs = []
len_data = len(sent_data['sent'])
for i in range(len_data):
    sent_data['sent'][i] = normalize_text(sent_data['sent'][i])
    is_valid = is_sent_contain_entities(sent_data['e1_label'][i], sent_data['e2_label'][i], sent_data['sent'][i])
    if is_valid == False:
        remove_idxs.append(i)

# %%
len(remove_idxs)
# Out:
# 182

# %%
sent_data.drop(sent_data.index[remove_idxs], inplace=True)

# %%
sent_data
# Out:
#          e1_id      e2_id rel_id                          e1_label  \
# 1      Q275740       Q869   P131                      Kanchanaburi
# 2     Q1083043    Q215380    P31                          Christie
# 3       Q35666     Q23392   P186                           glacier
# 4     Q1238748     Q41298    P31                             Domus
# 5     Q1238748     Q41298    P31                             Domus
# 6         Q265       Q232    P47                        Uzbekistan
# 7      Q159729      Q5372   P641                 San Antonio Spurs
# 8      Q382389     Q28389   P106                   Jacques Audiard
# 9     Q2333456   Q3372216   P161                        Spider-Man
# 10     Q465282      Q7850  P1412                         Liu Xiang
# 12    Q1197400      Q2095   P279                           crouton
# 13    Q3187334   Q1823259   P131                             Hints
# 14      Q25235      Q7727   P527                              hour
# 15    Q2448686      Q1899   P159                  Interfax-Ukraine
# 16       Q1028        Q29    P47                           Morocco
# 17    Q1652574       Q172   P159                Manulife Financial
# 18      Q49137       Q100   P131                      Faneuil Hall
# 19     Q888344       Q794    P17                             Qeshm
# 20       Q1445      Q1159    P47                        Tamil Nadu
# 21    Q1156323       Q847   P641  United States Tennis Association
# 22     Q723513    Q334800   P127                             Lay's
# 24    Q3051656    Q134556    P31                        Temptation
# 25    Q1913755      Q1321  P1412                             Pollo
# 26    Q1023983       Q774    P17                       Mazatenango
# 27    Q1113804      Q1345   P159                           Comcast
# 28    Q2497882       Q889    P17                          Shindand
# 29        Q962        Q15    P30                             Benin
# 30      Q41718     Q66117    P20                   Emiliano Zapata
# 31    Q4707609    Q134556    P31                       Electricity
# 32     Q784088    Q215380    P31                          Idlewild
# ...        ...        ...    ...                               ...
# 1592   Q650068  Q21713103   P131                        Peterhouse
# 1593   Q111074      Q1860  P1412                        John Barry
# 1594  Q2521716       Q869    P17                          Emporium
# 1595      Q889    Q121104   P150                       Afghanistan
# 1596   Q781877    Q482994    P31                          Stardust
# 1597   Q717956     Q18424   P131                         Unisphere
# 1598  Q2750108     Q44613   P279                            priory
# 1599   Q612373     Q11424    P31                          Fortress
# 1600      Q724    Q390141   P150                             Maine
# 1601    Q10566        Q16    P17                         Saskatoon
# 1602    Q10566        Q16    P17                         Saskatoon
# 1605  Q4734374    Q150186   P175                             Alone
# 1606  Q2956259     Q11424    P31                           Chantal
# 1607  Q3598102    Q482994    P31                                21
# 1608  Q3598102    Q482994    P31                                21
# 1610    Q34771       Q585   P131                      Holmenkollen
# 1611   Q775812      Q1344    P31                       Treemonisha
# 1612      Q833      Q1865   P150                          Malaysia
# 1613  Q4655519    Q235356   P279                             coach
# 1615  Q2511540       Q150   P364                              Plot
# 1616  Q1469370     Q41466   P641                Pittsburgh Pirates
# 1617  Q1783243       Q847   P641                      Mary Carillo
# 1618  Q2615521     Q11424    P31                              Race
# 1619  Q2615521     Q11424    P31                              Race
# 1620  Q1510292    Q482994    P31                          Intimacy
# 1621   Q935535       Q142    P17                              Isle
# 1622    Q77558     Q33231   P106                       Thomas Ruff
# 1623   Q908848    Q215380    P31                              Devo
# 1624  Q1630424        Q27    P17                          Hospital
# 1625  Q1767236     Q22151   P175                        Unintended
#
#             e2_label                                         rel_label  \
# 1           Thailand  located in the administrative territorial entity
# 2               band                                       instance of
# 3                ice                                     material used
# 4           magazine                                       instance of
# 5           magazine                                       instance of
# 6         Kazakhstan                                shares border with
# 7         basketball                                             sport
# 8       screenwriter                                        occupation
# 9         Paul Soles                                       cast member
# 10           Chinese               languages spoken, written or signed
# 12              food                                       subclass of
# 13         Lichfield  located in the administrative territorial entity
# 14            minute                                          has part
# 15              Kiev                             headquarters location
# 16             Spain                                shares border with
# 17           Toronto                             headquarters location
# 18            Boston  located in the administrative territorial entity
# 19              Iran                                           country
# 20    Andhra Pradesh                                shares border with
# 21            tennis                                             sport
# 22           PepsiCo                                          owned by
# 24            single                                       instance of
# 25           Spanish               languages spoken, written or signed
# 26         Guatemala                                           country
# 27      Philadelphia                             headquarters location
# 28       Afghanistan                                           country
# 29            Africa                                         continent
# 30           Morelos                                    place of death
# 31            single                                       instance of
# 32              band                                       instance of
# ...              ...                                               ...
# 1592       Cambridge  located in the administrative territorial entity
# 1593         English               languages spoken, written or signed
# 1594        Thailand                                           country
# 1595           Balkh        contains administrative territorial entity
# 1596           album                                       instance of
# 1597          Queens  located in the administrative territorial entity
# 1598       monastery                                       subclass of
# 1599            film                                       instance of
# 1600     York County        contains administrative territorial entity
# 1601          Canada                                           country
# 1602          Canada                                           country
# 1605             B'z                                         performer
# 1606            film                                       instance of
# 1607           album                                       instance of
# 1608           album                                       instance of
# 1610            Oslo  located in the administrative territorial entity
# 1611           opera                                       instance of
# 1612    Kuala Lumpur        contains administrative territorial entity
# 1613        carriage                                       subclass of
# 1615          French                         original language of work
# 1616      ice hockey                                             sport
# 1617          tennis                                             sport
# 1618            film                                       instance of
# 1619            film                                       instance of
# 1620           album                                       instance of
# 1621          France                                           country
# 1622    photographer                                        occupation
# 1623            band                                       instance of
# 1624         Ireland                                           country
# 1625            Muse                                         performer
#
#                                                    sent
# 1     Kanchanaburi is the largest of the western pro...
# 2     Christie is an English rock band that formed a...
# 3     A glacier is a persistent body of dense ice th...
# 4     Domus is an architecture and design magazine f...
# 5     Published by Editoriale Domus, the magazine is...
# 6     Uzbekistan is bordered by five landlocked coun...
# 7     The San Antonio Spurs are an American professi...
# 8     Jacques Audiard is a French film director and ...
# 9     The show starred the voice of Paul Soles as Pe...
# 10    Liu Xiang, born Liu Gengsheng and bearing the ...
# 12    A crouton is a piece of sautéed or rebaked bre...
# 13    Hints is a small village and civil parish betw...
# 14    As a unit of time, the minute is most of times...
# 15    The Interfax-Ukraine News Agency is a Kiev-bas...
# 16    The African enclaves of Ceuta and Melilla make...
# 17    Manulife Financial Corporation is a Canadian m...
# 18    Faneuil Hall, located near the waterfront and ...
# 19    Qeshm is a coastal city and capital of Qeshm C...
# 20    Tamil Nadu lies in the southernmost part of th...
# 21    The United States Tennis Association (USTA) is...
# 22    Lay's has been owned by PepsiCo through Frito-...
# 24    Temptation is a stand-alone single released by...
# 25    Adrián José Hernández Acosta, known as Pollo, ...
# 26    Mazatenango is a municipality in the Suchitepé...
# 27    Comcast Corporation is an American global tele...
# 28    Shīnḍanḍ is a town and the center of the Shind...
# 29    Benin, officially the Republic of Benin and fo...
# 30    Emiliano Zapata Salazar was a leading figure i...
# 31    Electricity is the 1979 debut single of the En...
# 32    Idlewild are a Scottish indie rock band that f...
# ...                                                 ...
# 1592  Peterhouse is a constituent college of the Uni...
# 1593  John Barry Prendergast, was an English compose...
# 1594  Emporium is a luxury shopping mall in Khlong T...
# 1595  Balkh is one of the 34 provinces of Afghanista...
# 1596  Stardust is the twenty-second studio album by ...
# 1597  The Unisphere is a spherical stainless steel r...
# 1598  A priory is a monastery of men or women under ...
# 1599  Fortress is a 1992 Australian-American science...
# 1600  York County is the southwesternmost county in ...
# 1601  With a 2016 census population of 246,376, Sask...
# 1602  The City of Saskatoon has estimated its popula...
# 1605  Alone is the ninth single by B'z, released on ...
# 1606  Chantal is a 2007 direct-to-video film written...
# 1607  21 is the second studio album by American R&B ...
# 1608  The album's title was inspired from when Omari...
# 1610  Holmenkollen is a neighborhood in the Vestre A...
# 1611  Treemonisha (1911) is an opera composed by the...
# 1612  Kuala Lumpur, officially the Federal Territory...
# 1613  A coach is originally a large, usually closed,...
# 1615  Plot is a 1972 French-Italian thriller film di...
# 1616  The Pittsburgh Pirates were an American profes...
# 1617  Mary Carillo is a U.S. sportscaster and former...
# 1618  Race is a 2008 Indian action thriller film dir...
# 1619  The first installment of Race film series, the...
# 1620  Intimacy is the third studio album by English ...
# 1621  The Isle is a 255-kilometre (158 mi) long rive...
# 1622  Thomas Ruff is a German photographer who lives...
# 1623  Devo is an American rock band from Akron, Ohio...
# 1624  Hospital is a town in east County Limerick, Ir...
# 1625  Unintended is a song by English rock band Muse...
#
# [1444 rows x 7 columns]

# %%
sent_data.to_csv('../valid_sentences_filtered.tsv', sep='\t', header=False, index=False)

# %% [markdown]
# ### Cut Sentence Number

# %%
sent_data = pd.read_csv('../valid_sentences_filtered.tsv', sep='\t', header=None, names=['e1_id', 'e2_id', 'rel_id', 'e1_label', 'e2_label', 'rel_label', 'sent'], quoting=csv.QUOTE_NONE)

# %%
sent_data
# Out:
#          e1_id      e2_id rel_id                          e1_label  \
# 0      Q275740       Q869   P131                      Kanchanaburi
# 1     Q1083043    Q215380    P31                          Christie
# 2       Q35666     Q23392   P186                           glacier
# 3     Q1238748     Q41298    P31                             Domus
# 4     Q1238748     Q41298    P31                             Domus
# 5         Q265       Q232    P47                        Uzbekistan
# 6      Q159729      Q5372   P641                 San Antonio Spurs
# 7      Q382389     Q28389   P106                   Jacques Audiard
# 8     Q2333456   Q3372216   P161                        Spider-Man
# 9      Q465282      Q7850  P1412                         Liu Xiang
# 10    Q1197400      Q2095   P279                           crouton
# 11    Q3187334   Q1823259   P131                             Hints
# 12      Q25235      Q7727   P527                              hour
# 13    Q2448686      Q1899   P159                  Interfax-Ukraine
# 14       Q1028        Q29    P47                           Morocco
# 15    Q1652574       Q172   P159                Manulife Financial
# 16      Q49137       Q100   P131                      Faneuil Hall
# 17     Q888344       Q794    P17                             Qeshm
# 18       Q1445      Q1159    P47                        Tamil Nadu
# 19    Q1156323       Q847   P641  United States Tennis Association
# 20     Q723513    Q334800   P127                             Lay's
# 21    Q3051656    Q134556    P31                        Temptation
# 22    Q1913755      Q1321  P1412                             Pollo
# 23    Q1023983       Q774    P17                       Mazatenango
# 24    Q1113804      Q1345   P159                           Comcast
# 25    Q2497882       Q889    P17                          Shindand
# 26        Q962        Q15    P30                             Benin
# 27      Q41718     Q66117    P20                   Emiliano Zapata
# 28    Q4707609    Q134556    P31                       Electricity
# 29     Q784088    Q215380    P31                          Idlewild
# ...        ...        ...    ...                               ...
# 1414   Q650068  Q21713103   P131                        Peterhouse
# 1415   Q111074      Q1860  P1412                        John Barry
# 1416  Q2521716       Q869    P17                          Emporium
# 1417      Q889    Q121104   P150                       Afghanistan
# 1418   Q781877    Q482994    P31                          Stardust
# 1419   Q717956     Q18424   P131                         Unisphere
# 1420  Q2750108     Q44613   P279                            priory
# 1421   Q612373     Q11424    P31                          Fortress
# 1422      Q724    Q390141   P150                             Maine
# 1423    Q10566        Q16    P17                         Saskatoon
# 1424    Q10566        Q16    P17                         Saskatoon
# 1425  Q4734374    Q150186   P175                             Alone
# 1426  Q2956259     Q11424    P31                           Chantal
# 1427  Q3598102    Q482994    P31                                21
# 1428  Q3598102    Q482994    P31                                21
# 1429    Q34771       Q585   P131                      Holmenkollen
# 1430   Q775812      Q1344    P31                       Treemonisha
# 1431      Q833      Q1865   P150                          Malaysia
# 1432  Q4655519    Q235356   P279                             coach
# 1433  Q2511540       Q150   P364                              Plot
# 1434  Q1469370     Q41466   P641                Pittsburgh Pirates
# 1435  Q1783243       Q847   P641                      Mary Carillo
# 1436  Q2615521     Q11424    P31                              Race
# 1437  Q2615521     Q11424    P31                              Race
# 1438  Q1510292    Q482994    P31                          Intimacy
# 1439   Q935535       Q142    P17                              Isle
# 1440    Q77558     Q33231   P106                       Thomas Ruff
# 1441   Q908848    Q215380    P31                              Devo
# 1442  Q1630424        Q27    P17                          Hospital
# 1443  Q1767236     Q22151   P175                        Unintended
#
#             e2_label                                         rel_label  \
# 0           Thailand  located in the administrative territorial entity
# 1               band                                       instance of
# 2                ice                                     material used
# 3           magazine                                       instance of
# 4           magazine                                       instance of
# 5         Kazakhstan                                shares border with
# 6         basketball                                             sport
# 7       screenwriter                                        occupation
# 8         Paul Soles                                       cast member
# 9            Chinese               languages spoken, written or signed
# 10              food                                       subclass of
# 11         Lichfield  located in the administrative territorial entity
# 12            minute                                          has part
# 13              Kiev                             headquarters location
# 14             Spain                                shares border with
# 15           Toronto                             headquarters location
# 16            Boston  located in the administrative territorial entity
# 17              Iran                                           country
# 18    Andhra Pradesh                                shares border with
# 19            tennis                                             sport
# 20           PepsiCo                                          owned by
# 21            single                                       instance of
# 22           Spanish               languages spoken, written or signed
# 23         Guatemala                                           country
# 24      Philadelphia                             headquarters location
# 25       Afghanistan                                           country
# 26            Africa                                         continent
# 27           Morelos                                    place of death
# 28            single                                       instance of
# 29              band                                       instance of
# ...              ...                                               ...
# 1414       Cambridge  located in the administrative territorial entity
# 1415         English               languages spoken, written or signed
# 1416        Thailand                                           country
# 1417           Balkh        contains administrative territorial entity
# 1418           album                                       instance of
# 1419          Queens  located in the administrative territorial entity
# 1420       monastery                                       subclass of
# 1421            film                                       instance of
# 1422     York County        contains administrative territorial entity
# 1423          Canada                                           country
# 1424          Canada                                           country
# 1425             B'z                                         performer
# 1426            film                                       instance of
# 1427           album                                       instance of
# 1428           album                                       instance of
# 1429            Oslo  located in the administrative territorial entity
# 1430           opera                                       instance of
# 1431    Kuala Lumpur        contains administrative territorial entity
# 1432        carriage                                       subclass of
# 1433          French                         original language of work
# 1434      ice hockey                                             sport
# 1435          tennis                                             sport
# 1436            film                                       instance of
# 1437            film                                       instance of
# 1438           album                                       instance of
# 1439          France                                           country
# 1440    photographer                                        occupation
# 1441            band                                       instance of
# 1442         Ireland                                           country
# 1443            Muse                                         performer
#
#                                                    sent
# 0     Kanchanaburi is the largest of the western pro...
# 1     Christie is an English rock band that formed a...
# 2     A glacier is a persistent body of dense ice th...
# 3     Domus is an architecture and design magazine f...
# 4     Published by Editoriale Domus, the magazine is...
# 5     Uzbekistan is bordered by five landlocked coun...
# 6     The San Antonio Spurs are an American professi...
# 7     Jacques Audiard is a French film director and ...
# 8     The show starred the voice of Paul Soles as Pe...
# 9     Liu Xiang, born Liu Gengsheng and bearing the ...
# 10    A crouton is a piece of sautéed or rebaked bre...
# 11    Hints is a small village and civil parish betw...
# 12    As a unit of time, the minute is most of times...
# 13    The Interfax-Ukraine News Agency is a Kiev-bas...
# 14    The African enclaves of Ceuta and Melilla make...
# 15    Manulife Financial Corporation is a Canadian m...
# 16    Faneuil Hall, located near the waterfront and ...
# 17    Qeshm is a coastal city and capital of Qeshm C...
# 18    Tamil Nadu lies in the southernmost part of th...
# 19    The United States Tennis Association (USTA) is...
# 20    Lay's has been owned by PepsiCo through Frito-...
# 21    Temptation is a stand-alone single released by...
# 22    Adrián José Hernández Acosta, known as Pollo, ...
# 23    Mazatenango is a municipality in the Suchitepé...
# 24    Comcast Corporation is an American global tele...
# 25    Shīnḍanḍ is a town and the center of the Shind...
# 26    Benin, officially the Republic of Benin and fo...
# 27    Emiliano Zapata Salazar was a leading figure i...
# 28    Electricity is the 1979 debut single of the En...
# 29    Idlewild are a Scottish indie rock band that f...
# ...                                                 ...
# 1414  Peterhouse is a constituent college of the Uni...
# 1415  John Barry Prendergast, was an English compose...
# 1416  Emporium is a luxury shopping mall in Khlong T...
# 1417  Balkh is one of the 34 provinces of Afghanista...
# 1418  Stardust is the twenty-second studio album by ...
# 1419  The Unisphere is a spherical stainless steel r...
# 1420  A priory is a monastery of men or women under ...
# 1421  Fortress is a 1992 Australian-American science...
# 1422  York County is the southwesternmost county in ...
# 1423  With a 2016 census population of 246,376, Sask...
# 1424  The City of Saskatoon has estimated its popula...
# 1425  Alone is the ninth single by B'z, released on ...
# 1426  Chantal is a 2007 direct-to-video film written...
# 1427  21 is the second studio album by American R&B ...
# 1428  The album's title was inspired from when Omari...
# 1429  Holmenkollen is a neighborhood in the Vestre A...
# 1430  Treemonisha (1911) is an opera composed by the...
# 1431  Kuala Lumpur, officially the Federal Territory...
# 1432  A coach is originally a large, usually closed,...
# 1433  Plot is a 1972 French-Italian thriller film di...
# 1434  The Pittsburgh Pirates were an American profes...
# 1435  Mary Carillo is a U.S. sportscaster and former...
# 1436  Race is a 2008 Indian action thriller film dir...
# 1437  The first installment of Race film series, the...
# 1438  Intimacy is the third studio album by English ...
# 1439  The Isle is a 255-kilometre (158 mi) long rive...
# 1440  Thomas Ruff is a German photographer who lives...
# 1441  Devo is an American rock band from Akron, Ohio...
# 1442  Hospital is a town in east County Limerick, Ir...
# 1443  Unintended is a song by English rock band Muse...
#
# [1444 rows x 7 columns]

# %%
sent_data = sent_data.drop_duplicates()
sent_data = sent_data.reset_index(drop=True)

# %%
sent_data
# Out:
#          e1_id      e2_id rel_id                          e1_label  \
# 0      Q275740       Q869   P131                      Kanchanaburi
# 1     Q1083043    Q215380    P31                          Christie
# 2       Q35666     Q23392   P186                           glacier
# 3     Q1238748     Q41298    P31                             Domus
# 4     Q1238748     Q41298    P31                             Domus
# 5         Q265       Q232    P47                        Uzbekistan
# 6      Q159729      Q5372   P641                 San Antonio Spurs
# 7      Q382389     Q28389   P106                   Jacques Audiard
# 8     Q2333456   Q3372216   P161                        Spider-Man
# 9      Q465282      Q7850  P1412                         Liu Xiang
# 10    Q1197400      Q2095   P279                           crouton
# 11    Q3187334   Q1823259   P131                             Hints
# 12      Q25235      Q7727   P527                              hour
# 13    Q2448686      Q1899   P159                  Interfax-Ukraine
# 14       Q1028        Q29    P47                           Morocco
# 15    Q1652574       Q172   P159                Manulife Financial
# 16      Q49137       Q100   P131                      Faneuil Hall
# 17     Q888344       Q794    P17                             Qeshm
# 18       Q1445      Q1159    P47                        Tamil Nadu
# 19    Q1156323       Q847   P641  United States Tennis Association
# 20     Q723513    Q334800   P127                             Lay's
# 21    Q3051656    Q134556    P31                        Temptation
# 22    Q1913755      Q1321  P1412                             Pollo
# 23    Q1023983       Q774    P17                       Mazatenango
# 24    Q1113804      Q1345   P159                           Comcast
# 25    Q2497882       Q889    P17                          Shindand
# 26        Q962        Q15    P30                             Benin
# 27      Q41718     Q66117    P20                   Emiliano Zapata
# 28    Q4707609    Q134556    P31                       Electricity
# 29     Q784088    Q215380    P31                          Idlewild
# ...        ...        ...    ...                               ...
# 1369  Q1197754       Q150   P364                      Incorrigible
# 1370   Q464813     Q36834   P106                           Chen Yi
# 1371   Q650068  Q21713103   P131                        Peterhouse
# 1372   Q111074      Q1860  P1412                        John Barry
# 1373  Q2521716       Q869    P17                          Emporium
# 1374   Q781877    Q482994    P31                          Stardust
# 1375  Q2750108     Q44613   P279                            priory
# 1376   Q612373     Q11424    P31                          Fortress
# 1377      Q724    Q390141   P150                             Maine
# 1378    Q10566        Q16    P17                         Saskatoon
# 1379    Q10566        Q16    P17                         Saskatoon
# 1380  Q4734374    Q150186   P175                             Alone
# 1381  Q2956259     Q11424    P31                           Chantal
# 1382  Q3598102    Q482994    P31                                21
# 1383  Q3598102    Q482994    P31                                21
# 1384    Q34771       Q585   P131                      Holmenkollen
# 1385   Q775812      Q1344    P31                       Treemonisha
# 1386      Q833      Q1865   P150                          Malaysia
# 1387  Q4655519    Q235356   P279                             coach
# 1388  Q2511540       Q150   P364                              Plot
# 1389  Q1469370     Q41466   P641                Pittsburgh Pirates
# 1390  Q1783243       Q847   P641                      Mary Carillo
# 1391  Q2615521     Q11424    P31                              Race
# 1392  Q2615521     Q11424    P31                              Race
# 1393  Q1510292    Q482994    P31                          Intimacy
# 1394   Q935535       Q142    P17                              Isle
# 1395    Q77558     Q33231   P106                       Thomas Ruff
# 1396   Q908848    Q215380    P31                              Devo
# 1397  Q1630424        Q27    P17                          Hospital
# 1398  Q1767236     Q22151   P175                        Unintended
#
#             e2_label                                         rel_label  \
# 0           Thailand  located in the administrative territorial entity
# 1               band                                       instance of
# 2                ice                                     material used
# 3           magazine                                       instance of
# 4           magazine                                       instance of
# 5         Kazakhstan                                shares border with
# 6         basketball                                             sport
# 7       screenwriter                                        occupation
# 8         Paul Soles                                       cast member
# 9            Chinese               languages spoken, written or signed
# 10              food                                       subclass of
# 11         Lichfield  located in the administrative territorial entity
# 12            minute                                          has part
# 13              Kiev                             headquarters location
# 14             Spain                                shares border with
# 15           Toronto                             headquarters location
# 16            Boston  located in the administrative territorial entity
# 17              Iran                                           country
# 18    Andhra Pradesh                                shares border with
# 19            tennis                                             sport
# 20           PepsiCo                                          owned by
# 21            single                                       instance of
# 22           Spanish               languages spoken, written or signed
# 23         Guatemala                                           country
# 24      Philadelphia                             headquarters location
# 25       Afghanistan                                           country
# 26            Africa                                         continent
# 27           Morelos                                    place of death
# 28            single                                       instance of
# 29              band                                       instance of
# ...              ...                                               ...
# 1369          French                         original language of work
# 1370        composer                                        occupation
# 1371       Cambridge  located in the administrative territorial entity
# 1372         English               languages spoken, written or signed
# 1373        Thailand                                           country
# 1374           album                                       instance of
# 1375       monastery                                       subclass of
# 1376            film                                       instance of
# 1377     York County        contains administrative territorial entity
# 1378          Canada                                           country
# 1379          Canada                                           country
# 1380             B'z                                         performer
# 1381            film                                       instance of
# 1382           album                                       instance of
# 1383           album                                       instance of
# 1384            Oslo  located in the administrative territorial entity
# 1385           opera                                       instance of
# 1386    Kuala Lumpur        contains administrative territorial entity
# 1387        carriage                                       subclass of
# 1388          French                         original language of work
# 1389      ice hockey                                             sport
# 1390          tennis                                             sport
# 1391            film                                       instance of
# 1392            film                                       instance of
# 1393           album                                       instance of
# 1394          France                                           country
# 1395    photographer                                        occupation
# 1396            band                                       instance of
# 1397         Ireland                                           country
# 1398            Muse                                         performer
#
#                                                    sent
# 0     Kanchanaburi is the largest of the western pro...
# 1     Christie is an English rock band that formed a...
# 2     A glacier is a persistent body of dense ice th...
# 3     Domus is an architecture and design magazine f...
# 4     Published by Editoriale Domus, the magazine is...
# 5     Uzbekistan is bordered by five landlocked coun...
# 6     The San Antonio Spurs are an American professi...
# 7     Jacques Audiard is a French film director and ...
# 8     The show starred the voice of Paul Soles as Pe...
# 9     Liu Xiang, born Liu Gengsheng and bearing the ...
# 10    A crouton is a piece of sautéed or rebaked bre...
# 11    Hints is a small village and civil parish betw...
# 12    As a unit of time, the minute is most of times...
# 13    The Interfax-Ukraine News Agency is a Kiev-bas...
# 14    The African enclaves of Ceuta and Melilla make...
# 15    Manulife Financial Corporation is a Canadian m...
# 16    Faneuil Hall, located near the waterfront and ...
# 17    Qeshm is a coastal city and capital of Qeshm C...
# 18    Tamil Nadu lies in the southernmost part of th...
# 19    The United States Tennis Association (USTA) is...
# 20    Lay's has been owned by PepsiCo through Frito-...
# 21    Temptation is a stand-alone single released by...
# 22    Adrián José Hernández Acosta, known as Pollo, ...
# 23    Mazatenango is a municipality in the Suchitepé...
# 24    Comcast Corporation is an American global tele...
# 25    Shīnḍanḍ is a town and the center of the Shind...
# 26    Benin, officially the Republic of Benin and fo...
# 27    Emiliano Zapata Salazar was a leading figure i...
# 28    Electricity is the 1979 debut single of the En...
# 29    Idlewild are a Scottish indie rock band that f...
# ...                                                 ...
# 1369  Incorrigible is a 1975 French comedy film dire...
# 1370  Chen Yi is a Chinese violinist and composer of...
# 1371  Peterhouse is a constituent college of the Uni...
# 1372  John Barry Prendergast, was an English compose...
# 1373  Emporium is a luxury shopping mall in Khlong T...
# 1374  Stardust is the twenty-second studio album by ...
# 1375  A priory is a monastery of men or women under ...
# 1376  Fortress is a 1992 Australian-American science...
# 1377  York County is the southwesternmost county in ...
# 1378  With a 2016 census population of 246,376, Sask...
# 1379  The City of Saskatoon has estimated its popula...
# 1380  Alone is the ninth single by B'z, released on ...
# 1381  Chantal is a 2007 direct-to-video film written...
# 1382  21 is the second studio album by American R&B ...
# 1383  The album's title was inspired from when Omari...
# 1384  Holmenkollen is a neighborhood in the Vestre A...
# 1385  Treemonisha (1911) is an opera composed by the...
# 1386  Kuala Lumpur, officially the Federal Territory...
# 1387  A coach is originally a large, usually closed,...
# 1388  Plot is a 1972 French-Italian thriller film di...
# 1389  The Pittsburgh Pirates were an American profes...
# 1390  Mary Carillo is a U.S. sportscaster and former...
# 1391  Race is a 2008 Indian action thriller film dir...
# 1392  The first installment of Race film series, the...
# 1393  Intimacy is the third studio album by English ...
# 1394  The Isle is a 255-kilometre (158 mi) long rive...
# 1395  Thomas Ruff is a German photographer who lives...
# 1396  Devo is an American rock band from Akron, Ohio...
# 1397  Hospital is a town in east County Limerick, Ir...
# 1398  Unintended is a song by English rock band Muse...
#
# [1399 rows x 7 columns]

# %%
max_sent = 40
rem_ids = []
len_data = len(sent_data['sent'])
sent_num = 0
prev_triple = sent_data['e1_id'][0] + ' ' + sent_data['rel_id'][0] + ' ' + sent_data['e2_id'][0]
for i in range(len_data):
    curr_triple = sent_data['e1_id'][i] + ' ' + sent_data['rel_id'][i] + ' ' + sent_data['e2_id'][i]
    if prev_triple == curr_triple:
        sent_num += 1
        if sent_num > max_sent:
            rem_ids.append(i)
    else:
        sent_num = 1
        prev_triple = curr_triple

# %%
len(rem_ids)
# Out:
# 0

# %%
sent_data.drop(sent_data.index[rem_ids], inplace=True)

# %%
sent_data
# Out:
#          e1_id      e2_id rel_id                          e1_label  \
# 0      Q275740       Q869   P131                      Kanchanaburi
# 1     Q1083043    Q215380    P31                          Christie
# 2       Q35666     Q23392   P186                           glacier
# 3     Q1238748     Q41298    P31                             Domus
# 4     Q1238748     Q41298    P31                             Domus
# 5         Q265       Q232    P47                        Uzbekistan
# 6      Q159729      Q5372   P641                 San Antonio Spurs
# 7      Q382389     Q28389   P106                   Jacques Audiard
# 8     Q2333456   Q3372216   P161                        Spider-Man
# 9      Q465282      Q7850  P1412                         Liu Xiang
# 10    Q1197400      Q2095   P279                           crouton
# 11    Q3187334   Q1823259   P131                             Hints
# 12      Q25235      Q7727   P527                              hour
# 13    Q2448686      Q1899   P159                  Interfax-Ukraine
# 14       Q1028        Q29    P47                           Morocco
# 15    Q1652574       Q172   P159                Manulife Financial
# 16      Q49137       Q100   P131                      Faneuil Hall
# 17     Q888344       Q794    P17                             Qeshm
# 18       Q1445      Q1159    P47                        Tamil Nadu
# 19    Q1156323       Q847   P641  United States Tennis Association
# 20     Q723513    Q334800   P127                             Lay's
# 21    Q3051656    Q134556    P31                        Temptation
# 22    Q1913755      Q1321  P1412                             Pollo
# 23    Q1023983       Q774    P17                       Mazatenango
# 24    Q1113804      Q1345   P159                           Comcast
# 25    Q2497882       Q889    P17                          Shindand
# 26        Q962        Q15    P30                             Benin
# 27      Q41718     Q66117    P20                   Emiliano Zapata
# 28    Q4707609    Q134556    P31                       Electricity
# 29     Q784088    Q215380    P31                          Idlewild
# ...        ...        ...    ...                               ...
# 1369  Q1197754       Q150   P364                      Incorrigible
# 1370   Q464813     Q36834   P106                           Chen Yi
# 1371   Q650068  Q21713103   P131                        Peterhouse
# 1372   Q111074      Q1860  P1412                        John Barry
# 1373  Q2521716       Q869    P17                          Emporium
# 1374   Q781877    Q482994    P31                          Stardust
# 1375  Q2750108     Q44613   P279                            priory
# 1376   Q612373     Q11424    P31                          Fortress
# 1377      Q724    Q390141   P150                             Maine
# 1378    Q10566        Q16    P17                         Saskatoon
# 1379    Q10566        Q16    P17                         Saskatoon
# 1380  Q4734374    Q150186   P175                             Alone
# 1381  Q2956259     Q11424    P31                           Chantal
# 1382  Q3598102    Q482994    P31                                21
# 1383  Q3598102    Q482994    P31                                21
# 1384    Q34771       Q585   P131                      Holmenkollen
# 1385   Q775812      Q1344    P31                       Treemonisha
# 1386      Q833      Q1865   P150                          Malaysia
# 1387  Q4655519    Q235356   P279                             coach
# 1388  Q2511540       Q150   P364                              Plot
# 1389  Q1469370     Q41466   P641                Pittsburgh Pirates
# 1390  Q1783243       Q847   P641                      Mary Carillo
# 1391  Q2615521     Q11424    P31                              Race
# 1392  Q2615521     Q11424    P31                              Race
# 1393  Q1510292    Q482994    P31                          Intimacy
# 1394   Q935535       Q142    P17                              Isle
# 1395    Q77558     Q33231   P106                       Thomas Ruff
# 1396   Q908848    Q215380    P31                              Devo
# 1397  Q1630424        Q27    P17                          Hospital
# 1398  Q1767236     Q22151   P175                        Unintended
#
#             e2_label                                         rel_label  \
# 0           Thailand  located in the administrative territorial entity
# 1               band                                       instance of
# 2                ice                                     material used
# 3           magazine                                       instance of
# 4           magazine                                       instance of
# 5         Kazakhstan                                shares border with
# 6         basketball                                             sport
# 7       screenwriter                                        occupation
# 8         Paul Soles                                       cast member
# 9            Chinese               languages spoken, written or signed
# 10              food                                       subclass of
# 11         Lichfield  located in the administrative territorial entity
# 12            minute                                          has part
# 13              Kiev                             headquarters location
# 14             Spain                                shares border with
# 15           Toronto                             headquarters location
# 16            Boston  located in the administrative territorial entity
# 17              Iran                                           country
# 18    Andhra Pradesh                                shares border with
# 19            tennis                                             sport
# 20           PepsiCo                                          owned by
# 21            single                                       instance of
# 22           Spanish               languages spoken, written or signed
# 23         Guatemala                                           country
# 24      Philadelphia                             headquarters location
# 25       Afghanistan                                           country
# 26            Africa                                         continent
# 27           Morelos                                    place of death
# 28            single                                       instance of
# 29              band                                       instance of
# ...              ...                                               ...
# 1369          French                         original language of work
# 1370        composer                                        occupation
# 1371       Cambridge  located in the administrative territorial entity
# 1372         English               languages spoken, written or signed
# 1373        Thailand                                           country
# 1374           album                                       instance of
# 1375       monastery                                       subclass of
# 1376            film                                       instance of
# 1377     York County        contains administrative territorial entity
# 1378          Canada                                           country
# 1379          Canada                                           country
# 1380             B'z                                         performer
# 1381            film                                       instance of
# 1382           album                                       instance of
# 1383           album                                       instance of
# 1384            Oslo  located in the administrative territorial entity
# 1385           opera                                       instance of
# 1386    Kuala Lumpur        contains administrative territorial entity
# 1387        carriage                                       subclass of
# 1388          French                         original language of work
# 1389      ice hockey                                             sport
# 1390          tennis                                             sport
# 1391            film                                       instance of
# 1392            film                                       instance of
# 1393           album                                       instance of
# 1394          France                                           country
# 1395    photographer                                        occupation
# 1396            band                                       instance of
# 1397         Ireland                                           country
# 1398            Muse                                         performer
#
#                                                    sent
# 0     Kanchanaburi is the largest of the western pro...
# 1     Christie is an English rock band that formed a...
# 2     A glacier is a persistent body of dense ice th...
# 3     Domus is an architecture and design magazine f...
# 4     Published by Editoriale Domus, the magazine is...
# 5     Uzbekistan is bordered by five landlocked coun...
# 6     The San Antonio Spurs are an American professi...
# 7     Jacques Audiard is a French film director and ...
# 8     The show starred the voice of Paul Soles as Pe...
# 9     Liu Xiang, born Liu Gengsheng and bearing the ...
# 10    A crouton is a piece of sautéed or rebaked bre...
# 11    Hints is a small village and civil parish betw...
# 12    As a unit of time, the minute is most of times...
# 13    The Interfax-Ukraine News Agency is a Kiev-bas...
# 14    The African enclaves of Ceuta and Melilla make...
# 15    Manulife Financial Corporation is a Canadian m...
# 16    Faneuil Hall, located near the waterfront and ...
# 17    Qeshm is a coastal city and capital of Qeshm C...
# 18    Tamil Nadu lies in the southernmost part of th...
# 19    The United States Tennis Association (USTA) is...
# 20    Lay's has been owned by PepsiCo through Frito-...
# 21    Temptation is a stand-alone single released by...
# 22    Adrián José Hernández Acosta, known as Pollo, ...
# 23    Mazatenango is a municipality in the Suchitepé...
# 24    Comcast Corporation is an American global tele...
# 25    Shīnḍanḍ is a town and the center of the Shind...
# 26    Benin, officially the Republic of Benin and fo...
# 27    Emiliano Zapata Salazar was a leading figure i...
# 28    Electricity is the 1979 debut single of the En...
# 29    Idlewild are a Scottish indie rock band that f...
# ...                                                 ...
# 1369  Incorrigible is a 1975 French comedy film dire...
# 1370  Chen Yi is a Chinese violinist and composer of...
# 1371  Peterhouse is a constituent college of the Uni...
# 1372  John Barry Prendergast, was an English compose...
# 1373  Emporium is a luxury shopping mall in Khlong T...
# 1374  Stardust is the twenty-second studio album by ...
# 1375  A priory is a monastery of men or women under ...
# 1376  Fortress is a 1992 Australian-American science...
# 1377  York County is the southwesternmost county in ...
# 1378  With a 2016 census population of 246,376, Sask...
# 1379  The City of Saskatoon has estimated its popula...
# 1380  Alone is the ninth single by B'z, released on ...
# 1381  Chantal is a 2007 direct-to-video film written...
# 1382  21 is the second studio album by American R&B ...
# 1383  The album's title was inspired from when Omari...
# 1384  Holmenkollen is a neighborhood in the Vestre A...
# 1385  Treemonisha (1911) is an opera composed by the...
# 1386  Kuala Lumpur, officially the Federal Territory...
# 1387  A coach is originally a large, usually closed,...
# 1388  Plot is a 1972 French-Italian thriller film di...
# 1389  The Pittsburgh Pirates were an American profes...
# 1390  Mary Carillo is a U.S. sportscaster and former...
# 1391  Race is a 2008 Indian action thriller film dir...
# 1392  The first installment of Race film series, the...
# 1393  Intimacy is the third studio album by English ...
# 1394  The Isle is a 255-kilometre (158 mi) long rive...
# 1395  Thomas Ruff is a German photographer who lives...
# 1396  Devo is an American rock band from Akron, Ohio...
# 1397  Hospital is a town in east County Limerick, Ir...
# 1398  Unintended is a song by English rock band Muse...
#
# [1399 rows x 7 columns]

# %%
sent_data.to_csv('../valid_sentences_filtered.tsv', sep='\t', header=False, index=False)

# %% [markdown]
# ### Get Sentences Only

# %%
sent_data_filtered = pd.read_csv('../train_sentences_filtered.tsv', sep='\t', header=None, names=['e1_id', 'e2_id', 'rel_id', 'e1_label', 'e2_label', 'rel_label', 'sent'], quoting=csv.QUOTE_NONE)

# %%
sent_data_filtered
# Out:
#            e1_id     e2_id rel_id          e1_label                 e2_label  \
# 0      Q18394838   Q482994    P31             Trick                    album
# 1       Q1324135     Q1563   P131         Floridita                   Havana
# 2       Q1324135     Q1563   P131         Floridita                   Havana
# 3         Q68155    Q65453    P47            Schwyz                   Illgau
# 4       Q1663240    Q11424    P31              Spun                     film
# 5        Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 6        Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 7        Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 8        Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 9        Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 10       Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 11       Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 12       Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 13       Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 14       Q130469      Q889    P17    Mazar-i-Sharif              Afghanistan
# 15       Q356033    Q33525   P279    adenocarcinoma                carcinoma
# 16       Q356033    Q33525   P279    adenocarcinoma                carcinoma
# 17       Q356033    Q33525   P279    adenocarcinoma                carcinoma
# 18       Q356033    Q33525   P279    adenocarcinoma                carcinoma
# 19       Q356033    Q33525   P279    adenocarcinoma                carcinoma
# 20      Q1768770     Q9043   P364            Hamsun                Norwegian
# 21      Q1768770     Q9043   P364            Hamsun                Norwegian
# 22      Q1768770     Q9043   P364            Hamsun                Norwegian
# 23      Q1940623   Q498162    P31            Wilson  census-designated place
# 24      Q7721463  Q5398426    P31           Twisted        television series
# 25         Q4119   Q245068   P101      Adam Carolla                 comedian
# 26       Q701443     Q2743    P31         Elisabeth                  musical
# 27       Q701443     Q2743    P31         Elisabeth                  musical
# 28       Q413940      Q623   P527   octanitrocubane                   carbon
# 29       Q170479     Q1974   P131  Vancouver Island         British Columbia
# ...          ...       ...    ...               ...                      ...
# 62140   Q1469551    Q11424    P31             Frogs                     film
# 62141   Q2142823      Q142    P27    Thierry Breton                   France
# 62142   Q2142823      Q142    P27    Thierry Breton                   France
# 62143   Q2142823      Q142    P27    Thierry Breton                   France
# 62144   Q2142823      Q142    P27    Thierry Breton                   France
# 62145   Q2142823      Q142    P27    Thierry Breton                   France
# 62146   Q1720413   Q215380    P31              Keel                     band
# 62147   Q1720413   Q215380    P31              Keel                     band
# 62148   Q1720413   Q215380    P31              Keel                     band
# 62149   Q1720413   Q215380    P31              Keel                     band
# 62150      Q8828     Q5765   P131           Majorca         Balearic Islands
# 62151      Q8828     Q5765   P131           Majorca         Balearic Islands
# 62152      Q8828     Q5765   P131           Majorca         Balearic Islands
# 62153    Q246782     Q5369   P641      Chicago Cubs                 baseball
# 62154    Q246782     Q5369   P641      Chicago Cubs                 baseball
# 62155   Q2371210     Q1204   P131         Roseville                 Illinois
# 62156    Q173158    Q33999   P106      Ben Kingsley                    actor
# 62157    Q753830   Q486168    P47          Redlands           San Bernardino
# 62158    Q753830   Q486168    P47          Redlands           San Bernardino
# 62159    Q753830   Q486168    P47          Redlands           San Bernardino
# 62160    Q753830   Q486168    P47          Redlands           San Bernardino
# 62161    Q753830   Q486168    P47          Redlands           San Bernardino
# 62162    Q753830   Q486168    P47          Redlands           San Bernardino
# 62163    Q753830   Q486168    P47          Redlands           San Bernardino
# 62164    Q753830   Q486168    P47          Redlands           San Bernardino
# 62165    Q753830   Q486168    P47          Redlands           San Bernardino
# 62166    Q753830   Q486168    P47          Redlands           San Bernardino
# 62167    Q156243      Q423    P17           Sinuiju              North Korea
# 62168   Q4165206   Q484282   P131             Berea         Box Butte County
# 62169   Q4165206   Q484282   P131             Berea         Box Butte County
#
#                                               rel_label  \
# 0                                           instance of
# 1      located in the administrative territorial entity
# 2      located in the administrative territorial entity
# 3                                    shares border with
# 4                                           instance of
# 5                                               country
# 6                                               country
# 7                                               country
# 8                                               country
# 9                                               country
# 10                                              country
# 11                                              country
# 12                                              country
# 13                                              country
# 14                                              country
# 15                                          subclass of
# 16                                          subclass of
# 17                                          subclass of
# 18                                          subclass of
# 19                                          subclass of
# 20                            original language of work
# 21                            original language of work
# 22                            original language of work
# 23                                          instance of
# 24                                          instance of
# 25                                        field of work
# 26                                          instance of
# 27                                          instance of
# 28                                             has part
# 29     located in the administrative territorial entity
# ...                                                 ...
# 62140                                       instance of
# 62141                            country of citizenship
# 62142                            country of citizenship
# 62143                            country of citizenship
# 62144                            country of citizenship
# 62145                            country of citizenship
# 62146                                       instance of
# 62147                                       instance of
# 62148                                       instance of
# 62149                                       instance of
# 62150  located in the administrative territorial entity
# 62151  located in the administrative territorial entity
# 62152  located in the administrative territorial entity
# 62153                                             sport
# 62154                                             sport
# 62155  located in the administrative territorial entity
# 62156                                        occupation
# 62157                                shares border with
# 62158                                shares border with
# 62159                                shares border with
# 62160                                shares border with
# 62161                                shares border with
# 62162                                shares border with
# 62163                                shares border with
# 62164                                shares border with
# 62165                                shares border with
# 62166                                shares border with
# 62167                                           country
# 62168  located in the administrative territorial entity
# 62169  located in the administrative territorial entity
#
#                                                     sent
# 0      Trick is the second solo album by Kele Okereke...
# 1      Floridita (Spanish pronunciation: floɾiˈðita )...
# 2      Hemingway's children also noted that in the ea...
# 3      Illgau is a municipality in Schwyz District in...
# 4      Spun is a 2002 American black comedy crime dra...
# 5      Mazar-i-Sharif (Dari/Pashto: مزار شریف‎; Mazâr...
# 6      Mazar-i-Sharif is the regional hub of northern...
# 7      Thus the ruler of North Central Afghanistan de...
# 8      Afterwards Mazar-i-Sharif became the de facto ...
# 9      The 209th Corps (Shaheen) of the Afghan Nation...
# 10     On April 1, 2011, as many as ten foreign emplo...
# 11     The city of Mazar-i-Sharif has a total populat...
# 12     Mazar-i-Sharif serves as the major trading cen...
# 13     Rail service from Mazar-i-Sharif to Uzbekistan...
# 14     As of 2017 , the country has three rail links,...
# 15     Thus invasive ductal carcinoma, the most commo...
# 16     The adenoma, lacking the carcinoma attached to...
# 17     A subtype of adenocarcinoma, the bronchioloalv...
# 18     The term adenocarcinoma is derived from adeno-...
# 19       adenocarcinoma and/or squamous cell carcinoma).
# 20     Hamsun is a 1996 internationally co-produced d...
# 21     The plans for the film have a history from 197...
# 22     The film was initially meant to be released in...
# 23     Wilson is a census-designated place (CDP) in T...
# 24     Twisted (stylized as twiƨted) was an American ...
# 25     Adam Carolla (/kəˈrɒlə/; born May 27, 1964) is...
# 26     Elisabeth is a Viennese, German-language music...
# 27     The musical tells the story of Elisabeth ( Sis...
# 28     In addition, octanitrocubane produces no water...
# 29     The southern part of Vancouver Island is the o...
# ...                                                  ...
# 62140  A reviewer from HorrorNews.net found it odd fo...
# 62141  Thierry Breton (born 15 January 1955 in Paris)...
# 62142  Widely acclaimed as a Turnaround whiz Thierry ...
# 62143  Thierry Breton held the 62nd position for his ...
# 62144  In 2012 Thierry Breton adopted the Societas Eu...
# 62145  Thierry Breton wanted France to be the first c...
# 62146  Keel is an American heavy metal band founded i...
# 62147  Bryan Jay and Dwain Miller went from Keel to f...
# 62148  Ron Keel has pursued numerous musiefore formin...
# 62149  On November 2008, Keel reunited in time to cel...
# 62150  Mallorca ( maˈʎorka ), or Majorca (/məˈjɔːrkə/...
# 62151  In 2013, Majorca was visited by nearly 9.5 mil...
# 62152  The Balearic Islands, of which Majorca forms p...
# 62153  The Chicago Cubs are an American professional ...
# 62154  The 1989 film Back to the Future Part II depic...
# 62155  Roseville is a village in Warren County, Illin...
# 62156  Sir Ben Kingsley (born Krishna Pandit Bhanji; ...
# 62157  Redlands /ˈrɛdlɪndz/ (Serrano: Tukut) is a cit...
# 62158  The Redlands Street Railway Company was incorp...
# 62159  Most Redlands street railways would pass to th...
# 62160  Pacific Electric interurban service to Redland...
# 62161  So beautifully kept was the area, with the dra...
# 62162  Congregation Emanu El, formerly located in nea...
# 62163  North Loma Linda is the area west of Mountain ...
# 62164  San Bernardino's only Jewish congregation move...
# 62165  The Heritage House holds the collection of the...
# 62166  San Bernardino is primarily served by the San ...
# 62167  A substantial portion of North Korea's interna...
# 62168  Berea is an unincorporated community and censu...
# 62169  Berea is about 10 miles (16 km) northwest of A...
#
# [62170 rows x 7 columns]

# %%
sents_only = sent_data_filtered['sent']

# %%
sents_only.to_csv('../graphene/train_sentences_filtered', sep='\t', header=False, index=False)

# %% [markdown]
# ### Divide Text

# %%
sents_only = pd.read_csv('../sentences/valid_sentences_filtered.tsv', sep='\t', header=None, names=['sent'], quoting=csv.QUOTE_NONE)

# %%
sents_only_1, sents_only_2 = sents_only[:3847], sents_only[3847:]

# %%
sents_only_1.to_csv('../sentences/valid_sentences_filtered_1.tsv', sep='\t', header=False, index=False)

# %%
sents_only_2.to_csv('../sentences/valid_sentences_filtered_2.tsv', sep='\t', header=False, index=False)

# %%
nltk.sent_tokenize('Traditional trumpet repertoire rarely calls for notes beyond this range, and the fingering tables of most method books peak at the high C, two octaves above middle C.'+'\n'+'Several trumpeters have achieved fame for their proficiency in the extreme high register, among them Maynard Ferguson, Cat Anderson, Dizzy Gillespie, Doc Severinsen, and more recently Wayne Bergeron, Thomas Gansch, James Morrison, Jon Faddis and Arturo Sandoval.')
# Out:
# ['Traditional trumpet repertoire rarely calls for notes beyond this range, and the fingering tables of most method books peak at the high C, two octaves above middle C.\nSeveral trumpeters have achieved fame for their proficiency in the extreme high register, among them Maynard Ferguson, Cat Anderson, Dizzy Gillespie, Doc Severinsen, and more recently Wayne Bergeron, Thomas Gansch, James Morrison, Jon Faddis and Arturo Sandoval.']
