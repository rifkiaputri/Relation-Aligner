# %%
import json
import pandas as pd

# %%
with open('../graphene/output_re_valid_sentences_filtered.txt') as f:
    data_dict = json.load(f)
    
df = pd.DataFrame(data_dict['sentences'])
df = df.drop(columns=['extractionMap'])

# %%
df
# Out:
#                                        originalSentence  sentenceIdx
# 0     Cantabria belongs to Green Spain , the name gi...            0
# 1     Due to the gulf stream , Cantabria , as well a...            1
# 2     In relative contrast to other regions of Spain...            2
# 3     During the Ancien Régime , the greatest jurisd...            3
# 4     Following the approval of the General Courts o...            4
# 5     Until the 13th century , Cantabria was organiz...            5
# 6     As of July 2014 , the unemployment rate in Can...            6
# 7     In 2007 , Cantabria 's growth of real GDP was ...            7
# 8     Before the construction of Pepsi Center , the ...            8
# 9     However , Denver Nuggets and Pepsi Center owne...            9
# 10    WWE chairman Vince McMahon said , Even though ...           10
# 11    On October 11 , 1945 , the Philippines became ...           11
# 12    As a founding and active member of the United ...           12
# ...

# %%
df.to_csv('../graphene/valid_sent2id.tsv', sep='\t', index=False)
