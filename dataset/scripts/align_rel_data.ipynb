# %%
import pandas as pd
import time
import spacy
nlp = spacy.load('en_core_web_md')
from tqdm import tqdm
from wikidata.client import Client
client = Client()

# %%
import nltk
import pickle

# %%
import enteater
# Out:
# Setting up Enteater [1] Loading Spacy Model ... Done
# Setting up Enteater [2] Loading Wikidata ID dictionary ... Done
# Setting up Enteater [3] Loading Wikidata-Freebase Mapping table ... Done

# %%
version = 'v10'
dt_type = 'valid'
data_kb = pd.read_csv('../' + dt_type + '_sentences.tsv', sep='\t', header=None, names=['e1_id', 'e2_id', 'rel_id', 'e1_label', 'e2_label', 'rel_label', 'sent'])
data_openie = pd.read_csv('../' + dt_type + '_openie.tsv', sep='\t', header=None, names=['has_kb_rel', 'sent_id', 'e1', 'rel', 'e2'])

# %%
data_kb
# Out:
#            e1_id      e2_id rel_id  \
# 0       Q2489949  Q22006653   P462
# 1         Q40088     Q23444   P462
# 2       Q2080084    Q838368   P462
# 3       Q2514152    Q838368   P462
# 4      Q17634359    Q838368   P462
# 5       Q4738474    Q838368   P462
# 6      Q20002488    Q838368   P462
# 7       Q3222758  Q22006653   P462
# 8        Q851395  Q22006653   P462
# 9        Q148807       Q943   P462
# 10      Q3280038    Q838368   P462
# 11      Q1138967  Q22006653   P462
# 12      Q6492060    Q838368   P462
# 13       Q647795     Q23445   P462
# 14     Q12165555     Q23445   P462
# 15       Q392530  Q22006653   P462
# 16        Q46302      Q3142   P462
# 17        Q46302      Q3142   P462
# 18        Q46302      Q3142   P462
# 19        Q46302      Q3142   P462
# 20        Q46302      Q3142   P462
# 21        Q46302      Q3142   P462
# 22       Q799202  Q22006653   P462
# 23        Q83149      Q1088   P462
# 24        Q48160     Q23445   P462
# 25      Q1219814  Q22006653   P462
# 26     Q21935651  Q22006653   P462
# 27     Q17042878  Q22006653   P462
# 28      Q7229123  Q22006653   P462
# 29      Q8954081  Q22006653   P462
# ...          ...        ...    ...
# 94128    Q784845    Q178285   P275
# 94129  Q21463683    Q334661   P275
# 94130   Q6984525      Q7603   P275
# 94131   Q4021853      Q7603   P275
# 94132  Q28444644      Q7603   P275
# 94133    Q931056    Q713244   P275
# 94134    Q250355    Q178285   P275
# 94135   Q4042577      Q7603   P275
# 94136   Q1710177      Q7603   P275
# 94137     Q46094      Q7603   P275
# 94138   Q7921362      Q7603   P275
# 94139  Q24700947    Q232932   P275
# 94140   Q7520679      Q7603   P275
# 94141   Q1409583    Q334661   P275
# 94142   Q1252865  Q10513450   P275
# 94143  Q18168774     Q79719   P275
# 94144  Q18168774     Q79719   P275
# 94145   Q3306840      Q7603   P275
# 94146   Q6607687      Q7603   P275
# 94147   Q1769157      Q7603   P275
# 94148     Q30239     Q22169   P275
# 94149        Q94    Q616526   P275
# 94150   Q1314472    Q334661   P275
# 94151   Q3700641      Q7603   P275
# 94152  Q15894894   Q3238057   P275
# 94153   Q1244713      Q7603   P275
# 94154  Q16590706    Q386474   P275
# 94155  Q18049241    Q847096  P1057
# 94156  Q18049241    Q847096  P1057
# 94157  Q14907873    Q836605  P1057
#
#                                                 e1_label  \
# 0                                   Ride a Crooked Trail
# 1                                         Carrara marble
# 2                                      Wing and a Prayer
# 3                              Terror from the Year 5000
# 4                                      Humo de Marihuana
# 5                                         Always on Duty
# 6                                        Special Mission
# 7                                        The Proud Rebel
# 8                                               Pakeezah
# 9                                                Senyera
# 10                                 The Man from Planet X
# 11                                            Crash Dive
# 12     Las Aventuras del Capitán Piluso en el Castill...
# 13                                       UE Santa Coloma
# 14                                             Félicette
# 15                                       Treasure Planet
# 16                                                 Smaug
# 17                                                 Smaug
# 18                                                 Smaug
# 19                                                 Smaug
# 20                                                 Smaug
# 21                                                 Smaug
# 22                                              Badlands
# 23                                        Flag of Norway
# 24                                       Flag of Germany
# 25                               The Sons of Katie Elder
# 26                                               Dunkirk
# 27                                     X-Men: Apocalypse
# 28                                               Popcorn
# 29                                                Tarzan
# ...                                                  ...
# 94128                                             AutoIt
# 94129                                            TressFX
# 94130                                              Neatx
# 94131                                             Xplico
# 94132                                         ChatSecure
# 94133                                          Simutrans
# 94134                                          Icy Tower
# 94135                                             LAMMPS
# 94136                               Open Journal Systems
# 94137                                       Oracle Linux
# 94138                                           Verinice
# 94139                                             JASPAR
# 94140                                   Simple Groupware
# 94141                                             Polipo
# 94142                                           LibreCAD
# 94143                                         Windows 10
# 94144                                         Windows 10
# 94145                                            MeshLab
# 94146                                          Virastyar
# 94147                                        Project.net
# 94148                                  Chinese Wikipedia
# 94149                                            Android
# 94150                                              VDPAU
# 94151                                            DaDaBIK
# 94152                                   B1 Free Archiver
# 94153                                            JSmooth
# 94154                                           LibreSSL
# 94155                                              APOA5
# 94156                                              APOA5
# 94157                                             CXCL13
#
#                              e2_label   rel_label  \
# 0                               color       color
# 1                               white       color
# 2                     black-and-white       color
# 3                     black-and-white       color
# 4                     black-and-white       color
# 5                     black-and-white       color
# 6                     black-and-white       color
# 7                               color       color
# 8                              colour       color
# 9                              yellow       color
# 10                    black-and-white       color
# 11                              color       color
# 12                    black-and-white       color
# 13                              black       color
# 14                              black       color
# 15                              color       color
# 16                                red       color
# 17                                red       color
# 18                                red       color
# 19                                red       color
# 20                                red       color
# 21                                red       color
# 22                              color       color
# 23                               blue       color
# 24                              black       color
# 25                              color       color
# 26                              color       color
# 27                              color       color
# 28                              color       color
# 29                              color       color
# ...                               ...         ...
# 94128                        freeware     license
# 94129                     MIT License     license
# 94130      GNU General Public License     license
# 94131      GNU General Public License     license
# 94132      GNU General Public License     license
# 94133                Artistic License     license
# 94134                        freeware     license
# 94135      GNU General Public License     license
# 94136      GNU General Public License     license
# 94137      GNU General Public License     license
# 94138      GNU General Public License     license
# 94139                     open access     license
# 94140      GNU General Public License     license
# 94141                     MIT License     license
# 94142                           GPLv2     license
# 94143                         license     license
# 94144                         license     license
# 94145      GNU General Public License     license
# 94146      GNU General Public License     license
# 94147      GNU General Public License     license
# 94148  GNU Free Documentation License     license
# 94149                  Apache License     license
# 94150                     MIT License     license
# 94151      GNU General Public License     license
# 94152             proprietary license     license
# 94153      GNU General Public License     license
# 94154                     ISC license     license
# 94155             human chromosome 11  chromosome
# 94156             human chromosome 11  chromosome
# 94157              human chromosome 4  chromosome
#
#                                                     sent
# 0      Ride a Crooked Trail Ride a Crooked Trail is a...
# 1      Carrara marble Carrara marble is a type of whi...
# 2      Wing and a Prayer Wing and a Prayer (also know...
# 3      Terror from the Year 5000 Terror from the Year...
# 4      Humo de Marihuana Humo de Marihuana () is an A...
# 5      Always on Duty Zu jeder Stunde (English-langua...
# 6      Special Mission Im Sonderauftrag (English-lang...
# 7      The Proud Rebel The Proud Rebel is a 1958 Amer...
# 8      Meena Kumari's performance as a golden-hearted...
# 9      Senyera The Senyera (; meaning pennon , standa...
# 10     The Man from Planet X The Man from Planet X is...
# 11     Crash Dive Crash Dive is a World War II film i...
# 12     Las Aventuras del Capitán Piluso en el Castill...
# 13     The nowadays crest still represent the icons o...
# 14     Félicette was a black-and-white stray cat, fou...
# 15     The overall look of Treasure Planet was based ...
# 16     Smaug sensed Bilbo's presence immediately, eve...
# 17     The latter were a detailed ink and watercolour...
# 18     While neither of these appeared in the origina...
# 19     On June 16, 2011, it was announced that Smaug ...
# 20     Smaug was considered one of the highlights of ...
# 21     Tolkien Calendar , the Brothers Hildebrandt de...
# 22     Badlands often have a spectacular color displa...
# 23     Flag of Norway The flag of Norway () is a red ...
# 24     Flag of Germany The flag of Germany or German ...
# 25     The Sons of Katie Elder The Sons of Katie Elde...
# 26     On 14 December 2002, the Norwegian auto carrie...
# 27     Club commented, Much of what makes X-Men: Apoc...
# 28     Popcorn varieties are broadly categorized by t...
# 29     Several Tarzan-themed products have been manuf...
# ...                                                  ...
# 94128  AutoIt AutoIt is a freeware automation languag...
# 94129  Released as part of GPUOpen AMD TressFX is fre...
# 94130  Neatx is written mostly in Python, with the ex...
# 94131  Xplico is free and open-source software, subje...
# 94132  ChatSecure is free and open source software av...
# 94133  Simutrans was developed internally as a closed...
# 94134  Icy Tower Icy Tower is a freeware computer gam...
# 94135  LAMMPS makes use of Message Passing Interface ...
# 94136  Open Journal Systems Open Journal Systems (OJS...
# 94137  Oracle Linux Oracle Linux (OL, formerly known ...
# 94138  Verinice is licensed under GNU General Public ...
# 94139  JASPAR JASPAR is an open access and widely use...
# 94140  Simple Groupware is free software released und...
# 94141  Polipo is free software released under the MIT...
# 94142  As the GNU LibreDWG library is released under ...
# 94143  A Windows 10 Pro Pack license allows upgrades ...
# 94144  Enterprise licensees may use the Windows 10 En...
# 94145  MeshLab is free and open-source software, subj...
# 94146  Virastyar is mostly coded in Microsoft Visual ...
# 94147  https://www.gartner.com/DisplayDocument?doc_cd...
# 94148  Whereas the Chinese Wikipedia is released unde...
# 94149  In a blog post from May 2008, Google mentioned...
# 94150  VDPAU Video Decode and Presentation API for Un...
# 94151  DaDaBIK was originally released in 2001 on Sou...
# 94152  B1 Free Archiver is written in C++/Qt and is r...
# 94153  It allows specifying various details on how th...
# 94154  Google has already relicensed some of its cont...
# 94155  The gene for apolipoprotein A5 (APOA5, gene ID...
# 94156  The APOA5 gene was found by comparative sequen...
# 94157  The gene for CXCL13 is located on human chromo...
#
# [94158 rows x 7 columns]

# %%
data_kb.groupby('rel_id').size().sort_values(ascending=False).to_csv('../' + version + '/' + dt_type + '_rel_kb_freq.tsv', sep='\t')

# %%
data_openie
# Out:
#         has_kb_rel  sent_id                                            e1  \
# 0                1        0                                         Trail
# 1                1        0                                 Crooked Trail
# 2                1        0                                 Crooked Trail
# 3                1        0                                         Trail
# 4                1        0                                         Trail
# 5                1        0                                 Crooked Trail
# 6                1        0                                         Trail
# 7                1        0                                 Crooked Trail
# 8                0        0                            Crooked Trail Ride
# 9                0        0  1958 American Eastmancolor Western film shot
# 10               0        0                                         Trail
# 11               0        1                 Carrara marble Carrara marble
# 12               0        1                 Carrara marble Carrara marble
# 13               0        1                 Carrara marble Carrara marble
# 14               0        1                 Carrara marble Carrara marble
# 15               1        1                 Carrara marble Carrara marble
# 16               1        1                 Carrara marble Carrara marble
# 17               0        1                 Carrara marble Carrara marble
# 18               0        1                                        marble
# 19               0        1                 Carrara marble Carrara marble
# 20               0        1                 Carrara marble Carrara marble
# 21               1        1                 Carrara marble Carrara marble
# 22               0        1                 Carrara marble Carrara marble
# 23               1        1                 Carrara marble Carrara marble
# 24               0        1                 Carrara marble Carrara marble
# 25               1        1                 Carrara marble Carrara marble
# 26               0        1                                           use
# 27               0        1                 Carrara marble Carrara marble
# 28               1        1                 Carrara marble Carrara marble
# 29               1        1                 Carrara marble Carrara marble
# ...            ...      ...                                           ...
# 829055           0    94156                                    APOA5 gene
# 829056           0    94156                                    APOA5 gene
# 829057           0    94156                                    APOA5 gene
# 829058           0    94156                                    APOA5 gene
# 829059           1    94156                                    APOA5 gene
# 829060           0    94156                                    APOA5 gene
# 829061           0    94156                                    APOA5 gene
# 829062           0    94156                                    APOA5 gene
# 829063           0    94156                                    APOA5 gene
# 829064           0    94156                                    APOA5 gene
# 829065           0    94156                                    APOA5 gene
# 829066           0    94156                                    APOA5 gene
# 829067           0    94156                                    APOA5 gene
# 829068           0    94156                                    APOA5 gene
# 829069           0    94156                                    APOA5 gene
# 829070           0    94156                                    APOA5 gene
# 829071           0    94156                                    APOA5 gene
# 829072           1    94156                                    APOA5 gene
# 829073           0    94156                                    APOA5 gene
# 829074           1    94156                                    APOA5 gene
# 829075           0    94157                                          gene
# 829076           0    94157                                          gene
# 829077           0    94157                                          gene
# 829078           0    94157                                          gene
# 829079           0    94157                                          gene
# 829080           0    94157                            human chromosome 4
# 829081           0    94157                                          gene
# 829082           0    94157                                          gene
# 829083           0    94157                                          gene
# 829084           0    94157                                          gene
#
#                        rel                                                 e2
# 0                       is  1958 American Eastmancolor Western film shot i...
# 1                       is  1958 Eastmancolor Western film shot in CinemaS...
# 2                       is                1958 Eastmancolor Western film shot
# 3                       is       1958 American Eastmancolor Western film shot
# 4                       is                1958 Eastmancolor Western film shot
# 5                       is       1958 American Eastmancolor Western film shot
# 6                       is  1958 Eastmancolor Western film shot in CinemaS...
# 7                       is  1958 American Eastmancolor Western film shot i...
# 8                  is with              former World War II hero Audie Murphy
# 9                    is in                                        CinemaScope
# 10                      is                                           American
# 11              is type of                                  marble of quality
# 12                      is     type of marble of high quality popular for use
# 13                      is  type of marble of high quality popular for use...
# 14      is type popular of                                             marble
# 15      is type popular of                                       white marble
# 16                      is    type of white marble of quality popular for use
# 17                      is        type of marble popular for use in sculpture
# 18                      is                                            popular
# 19                      is                                       type popular
# 20                      is  type of marble of quality popular for use in s...
# 21                      is  type of white marble of high quality popular f...
# 22                      is          type of marble of quality popular for use
# 23                      is  type of white marble of quality popular for us...
# 24                      is                                               type
# 25              is type of                                       white marble
# 26                   is in                                          sculpture
# 27      is type popular of                             marble of high quality
# 28      is type popular of                       white marble of high quality
# 29                      is  type of white marble popular for use in sculpture
# ...                    ...                                                ...
# 829055                 was                                              found
# 829056                 was  found by comparative sequencing of ~ 200 kbp o...
# 829057                 was  found by comparative sequencing as member of g...
# 829058                 was  found by sequencing as last member of gene clu...
# 829059                 was  found by sequencing of ~ 200 kbp as last membe...
# 829060                 was  found by sequencing of ~ 200 kbp of human DNA ...
# 829061                 was  found by comparative sequencing of ~ 200 kbp o...
# 829062                 was  found by sequencing of ~ 200 kbp of human DNA ...
# 829063        was found by                     sequencing of ~ 200 kbp of DNA
# 829064                 was  found by sequencing of ~ 200 kbp as last membe...
# 829065                 was  found by comparative sequencing of ~ 200 kbp a...
# 829066                 was                      found by sequencing as member
# 829067        was found by                comparative sequencing of ~ 200 kbp
# 829068        was found by               sequencing of ~ 200 kbp of human DNA
# 829069                 was  found by comparative sequencing of ~ 200 kbp o...
# 829070                 was      found by sequencing as member of gene cluster
# 829071                 was  found by comparative sequencing as last member...
# 829072                 was  found by sequencing as member of gene cluster ...
# 829073                 was                 found by sequencing as last member
# 829074                 was  found by comparative sequencing as member of g...
# 829075       is located on                                 human chromosome 4
# 829076       is located on    human chromosome 4 in cluster of CXC chemokines
# 829077       is located on  human chromosome 4 in cluster of other CXC che...
# 829078       is located on          chromosome 4 in cluster of CXC chemokines
# 829079       is located on                      human chromosome 4 in cluster
# 829080               is in                    cluster of other CXC chemokines
# 829081                  is                                            located
# 829082       is located on                            chromosome 4 in cluster
# 829083       is located on    chromosome 4 in cluster of other CXC chemokines
# 829084       is located on                                       chromosome 4
#
# [829085 rows x 5 columns]

# %%
rel_aliases = pd.read_csv('../relation_desc_aliases.tsv', sep='\t', header=None, names=['id', 'rel', 'desc', 'len_desc', 'aliases'])
aliases_dict = {}
for i in range(len(rel_aliases)):
    aliases = rel_aliases['aliases'][i]
    if isinstance(aliases, str):
        aliases_dict[rel_aliases['id'][i]] = aliases.split(', ')
    else:
        aliases_dict[rel_aliases['id'][i]] = [rel_aliases['rel'][i]]

# %%
aliases_dict['P1057']
# Out:
# ['on chromosome']

# %%
with open('../../dutta/align_v6.p', 'rb') as fp:
    dutta_dict = pickle.load(fp)

# %%
def get_entity_tuple_id(e1, e2, e1_kb, e2_kb):
    e1_wiki_id = ''
    e2_wiki_id = ''
    e1_label = ''
    e2_label = ''
    
    # Get e1 ID
    e1_list = [x for x in enteater.get_wikidata_id(e1) if 'Q' in x]
    if e1_kb in e1_list:
        e1_wiki_id = e1_kb
    else:
        if len(e1_list) >= 1:
            e1_wiki_id = e1_list[0]
    
    # Get e2 ID
    e2_list = [x for x in enteater.get_wikidata_id(e2) if 'Q' in x]
    if e2_kb in e2_list:
        e2_wiki_id = e2_kb
    else:
        if len(e2_list) >= 1:
            e2_wiki_id = e2_list[0]
    
    return (e1_wiki_id, e1_label, e2_wiki_id, e2_label)

# %%
def get_relation_label(rel_kb_id, rel_kb, rel_oie):
    if rel_kb == rel_oie or (rel_oie in rel_kb) or (rel_kb in rel_oie):
        return '0'
    
    aliases = aliases_dict[rel_kb_id]
    for alias in aliases:
        alias = alias.lower()
        if alias == rel_oie or (rel_oie in alias) or (alias in rel_oie):
            return '0'
    
    oie_nlp = nlp(rel_oie)
    oie_lemma = ''
    for token in oie_nlp:
        oie_lemma = oie_lemma + ' ' + token.lemma_
    
    if rel_kb == oie_lemma or (oie_lemma in rel_kb) or (rel_kb in oie_lemma):
        return '0'
    
    for alias in aliases:
        alias = alias.lower()
        if alias == oie_lemma or (oie_lemma in alias) or (alias in oie_lemma):
            return '0'
        
#     try:
#         rels_d = dutta_dict[rel_kb_id]
#         for rel in rels_d:
#             rel = rel.lower()
#             if rel == rel_oie or (rel_oie in rel) or (rel in rel_oie):
#                 return '0'

#         for rel in rels_d:
#             rel = rel.lower()
#             if rel == oie_lemma or (oie_lemma in rel) or (rel in oie_lemma):
#                 return '0'
#     except KeyError:
#         return '1'
    
    return '1'

def is_similar_entity(ent_kb, ent_kb_id, ent_oie, ent_oie_id):
    if ent_kb_id == ent_oie_id:
        return True
    elif ent_kb == ent_oie:
        return True
    else:
        diff = nltk.edit_distance(ent_kb, ent_oie)
        if diff < 10 and ((ent_kb in ent_oie) or (ent_oie in ent_kb)):
            return True
        else:
            return False
    
def normalize_entity(ent):
    if not isinstance(ent, str):
        ent = str(ent)
    ent = ent.replace(' \'s', '\'s')
    ent = ent.replace('-', '')
    return ent

# %%
align_data = []
sent_idx_list = set()
len_openie = len(data_openie)
for i in tqdm(range(len_openie)):
    sent_idx = data_openie['sent_id'][i]
    e1_kb_id = data_kb['e1_id'][sent_idx]
    e2_kb_id = data_kb['e2_id'][sent_idx]
    e1_kb = normalize_entity(data_kb['e1_label'][sent_idx])
    e2_kb = normalize_entity(data_kb['e2_label'][sent_idx])
    rel_kb = data_kb['rel_label'][sent_idx].lower()
    rel_kb_id = data_kb['rel_id'][sent_idx]
    e1_oie = normalize_entity(data_openie['e1'][i])
    e2_oie = normalize_entity(data_openie['e2'][i])
    rel_oie = data_openie['rel'][i].lower()
    e1_oie_id, e1_oie_root, e2_oie_id, e2_oie_root = get_entity_tuple_id(e1_oie, e2_oie, e1_kb_id, e2_kb_id)
    
    if is_similar_entity(e1_kb, e1_kb_id, e1_oie, e1_oie_id) and is_similar_entity(e2_kb, e2_kb_id, e2_oie, e2_oie_id):
#         label = get_relation_label(rel_kb_id, rel_kb, rel_oie)
#         if label == '0':
        label = '0'
        align_data.append((e1_kb, rel_kb, rel_kb_id, e2_kb,
                           e1_oie, rel_oie, e2_oie,
                           e1_kb_id, e2_kb_id, e1_oie_id, e2_oie_id, e1_oie_root, e2_oie_root,
                           label))
        sent_idx_list.add(sent_idx)
    elif is_similar_entity(e1_kb, e1_kb_id, e1_oie, e1_oie_id) and not is_similar_entity(e2_kb, e2_kb_id, e2_oie, e2_oie_id):
        label = get_relation_label(rel_kb_id, rel_kb, rel_oie)
        if label == '1':
            align_data.append((e1_kb, rel_kb, rel_kb_id, e2_kb,
                               e1_oie, rel_oie, e2_oie,
                               e1_kb_id, e2_kb_id, e1_oie_id, e2_oie_id, e1_oie_root, e2_oie_root,
                               label))
            sent_idx_list.add(sent_idx)
    elif not is_similar_entity(e1_kb, e1_kb_id, e1_oie, e1_oie_id) and is_similar_entity(e2_kb, e2_kb_id, e2_oie, e2_oie_id):
        label = get_relation_label(rel_kb_id, rel_kb, rel_oie)
        if label == '1':
            align_data.append((e1_kb, rel_kb, rel_kb_id, e2_kb,
                               e1_oie, rel_oie, e2_oie,
                               e1_kb_id, e2_kb_id, e1_oie_id, e2_oie_id, e1_oie_root, e2_oie_root,
                               label))
            sent_idx_list.add(sent_idx)
# Out:
# 100%|██████████| 829085/829085 [57:19<00:00, 241.08it/s]

# %%
len(align_data), len(sent_idx_list)
# Out:
# (196234, 42874)

# %%
with open('../' + version + '/' + dt_type + '_align.tsv', 'w') as f:
    for item in align_data:
        len_item = len(item) - 1
        for i in range(len_item):
            f.write(str(item[i]) + '\t')
        f.write(str(item[len_item]) + '\n')
f.closed
# Out:
# True

# %% [markdown]
# ### Generate more positive examples

# %%
align_df = pd.read_csv('../' + version + '/' + dt_type + '_align.tsv', sep='\t', header=None, names=['e1_kb', 'rel_kb', 'rel_kb_id', 'e2_kb', 'e1_oie', 'rel_oie', 'e2_oie', 'e1_kb_id', 'e2_kb_id', 'e1_oie_id', 'e2_oie_id', 'e1_oie_root', 'e2_oie_root', 'label'])

# %%
align_df
# Out:
#                             e1_kb      rel_kb rel_kb_id                e2_kb  \
# 0            Ride a Crooked Trail       color      P462                color
# 1            Ride a Crooked Trail       color      P462                color
# 2            Ride a Crooked Trail       color      P462                color
# 3            Ride a Crooked Trail       color      P462                color
# 4                  Carrara marble       color      P462                white
# 5                  Carrara marble       color      P462                white
# 6                  Carrara marble       color      P462                white
# 7               Wing and a Prayer       color      P462        blackandwhite
# 8               Wing and a Prayer       color      P462        blackandwhite
# 9       Terror from the Year 5000       color      P462        blackandwhite
# 10                 Always on Duty       color      P462        blackandwhite
# 11                Special Mission       color      P462        blackandwhite
# 12                Special Mission       color      P462        blackandwhite
# 13                Special Mission       color      P462        blackandwhite
# 14                The Proud Rebel       color      P462                color
# 15                The Proud Rebel       color      P462                color
# 16                The Proud Rebel       color      P462                color
# 17                The Proud Rebel       color      P462                color
# 18                The Proud Rebel       color      P462                color
# 19                The Proud Rebel       color      P462                color
# 20                The Proud Rebel       color      P462                color
# 21                The Proud Rebel       color      P462                color
# 22                The Proud Rebel       color      P462                color
# 23                The Proud Rebel       color      P462                color
# 24                The Proud Rebel       color      P462                color
# 25                The Proud Rebel       color      P462                color
# 26                The Proud Rebel       color      P462                color
# 27                       Pakeezah       color      P462               colour
# 28                       Pakeezah       color      P462               colour
# 29                       Pakeezah       color      P462               colour
# ...                           ...         ...       ...                  ...
# 196204                      APOA5  chromosome     P1057  human chromosome 11
# 196205                      APOA5  chromosome     P1057  human chromosome 11
# 196206                      APOA5  chromosome     P1057  human chromosome 11
# 196207                      APOA5  chromosome     P1057  human chromosome 11
# 196208                      APOA5  chromosome     P1057  human chromosome 11
# 196209                      APOA5  chromosome     P1057  human chromosome 11
# 196210                      APOA5  chromosome     P1057  human chromosome 11
# 196211                      APOA5  chromosome     P1057  human chromosome 11
# 196212                      APOA5  chromosome     P1057  human chromosome 11
# 196213                      APOA5  chromosome     P1057  human chromosome 11
# 196214                      APOA5  chromosome     P1057  human chromosome 11
# 196215                      APOA5  chromosome     P1057  human chromosome 11
# 196216                      APOA5  chromosome     P1057  human chromosome 11
# 196217                      APOA5  chromosome     P1057  human chromosome 11
# 196218                      APOA5  chromosome     P1057  human chromosome 11
# 196219                      APOA5  chromosome     P1057  human chromosome 11
# 196220                      APOA5  chromosome     P1057  human chromosome 11
# 196221                      APOA5  chromosome     P1057  human chromosome 11
# 196222                      APOA5  chromosome     P1057  human chromosome 11
# 196223                      APOA5  chromosome     P1057  human chromosome 11
# 196224                      APOA5  chromosome     P1057  human chromosome 11
# 196225                      APOA5  chromosome     P1057  human chromosome 11
# 196226                      APOA5  chromosome     P1057  human chromosome 11
# 196227                      APOA5  chromosome     P1057  human chromosome 11
# 196228                      APOA5  chromosome     P1057  human chromosome 11
# 196229                      APOA5  chromosome     P1057  human chromosome 11
# 196230                      APOA5  chromosome     P1057  human chromosome 11
# 196231                      APOA5  chromosome     P1057  human chromosome 11
# 196232                     CXCL13  chromosome     P1057   human chromosome 4
# 196233                     CXCL13  chromosome     P1057   human chromosome 4
#
#                                   e1_oie             rel_oie  \
# 0                          Crooked Trail                  is
# 1                          Crooked Trail                  is
# 2                          Crooked Trail                  is
# 3                          Crooked Trail                  is
# 4          Carrara marble Carrara marble  is type popular of
# 5                                 marble                  is
# 6          Carrara marble Carrara marble          is type of
# 7                                   Wing                  is
# 8                                   Wing                  is
# 9                                 Terror                  is
# 10                  Duty Zu jeder Stunde                  is
# 11      Special Mission Im Sonderauftrag                  is
# 12              Mission Im Sonderauftrag                  is
# 13                         Sonderauftrag                  is
# 14                           Proud Rebel                  is
# 15                           Proud Rebel                  is
# 16                           Proud Rebel                  is
# 17                           Proud Rebel                  is
# 18                           Proud Rebel                  is
# 19                           Proud Rebel                  is
# 20                           Proud Rebel                  is
# 21                           Proud Rebel                  is
# 22                           Proud Rebel         directed by
# 23                           Proud Rebel                  is
# 24                           Proud Rebel                  is
# 25                           Proud Rebel                  is
# 26                           Proud Rebel                  is
# 27                              Pakeezah            acquired
# 28                              Pakeezah      since acquired
# 29                              Pakeezah                  is
# ...                                  ...                 ...
# 196204                        APOA5 gene                 was
# 196205                        APOA5 gene                 was
# 196206                        APOA5 gene                 was
# 196207                        APOA5 gene        was found as
# 196208                        APOA5 gene                 was
# 196209                        APOA5 gene                 was
# 196210                        APOA5 gene                 was
# 196211                        APOA5 gene                 was
# 196212                        APOA5 gene                 was
# 196213                        APOA5 gene                 was
# 196214                        APOA5 gene                 was
# 196215                        APOA5 gene                 was
# 196216                        APOA5 gene                 was
# 196217                        APOA5 gene                 was
# 196218                        APOA5 gene                 was
# 196219                        APOA5 gene                 was
# 196220                        APOA5 gene        was found by
# 196221                        APOA5 gene                 was
# 196222                        APOA5 gene                 was
# 196223                        APOA5 gene                 was
# 196224                        APOA5 gene        was found by
# 196225                        APOA5 gene        was found by
# 196226                        APOA5 gene                 was
# 196227                        APOA5 gene                 was
# 196228                        APOA5 gene                 was
# 196229                        APOA5 gene                 was
# 196230                        APOA5 gene                 was
# 196231                        APOA5 gene                 was
# 196232                              gene       is located on
# 196233                              gene       is located on
#
#                                                    e2_oie   e1_kb_id  \
# 0       1958 Eastmancolor Western film shot in CinemaS...   Q2489949
# 1                     1958 Eastmancolor Western film shot   Q2489949
# 2            1958 American Eastmancolor Western film shot   Q2489949
# 3       1958 American Eastmancolor Western film shot i...   Q2489949
# 4                                            white marble     Q40088
# 5                                                 popular     Q40088
# 6                                            white marble     Q40088
# 7                                           blackandwhite   Q2080084
# 8                                           blackandwhite   Q2080084
# 9                                           blackandwhite   Q2514152
# 10                                     blackandwhite film   Q4738474
# 11                                     blackandwhite film  Q20002488
# 12                                     blackandwhite film  Q20002488
# 13                                          blackandwhite  Q20002488
# 14       1958 Technicolor film directed by Michael Curtiz   Q3222758
# 15      1958 American Technicolor film directed by Mic...   Q3222758
# 16      1958 American Technicolor western film directe...   Q3222758
# 17                          1958 Technicolor western film   Q3222758
# 18        1958 American Technicolor western film directed   Q3222758
# 19                 1958 Technicolor western film directed   Q3222758
# 20                 1958 American Technicolor western film   Q3222758
# 21      1958 Technicolor western film directed by Mich...   Q3222758
# 22                                         Michael Curtiz   Q3222758
# 23                                  1958 Technicolor film   Q3222758
# 24                1958 American Technicolor film directed   Q3222758
# 25                         1958 American Technicolor film   Q3222758
# 26                         1958 Technicolor film directed   Q3222758
# 27                                      major cult status    Q851395
# 28                                      major cult status    Q851395
# 29               India's first colour film in Cinemascope    Q851395
# ...                                                   ...        ...
# 196204  found by sequencing of ~ 200 kbp as last membe...  Q18049241
# 196205  found by comparative sequencing of ~ 200 kbp o...  Q18049241
# 196206  found by comparative sequencing of ~ 200 kbp a...  Q18049241
# 196207                        last member of gene cluster  Q18049241
# 196208  found by sequencing as last member of gene clu...  Q18049241
# 196209  found by sequencing of ~ 200 kbp of DNA as las...  Q18049241
# 196210  found by sequencing of ~ 200 kbp as last membe...  Q18049241
# 196211         found by sequencing of ~ 200 kbp as member  Q18049241
# 196212                                              found  Q18049241
# 196213  found by comparative sequencing of ~ 200 kbp o...  Q18049241
# 196214  found by comparative sequencing as member of g...  Q18049241
# 196215  found by sequencing as last member of gene clu...  Q18049241
# 196216  found by sequencing of ~ 200 kbp as last membe...  Q18049241
# 196217  found by sequencing of ~ 200 kbp of human DNA ...  Q18049241
# 196218  found by comparative sequencing of ~ 200 kbp o...  Q18049241
# 196219  found by sequencing of ~ 200 kbp of human DNA ...  Q18049241
# 196220                     sequencing of ~ 200 kbp of DNA  Q18049241
# 196221  found by sequencing of ~ 200 kbp as last membe...  Q18049241
# 196222  found by comparative sequencing of ~ 200 kbp a...  Q18049241
# 196223                      found by sequencing as member  Q18049241
# 196224                comparative sequencing of ~ 200 kbp  Q18049241
# 196225               sequencing of ~ 200 kbp of human DNA  Q18049241
# 196226  found by comparative sequencing of ~ 200 kbp o...  Q18049241
# 196227      found by sequencing as member of gene cluster  Q18049241
# 196228  found by comparative sequencing as last member...  Q18049241
# 196229  found by sequencing as member of gene cluster ...  Q18049241
# 196230                 found by sequencing as last member  Q18049241
# 196231  found by comparative sequencing as member of g...  Q18049241
# 196232                                 human chromosome 4  Q14907873
# 196233                                       chromosome 4  Q14907873
#
#          e2_kb_id e1_oie_id e2_oie_id  e1_oie_root  e2_oie_root  label
# 0       Q22006653  Q7728157       NaN          NaN          NaN      1
# 1       Q22006653  Q7728157       NaN          NaN          NaN      1
# 2       Q22006653  Q7728157       NaN          NaN          NaN      1
# 3       Q22006653  Q7728157       NaN          NaN          NaN      1
# 4          Q23444       NaN       NaN          NaN          NaN      1
# 5          Q23444  Q2080761   Q400146          NaN          NaN      1
# 6          Q23444       NaN       NaN          NaN          NaN      1
# 7         Q838368   Q161358       NaN          NaN          NaN      1
# 8         Q838368   Q161358       NaN          NaN          NaN      1
# 9         Q838368  Q1968139       NaN          NaN          NaN      1
# 10        Q838368       NaN       NaN          NaN          NaN      1
# 11        Q838368       NaN       NaN          NaN          NaN      1
# 12        Q838368       NaN       NaN          NaN          NaN      1
# 13        Q838368       NaN       NaN          NaN          NaN      1
# 14      Q22006653  Q3222758       NaN          NaN          NaN      1
# 15      Q22006653  Q3222758       NaN          NaN          NaN      1
# 16      Q22006653  Q3222758       NaN          NaN          NaN      1
# 17      Q22006653  Q3222758       NaN          NaN          NaN      1
# 18      Q22006653  Q3222758       NaN          NaN          NaN      1
# 19      Q22006653  Q3222758       NaN          NaN          NaN      1
# 20      Q22006653  Q3222758       NaN          NaN          NaN      1
# 21      Q22006653  Q3222758       NaN          NaN          NaN      1
# 22      Q22006653  Q3222758    Q51491          NaN          NaN      1
# 23      Q22006653  Q3222758       NaN          NaN          NaN      1
# 24      Q22006653  Q3222758       NaN          NaN          NaN      1
# 25      Q22006653  Q3222758       NaN          NaN          NaN      1
# 26      Q22006653  Q3222758       NaN          NaN          NaN      1
# 27      Q22006653   Q851395       NaN          NaN          NaN      1
# 28      Q22006653   Q851395       NaN          NaN          NaN      1
# 29      Q22006653   Q851395       NaN          NaN          NaN      1
# ...           ...       ...       ...          ...          ...    ...
# 196204    Q847096       NaN       NaN          NaN          NaN      1
# 196205    Q847096       NaN       NaN          NaN          NaN      1
# 196206    Q847096       NaN       NaN          NaN          NaN      1
# 196207    Q847096       NaN       NaN          NaN          NaN      1
# 196208    Q847096       NaN       NaN          NaN          NaN      1
# 196209    Q847096       NaN       NaN          NaN          NaN      1
# 196210    Q847096       NaN       NaN          NaN          NaN      1
# 196211    Q847096       NaN       NaN          NaN          NaN      1
# 196212    Q847096       NaN  Q5474251          NaN          NaN      1
# 196213    Q847096       NaN       NaN          NaN          NaN      1
# 196214    Q847096       NaN       NaN          NaN          NaN      1
# 196215    Q847096       NaN       NaN          NaN          NaN      1
# 196216    Q847096       NaN       NaN          NaN          NaN      1
# 196217    Q847096       NaN       NaN          NaN          NaN      1
# 196218    Q847096       NaN       NaN          NaN          NaN      1
# 196219    Q847096       NaN       NaN          NaN          NaN      1
# 196220    Q847096       NaN       NaN          NaN          NaN      1
# 196221    Q847096       NaN       NaN          NaN          NaN      1
# 196222    Q847096       NaN       NaN          NaN          NaN      1
# 196223    Q847096       NaN       NaN          NaN          NaN      1
# 196224    Q847096       NaN       NaN          NaN          NaN      1
# 196225    Q847096       NaN       NaN          NaN          NaN      1
# 196226    Q847096       NaN       NaN          NaN          NaN      1
# 196227    Q847096       NaN       NaN          NaN          NaN      1
# 196228    Q847096       NaN       NaN          NaN          NaN      1
# 196229    Q847096       NaN       NaN          NaN          NaN      1
# 196230    Q847096       NaN       NaN          NaN          NaN      1
# 196231    Q847096       NaN       NaN          NaN          NaN      1
# 196232    Q836605  Q5531066       NaN          NaN          NaN      1
# 196233    Q836605  Q5531066       NaN          NaN          NaN      1
#
# [196234 rows x 14 columns]

# %%
align_df.groupby(['rel_kb_id', 'rel_kb', 'rel_oie', 'label']).size().to_csv('../' + version + '/' + dt_type + '_align_freq.tsv', sep='\t')

# %%
align_df.groupby(['label']).size()
# Out:
# label
# 0     11613
# 1    184621
# dtype: int64

# %%
# rel_except = ['P175']
# align_df_pos = align_df[(align_df.label != 1) & (~align_df.rel_kb_id.isin(rel_except))]
align_df_pos = align_df[(align_df.label != 1)]

# %%
align_df_pos
# Out:
#                       e1_kb       rel_kb rel_kb_id  \
# 52                Félicette        color      P462
# 94                    Smaug        color      P462
# 138           Second Choice        color      P462
# 148                99 Homes  film editor     P1040
# 150                99 Homes  film editor     P1040
# 205               Session 9  film editor     P1040
# 253            Toto Forever  film editor     P1040
# 309      His New Profession  film editor     P1040
# 329        Hooligan Sparrow  film editor     P1040
# 380               True Lies  film editor     P1040
# 381               True Lies  film editor     P1040
# 453                 Cabiria  film editor     P1040
# 454            Citizen Kane  film editor     P1040
# 502                Desierto  film editor     P1040
# 542          Loving Vincent  film editor     P1040
# 571                Spy Kids  film editor     P1040
# 748                    Agne       family       P53
# 759                    Agne       family       P53
# 799               Wang Mang       family       P53
# 818                Hethum I       family       P53
# 823          Diomede Carafa       family       P53
# 842     Emperor Ling of Han       family       P53
# 843     Emperor Ling of Han       family       P53
# 871        Theodora Komnene       family       P53
# 904                 Hugleik       family       P53
# 905                 Hugleik       family       P53
# 908                 Hugleik       family       P53
# 910                 Hugleik       family       P53
# 916                Ismail I       family       P53
# 965        Cenred of Wessex       family       P53
# ...                     ...          ...       ...
# 195737         Linux kernel      license      P275
# 195742         Linux kernel      license      P275
# 195764          Qt Extended      license      P275
# 195765          Qt Extended      license      P275
# 195766          Qt Extended      license      P275
# 195767          Qt Extended      license      P275
# 195778              Bersirc      license      P275
# 195798              Warface      license      P275
# 195802             TeX Live      license      P275
# 195856                 Jimm      license      P275
# 195906              OpenBSD      license      P275
# 195911              OpenBSD      license      P275
# 195915                Gajim      license      P275
# 195919             Code2000      license      P275
# 195927               KisMAC      license      P275
# 195935               Xuheki      license      P275
# 195942            GStreamer      license      P275
# 195957             Code2000      license      P275
# 195975            Icy Tower      license      P275
# 195982               LAMMPS      license      P275
# 195986             Verinice      license      P275
# 195991               JASPAR      license      P275
# 195998               JASPAR      license      P275
# 196000               JASPAR      license      P275
# 196032    Chinese Wikipedia      license      P275
# 196033    Chinese Wikipedia      license      P275
# 196043              DaDaBIK      license      P275
# 196051              DaDaBIK      license      P275
# 196071     B1 Free Archiver      license      P275
# 196078              JSmooth      license      P275
#
#                                     e2_kb              e1_oie  \
# 52                                  black           Félicette
# 94                                    red               Smaug
# 138                         blackandwhite              Choice
# 148                         Ramin Bahrani   99 Homes 99 Homes
# 150                         Ramin Bahrani      Homes 99 Homes
# 205                         Brad Anderson             Session
# 253                     Roberto F. Canuto        Toto Forever
# 309                       Charlie Chaplin  His New Profession
# 329                            Nanfu Wang    Hooligan Sparrow
# 380                         James Cameron                Lies
# 381                         James Cameron           True Lies
# 453                     Giovanni Pastrone     Cabiria Cabiria
# 454                           Robert Wise        Citizen Kane
# 502                          Jonás Cuarón   Desierto Desierto
# 542                        Dorota Kobiela      Loving Vincent
# 571                      Robert Rodriguez   Spy Kids Spy Kids
# 748                               Yngling           Agne Agne
# 759                               Yngling           Agne Agne
# 799                           Xin dynasty           Wang Mang
# 818                             Hethumids            Hethum I
# 823                       House of Carafa      Diomede Carafa
# 842                           Han dynasty        Emperor Ling
# 843                           Han dynasty        Emperor Ling
# 871                              Komnenos    Theodora Komnene
# 904                               Yngling     Hugleik Hugleik
# 905                               Yngling     Hugleik Hugleik
# 908                               Yngling     Hugleik Hugleik
# 910                               Yngling     Hugleik Hugleik
# 916                       Safavid dynasty            Ismail I
# 965                       House of Wessex              Cenred
# ...                                   ...                 ...
# 195737                              GPLv2        Linux kernel
# 195742                              GPLv2        Linux kernel
# 195764         GNU General Public License                  Qt
# 195765         GNU General Public License                  Qt
# 195766         GNU General Public License                  Qt
# 195767         GNU General Public License                  Qt
# 195778  GNU Lesser General Public License             Bersirc
# 195798                         freetoplay             Warface
# 195802                      free software                Live
# 195856         GNU General Public License                Jimm
# 195906                        ISC license             OpenBSD
# 195911                        ISC license     OpenBSD project
# 195915         GNU General Public License               Gajim
# 195919                          shareware       Code2000 font
# 195927         GNU General Public License              KisMAC
# 195935         GNU General Public License              Xuheki
# 195942  GNU Lesser General Public License           GStreamer
# 195957                           freeware       Code2000 font
# 195975                           freeware               Tower
# 195982         GNU General Public License              LAMMPS
# 195986         GNU General Public License            Verinice
# 195991                        open access              JASPAR
# 195998                        open access       JASPAR JASPAR
# 196000                        open access       JASPAR JASPAR
# 196032     GNU Free Documentation License           Wikipedia
# 196033     GNU Free Documentation License   Chinese Wikipedia
# 196043         GNU General Public License             DaDaBIK
# 196051         GNU General Public License             DaDaBIK
# 196071                proprietary license    B1 Free Archiver
# 196078         GNU General Public License             JSmooth
#
#                               rel_oie  \
# 52                                was
# 94                                was
# 138                                is
# 148                        written by
# 150                        written by
# 205                       directed by
# 253                    's director is
# 309                          starring
# 329                             shows
# 380                        written by
# 381                        written by
# 453                       directed by
# 454                     was edited by
# 502                       directed by
# 542                   was realized by
# 571                        written by
# 748          was mythological king of
# 759                       was king of
# 799                        emperor of
# 818                          first of
# 823                          was born
# 842               was 12th emperor of
# 843                    was emperor of
# 871                          niece of
# 904                       was king of
# 905               was swedish king of
# 908             was king according to
# 910     was swedish king according to
# 916                        founder of
# 965                     was member of
# ...                               ...
# 195737              is released under
# 195742              is released under
# 195764              is licensed under
# 195765         is dual licensed under
# 195766              is licensed under
# 195767         is dual licensed under
# 195778             was licensed under
# 195798                             is
# 195802                             is
# 195856              is licensed under
# 195906                     preferring
# 195911                          using
# 195915                 released under
# 195919               was available as
# 195927              distributed under
# 195935              is released under
# 195942                     is free to
# 195957                    code2001 as
# 195975                             is
# 195982              distributed under
# 195986              is licensed under
# 195991                             is
# 195998                             is
# 196000                             is
# 196032              is released under
# 196033              is released under
# 196043  was originally released under
# 196051             was released under
# 196071              is released under
# 196078           is distributed under
#
#                                             e2_oie   e1_kb_id   e2_kb_id  \
# 52                                   blackandwhite  Q12165555     Q23445
# 94                                      considered     Q46302      Q3142
# 138                                  blackandwhite   Q7443191    Q838368
# 148                                        Bahrani  Q16147760   Q3418487
# 150                                        Bahrani  Q16147760   Q3418487
# 205                                  Brad Anderson    Q577221    Q598238
# 253                              Roberto F. Canuto  Q17504820  Q17486474
# 309                                Charlie Chaplin   Q2367759       Q882
# 329                                     Nanfu Wang  Q24608885  Q24609090
# 380                                  James Cameron    Q110397     Q42574
# 381                                  James Cameron    Q110397     Q42574
# 453                              Giovanni Pastrone   Q1024861     Q53043
# 454                                    Robert Wise     Q24815     Q59821
# 502                                   Jonás Cuarón  Q21076281  Q15142000
# 542                                 Dorota Kobiela  Q23013713  Q41825009
# 571                               Robert Rodriguez    Q550581     Q47284
# 748                               House of Yngling   Q2436711    Q913138
# 759                               House of Yngling   Q2436711    Q913138
# 799                                    Xin dynasty      Q7250    Q504769
# 818                                      Hethumids    Q733854    Q798581
# 823                         son of House of Carafa    Q714983    Q351733
# 842                            Eastern Han dynasty      Q7299      Q7209
# 843                            Eastern Han dynasty      Q7299      Q7209
# 871                              Manuel I Komnenos    Q273606    Q163814
# 904                               House of Yngling   Q3480168    Q913138
# 905                               House of Yngling   Q3480168    Q913138
# 908                                  Ynglinga saga   Q3480168    Q913138
# 910                                  Ynglinga saga   Q3480168    Q913138
# 916                                Safavid dynasty    Q214559    Q161205
# 965                                House of Wessex    Q886103    Q511482
# ...                                            ...        ...        ...
# 195737        GNU General Public License version 2     Q14579  Q10513450
# 195742                                       GPLv2     Q14579  Q10513450
# 195764                  GNU General Public License   Q2116784      Q7603
# 195765                  GNU General Public License   Q2116784      Q7603
# 195766                                         GPL   Q2116784      Q7603
# 195767                                         GPL   Q2116784      Q7603
# 195778           GNU Lesser General Public License    Q793717    Q192897
# 195798                                  freetoplay   Q1052646   Q1414510
# 195802                                        free   Q2002007       Q341
# 195856         terms of GNU General Public License   Q1471481      Q7603
# 195906                                 ISC license     Q34215    Q386474
# 195911                                 ISC license     Q34215    Q386474
# 195915                  GNU General Public License     Q58105      Q7603
# 195919                                   shareware   Q1105549    Q185534
# 195927                  GNU General Public License   Q2036340      Q7603
# 195935                  GNU General Public License   Q8045239      Q7603
# 195942  terms of GNU Lesser General Public License    Q860213    Q192897
# 195957                                    freeware   Q1105549    Q178285
# 195975                                    freeware    Q250355    Q178285
# 195982         terms of GNU General Public License   Q4042577      Q7603
# 195986                  GNU General Public License   Q7921362      Q7603
# 195991                                        open  Q24700947    Q232932
# 195998                                      access  Q24700947    Q232932
# 196000                                 open access  Q24700947    Q232932
# 196032              GNU Free Documentation License     Q30239     Q22169
# 196033              GNU Free Documentation License     Q30239     Q22169
# 196043                  GNU General Public License   Q3700641      Q7603
# 196051                  GNU General Public License   Q3700641      Q7603
# 196071                         proprietary license  Q15894894   Q3238057
# 196078                  GNU General Public License   Q1244713      Q7603
#
#         e1_oie_id  e2_oie_id  e1_oie_root  e2_oie_root  label
# 52      Q12165555        NaN          NaN          NaN      0
# 94         Q46302        NaN          NaN          NaN      0
# 138      Q1075772        NaN          NaN          NaN      0
# 148           NaN        NaN          NaN          NaN      0
# 150           NaN        NaN          NaN          NaN      0
# 205       Q362310    Q598238          NaN          NaN      0
# 253     Q17504820  Q17486474          NaN          NaN      0
# 309      Q2367759       Q882          NaN          NaN      0
# 329     Q24608885  Q24609090          NaN          NaN      0
# 380       Q623837     Q42574          NaN          NaN      0
# 381       Q110397     Q42574          NaN          NaN      0
# 453           NaN     Q53043          NaN          NaN      0
# 454        Q24815     Q59821          NaN          NaN      0
# 502           NaN  Q15142000          NaN          NaN      0
# 542     Q23013713        NaN          NaN          NaN      0
# 571           NaN     Q47284          NaN          NaN      0
# 748           NaN        NaN          NaN          NaN      0
# 759           NaN        NaN          NaN          NaN      0
# 799         Q7250    Q504769          NaN          NaN      0
# 818           NaN    Q798581          NaN          NaN      0
# 823       Q714983        NaN          NaN          NaN      0
# 842           NaN        NaN          NaN          NaN      0
# 843           NaN        NaN          NaN          NaN      0
# 871       Q273606     Q41610          NaN          NaN      0
# 904           NaN        NaN          NaN          NaN      0
# 905           NaN        NaN          NaN          NaN      0
# 908           NaN    Q510143          NaN          NaN      0
# 910           NaN    Q510143          NaN          NaN      0
# 916       Q214559    Q161205          NaN          NaN      0
# 965       Q886103    Q511482          NaN          NaN      0
# ...           ...        ...          ...          ...    ...
# 195737     Q14579  Q10513450          NaN          NaN      0
# 195742     Q14579  Q10513450          NaN          NaN      0
# 195764  Q19877427      Q7603          NaN          NaN      0
# 195765  Q19877427      Q7603          NaN          NaN      0
# 195766  Q19877427      Q7603          NaN          NaN      0
# 195767  Q19877427      Q7603          NaN          NaN      0
# 195778    Q793717    Q192897          NaN          NaN      0
# 195798   Q1052646        NaN          NaN          NaN      0
# 195802   Q1943677     Q45650          NaN          NaN      0
# 195856   Q1471481        NaN          NaN          NaN      0
# 195906     Q34215    Q386474          NaN          NaN      0
# 195911        NaN    Q386474          NaN          NaN      0
# 195915     Q58105      Q7603          NaN          NaN      0
# 195919        NaN    Q185534          NaN          NaN      0
# 195927   Q2036340      Q7603          NaN          NaN      0
# 195935   Q8045239      Q7603          NaN          NaN      0
# 195942    Q860213        NaN          NaN          NaN      0
# 195957        NaN    Q178285          NaN          NaN      0
# 195975    Q869870    Q178285          NaN          NaN      0
# 195982   Q4042577        NaN          NaN          NaN      0
# 195986   Q7921362      Q7603          NaN          NaN      0
# 195991  Q24700947   Q7095927          NaN          NaN      0
# 195998        NaN    Q338906          NaN          NaN      0
# 196000        NaN    Q232932          NaN          NaN      0
# 196032   Q3913001     Q22169          NaN          NaN      0
# 196033     Q30239     Q22169          NaN          NaN      0
# 196043   Q3700641      Q7603          NaN          NaN      0
# 196051   Q3700641      Q7603          NaN          NaN      0
# 196071  Q15894894   Q3238057          NaN          NaN      0
# 196078   Q1244713      Q7603          NaN          NaN      0
#
# [11613 rows x 14 columns]

# %%
align_data = []
len_pos = len(align_df_pos)
for idx, row in tqdm(align_df_pos.iterrows(), total=align_df_pos.shape[0]):
    e1, e1_id, rel, rel_id, e2, e2_id = row['e1_kb'], row['e1_kb_id'], row['rel_kb'], row['rel_kb_id'], row['e2_kb'], row['e2_kb_id']
    pos_list = align_df_pos[(align_df_pos.rel_kb_id == rel_id) & (align_df_pos.e1_kb_id != e1_id) & (align_df_pos.e2_kb_id != e2_id)]
    if len(pos_list) > 0:
        for idx_l, row_l in pos_list.iterrows():
            align_data.append({
                'e1_kb': e1,
                'rel_kb': rel,
                'rel_kb_id': rel_id,
                'e2_kb': e2,
                'e1_oie': row_l['e1_oie'],
                'rel_oie': row_l['rel_oie'],
                'e2_oie': row_l['e2_oie'],
                'e1_kb_id': e1_id,
                'e2_kb_id': e2_id,
                'e1_oie_id': row_l['e1_oie_id'],
                'e2_oie_id': row_l['e2_oie_id'],
                'e1_oie_root': row_l['e1_oie_root'],
                'e2_oie_root': row_l['e2_oie_root'],
                'label': 0
            })
# Out:
# 100%|██████████| 11613/11613 [04:56<00:00, 39.12it/s]

# %%
align_df = align_df.append(align_data)

# %%
align_df.to_csv('../' + version + '/' + dt_type + '_align_all.tsv', sep='\t', header=False, index=False)

# %%
len(align_df)
# Out:
# 2397308

# %%
align_df.groupby(['label']).size()
# Out:
# label
# 0    2212687
# 1     184621
# dtype: int64
